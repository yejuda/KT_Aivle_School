# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/air.png?raw=true" width=800 align="left"/>

# %% [markdown]
# # 실습 내용
#
# - 머신러닝 모델링을 위한 코딩은 무조건 할 수 있어야 합니다.
# - 코딩 내용을 자세히 알지 못해도 **무작정** 코딩을 진행해봅니다.
# - AirQuality 데이터를 대상으로 모델링 해서 오존 농도를 예측해 봅니다.
# - LinearRegression 알고리즘을 사용합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 **라이브러리**와 대상 **데이터**를 가져와 이후 과정을 준비합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_11.png?raw=true" width=700 align="left"/>

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/Jangrae/csv/master/airquality_simple.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 **충분히 이해**할 수 있도록 다양한 **탐색** 과정을 수행합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_12.png?raw=true" width=700 align="left"/>

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41    190.0   7.4    67      5    1
# 1     36    118.0   8.0    72      5    2
# 2     12    149.0  12.6    74      5    3
# 3     18    313.0  11.5    62      5    4
# 4     19      NaN  14.3    56      5    5

# %%
# 하위 몇 개 행 확인
data.tail()
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 148     30    193.0   6.9    70      9   26
# 149     23    145.0  13.2    77      9   27
# 150     14    191.0  14.3    75      9   28
# 151     18    131.0   8.0    76      9   29
# 152     20    223.0  11.5    68      9   30

# %%
# 변수 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    153 non-null    int64
#  1   Solar.R  146 non-null    float64
#  2   Wind     153 non-null    float64
#  3   Temp     153 non-null    int64
#  4   Month    153 non-null    int64
#  5   Day      153 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 7.3 KB

# %%
# 기술통계 확인
data.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  153.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.052288  185.931507    9.957516   77.882353    6.993464   15.803922
# std     30.156127   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     20.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     34.000000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     59.000000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
# 상관관계 확인

# data.corr(numeric_only = True) -> 수치형 데이터만 사용하겠다는 의미
# 사용하지 않은 경우 warnning이 발견할 수 있음
tmp = data.corr(numeric_only = True)  
tmp.style.background_gradient()   # 히트맵을 그리지 않아도 색깔별로 확인 가능
# Out:
# <style type="text/css">
# #T_feec6_row0_col0, #T_feec6_row1_col1, #T_feec6_row2_col2, #T_feec6_row3_col3, #T_feec6_row4_col4, #T_feec6_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_feec6_row0_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_feec6_row0_col2, #T_feec6_row1_col5, #T_feec6_row2_col0, #T_feec6_row2_col3, #T_feec6_row2_col4, #T_feec6_row5_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_feec6_row0_col3 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_feec6_row0_col4 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_feec6_row0_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_feec6_row1_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_feec6_row1_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_feec6_row1_col3 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_feec6_row1_col4 {
#   background-color: #f2ecf5;
# ...

# %%
# 상관관계 시각화
sns.heatmap(data.corr(numeric_only=True),
            annot = True,
            cmap = 'Blues',
            cbar = False,
            square = True,  # 정사각형으로
            fmt = '.3f',  # 소수점 3자리까지,
            annot_kws = {'size': 8}
            )
plt.show()

# %% [markdown]
# # 3.데이터 준비
#
# - **전처리** 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_13.png?raw=true" width=700 align="left"/>

# %% [markdown]
# **1) 결측치 처리**
#
# - 결측치가 있으면 제거하거나 적절한 값으로 채웁니다.

# %%
# 결측치 확인
data.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
# 전날 값으로 결측치 채우기
# data.ffill(inplace = True)
data.interpolate(method = 'nearest', inplace = True)

# 확인
data.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %% [markdown]
# **2) 변수 제거**
#
# - 분석에 의미가 없다고 판단되는 변수는 제거합니다.

# %%
# 변수 제거
drop_cols = ['Month', 'Day']
data.drop(columns = drop_cols, inplace = True)

# 확인
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp
# 0     41    190.0   7.4    67
# 1     36    118.0   8.0    72
# 2     12    149.0  12.6    74
# 3     18    313.0  11.5    62
# 4     19    313.0  14.3    56

# %% [markdown]
# **3) x, y 분리**
#
# - 우선 target 변수를 명확히 지정합니다.
# - target을 제외한 나머지 변수들 데이터는 x로 선언합니다.
# - target 변수 데이터는 y로 선언합니다.
# - 이 결과로 만들어진 x는 데이터프레임, y는 시리즈가 됩니다.
# - 이후 모든 작업은 x, y를 대상으로 진행합니다.

# %%
# target 확인
target ='Ozone'

# 데이터 분리
x = data.drop(columns=target)
y = data.loc[:, 'Ozone']

# %%
x.head()
# Out:
#    Solar.R  Wind  Temp
# 0    190.0   7.4    67
# 1    118.0   8.0    72
# 2    149.0  12.6    74
# 3    313.0  11.5    62
# 4    313.0  14.3    56

# %%
y.head()
# Out:
# 0    41
# 1    36
# 2    12
# 3    18
# 4    19
# Name: Ozone, dtype: int64

# %% [markdown]
# **4) 학습용, 평가용 데이터 분리**
#
# - 학습용, 평가용 데이터를 적절한 비율로 분리합니다.
# - 반복 실행 시 동일한 결과를 얻기 위해 random_state 옵션을 지정합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/split.png?raw=true" width=500 align="left"/>

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 7:3으로 분리 -> 데이터를 섞어서 나누는 것이다.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 1)

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 **선언**하고 **학습**하고 **평가**하는 과정을 진행합니다.
# - 우선 **회귀** 문제인지 **분류** 문제인지 명확히 구분합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_14.png?raw=true" width=700 align="left"/>

# %% [markdown]
# **1) 모델링**
#
# - 회귀 문제 인가요? 분류 문제인가요?
# - 회귀인지 분류인지에 따라 사용할 알고리즘과 평가 방법이 달라집니다.
# - 우선 다음 알고리즘과 평가 방법을 사용합니다.
#     - 알고리즘: LinearRegression
#     - 평가방법: mean_absolute_error

# %%
# 1단계: 불러오기
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# 2단계: 선언하기
model = LinearRegression()

# %%
# 3단계: 학습하기
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# x_test로 예측하고, y_test와 x_test로 예측한 것을 '평가한다'

# %%
# 4단계: 예측하기
y_pred = model.predict(x_test)

# %%
# 5단계: 평가하기
mean_absolute_error(y_test, y_pred)  # y_test가 실제 정답이다.
# Out:
# 14.210628925230605

# %% [markdown]
# * y_test.values[:10]
# y_test에 values가 붙는 이유.
# y_test는 시리즈 형태이고, 이 값을 보려고 하는 것이 values이다.

# %%
y_test
# Out:
# 59      24
# 33      18
# 69      97
# 127     47
# 31      34
# 107     22
# 97      66
# 14      18
# 53      69
# 44      27
# 147     14
# 138     46
# 78      61
# 102     48
# 5       28
# 85     108
# 16      34
# 100    110
# 89      50
# 95      78
# 91      59
# 124     78
# 92      39
# 99      89
# 93       9
# 40      39
# 29     115
# 42      62
# 54      52
# 122     85
# 35      49
# 19      11
# 113      9
# 103     44
# 77      35
# 145     36
# 58      50
# 121     84
# 56      55
# 28      45
# 51      49
# 109     23
# 66      40
# 17       6
# 119     76
# 126     91
# Name: Ozone, dtype: int64

# %%
# 실제값, 예측값

# y는 시리즈 형태이다.
# print('실제값:', y_test)   
print('실제값:', y_test.values[:10])  # 시리즈
print('예측값:', y_pred[:10])         # 배열
# Out:
# 실제값: [24 18 97 47 34 22 66 18 69 27]
# 예측값: [13.84003067  5.82919112 81.93563027 58.41267418 50.86150737 31.52971121
#  76.77834219 -8.56411529 50.2136544  39.13346172]

# %%
type(y_test)   # 시리즈 형태이기 때문에 위에서 .values를 붙여줘야한다.
# Out:
# pandas.core.series.Series

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
# 시각화 비교
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label = 'Predicted')
plt.legend()
plt.show()
