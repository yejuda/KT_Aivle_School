# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계3 : 단계별 모델링

# %% [markdown]
# ## 0.미션4

# %% [markdown]
# * 단계별로 나눠서 모델링을 수행하고자 합니다.
# * 단계 구분 예시
#     * 단계1 : 정적(0), 동적(1) 행동 분류 모델 생성
#     * 단계2 : 세부 동작에 대한 분류모델 생성
#         * 단계1 모델에서 0으로 예측 -> 정적 행동 3가지 분류 모델링
#         * 단계1 모델에서 1으로 예측 -> 동적 행동 3가지 분류 모델링
# * 모델 통합
#     * 두 단계 모델을 통합하고, 새로운 데이터에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
# * 성능 비교
#     * 기본 모델링의 성능과 비교
#     * 성능 가이드
#         * Accuracy : 0.97 ~ 0.99
# * 파이프라인 구성
#     * test 데이터를 입력하여, 전처리 및 예측결과가 나오도록 함수 구성

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/project3/'

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Input
from keras.backend import clear_session
from keras.optimizers import Adam

from keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %% [markdown]
# #### 1) 데이터로딩

# %%
data1 = pd.read_csv(path + '/data01_train.csv')
# data1.drop('subject', axis=1, inplace=True)
data1.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.965650         -0.929747  ...                        -0.816696
# 1         -0.987558         -0.937337  ...                        -0.693515
# 2         -0.995017         -0.942584  ...                        -0.829311
# 3         -0.347916          0.008288  ...                        -0.408956
# 4         -0.346372          0.584131  ...                        -0.563437
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.042494                             -0.044218
# 1                    -0.062899                              0.388459
# 2                     0.000265                             -0.525022
# 3                    -0.255125                              0.612804
# 4                    -0.044344                             -0.845268
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.307873                              0.072790
# 1                         -0.765014                              0.771524
# 2                         -0.891875                              0.021528
# 3                          0.747381                             -0.072944
# 4                         -0.974650                             -0.887846
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.601120              0.331298              0.165163       21
# 1              0.345205             -0.769186             -0.147944       15
# 2             -0.833564              0.202434             -0.032755       11
# 3             -0.695819              0.287154              0.111388       17
# 4             -0.705029              0.264952              0.137758       17
#
#              Activity
# 0            STANDING
# 1              LAYING
# 2            STANDING
# 3             WALKING
# 4  WALKING_DOWNSTAIRS
#
# [5 rows x 563 columns]

# %%
data2 = pd.read_csv(path + '/data01_test.csv')
# data2.drop('subject', axis=1, inplace=True)
data2.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 2           0.305833          -0.041023          -0.087303          0.006880
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 2          0.182800         -0.237984          0.005642          0.028616
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.958142         -0.938850  ...                        -0.850065
# 1         -0.971788         -0.939837  ...                        -0.613367
# 2         -0.236474          0.016311  ...                         0.394388
# 3         -0.974907         -0.941425  ...                        -0.841455
# 4         -0.856807         -0.920760  ...                         0.214219
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.018043                              0.092304
# 1                    -0.022456                             -0.155414
# 2                    -0.362616                              0.171069
# 3                     0.289548                              0.079801
# 4                     0.010111                              0.114179
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.074220                             -0.714534
# 1                          0.247498                             -0.112257
# 2                          0.576349                             -0.688314
# 3                         -0.020033                              0.291898
# 4                         -0.830776                             -0.325098
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.671943             -0.018351             -0.185733       22
# 1             -0.826816              0.184489             -0.068699       15
# 2             -0.743234              0.272186              0.053101       22
# 3             -0.639435             -0.111998             -0.123298        8
# 4             -0.840817              0.116237             -0.096615        5
#
#    Activity
# 0   SITTING
# 1  STANDING
# 2   WALKING
# 3   SITTING
# 4  STANDING
#
# [5 rows x 563 columns]

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
print('train : ', data1.shape)
print('test : ', data2.shape)
# Out:
# train :  (5881, 563)
# test :  (1471, 563)

# %%
data1.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# 25%           -0.992774         -0.977680         -0.980127         -0.993602
# 50%           -0.943933         -0.844575         -0.856352         -0.948501
# 75%           -0.242130         -0.034499         -0.262690         -0.291138
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       5881.000000       5881.000000       5881.000000  ...
# mean          -0.525944         -0.605374         -0.465490  ...
# std            0.485115          0.413043          0.544995  ...
# min           -0.999419         -1.000000         -1.000000  ...
# 25%           -0.977865         -0.980112         -0.936067  ...
# 50%           -0.849266         -0.849896         -0.878729  ...
# 75%           -0.068857         -0.268539         -0.013690  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      5881.000000                      5881.000000
# mean                         -0.305883                        -0.623548
# std                           0.322808                         0.310371
# min                          -0.979261                        -0.999765
# 25%                          -0.541969                        -0.845985
# 50%                          -0.342923                        -0.712677
# 75%                          -0.127371                        -0.501158
# max                           0.989538                         0.956845
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  5881.000000                           5881.000000
# mean                      0.008524                             -0.001185
# std                       0.339730                              0.447197
# min                      -0.976580                             -1.000000
# 25%                      -0.122361                             -0.294369
# 50%                       0.010278                              0.005146
# 75%                       0.154985                              0.285030
# max                       1.000000                              1.000000
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       5881.000000                           5881.000000
# mean                           0.009340                             -0.007099
# std                            0.608190                              0.476738
# min                           -1.000000                             -1.000000
# 25%                           -0.481718                             -0.373345
# 50%                            0.011448                             -0.000847
# 75%                            0.499857                              0.356236
# max                            0.998702                              0.996078
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           5881.000000           5881.000000           5881.000000
# mean              -0.491501              0.059299             -0.054594
# std                0.509069              0.297340              0.278479
# min               -1.000000             -1.000000             -0.980143
# 25%               -0.811397             -0.018203             -0.141555
# 50%               -0.709441              0.182893              0.003951
# 75%               -0.511330              0.248435              0.111932
# max                0.977344              0.478157              1.000000
#
#            subject
# count  5881.000000
# mean     17.381568
# std       8.938316
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %%
data2.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        1471.000000        1471.000000        1471.000000
# mean            0.273198          -0.017281          -0.108123
# std             0.079989           0.045957           0.049082
# min            -1.000000          -1.000000          -0.418354
# 25%             0.263787          -0.024792          -0.120733
# 50%             0.277322          -0.017187          -0.108124
# 75%             0.288058          -0.010238          -0.096606
# max             0.631510           0.359587           0.543939
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       1471.000000       1471.000000       1471.000000       1471.000000
# mean          -0.614634         -0.515427         -0.607533         -0.639950
# std            0.448480          0.506094          0.424243          0.422994
# min           -0.999717         -0.999873         -1.000000         -0.999867
# 25%           -0.992669         -0.979082         -0.981070         -0.993498
# 50%           -0.952426         -0.867309         -0.869890         -0.958705
# 75%           -0.245405         -0.030639         -0.260223         -0.297260
# max            0.899922          0.782590          0.931308          0.950758
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       1471.000000       1471.000000       1471.000000  ...
# mean          -0.530760         -0.609256         -0.481055  ...
# std            0.489381          0.418536          0.542756  ...
# min           -1.000000         -0.999879         -0.948723  ...
# 25%           -0.979214         -0.980659         -0.936791  ...
# 50%           -0.873891         -0.863451         -0.890491  ...
# 75%           -0.058824         -0.256657         -0.030692  ...
# max            0.602458          0.784041          0.821218  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      1471.000000                      1471.000000
# mean                         -0.311513                        -0.632273
# std                           0.313792                         0.296179
# min                          -0.995357                        -0.994664
# 25%                          -0.546342                        -0.844547
# 50%                          -0.347433                        -0.706699
# 75%                          -0.125796                        -0.516910
# max                           0.941113                         0.894210
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  1471.000000                           1471.000000
# mean                      0.009324                              0.015666
# std                       0.324864                              0.452616
# min                      -0.937468                             -0.990492
# 25%                      -0.119166                             -0.265533
# 50%                       0.005049                              0.023421
# 75%                       0.135698                              0.312690
# max                       0.980889                              0.991899
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       1471.000000                           1471.000000
# mean                           0.006272                             -0.001510
# std                            0.608954                              0.483028
# min                           -0.995222                             -0.969066
# 25%                           -0.485998                             -0.380300
# 50%                           -0.005036                              0.002408
# 75%                            0.518184                              0.374583
# max                            0.994366                              0.979522
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           1471.000000           1471.000000           1471.000000
# mean              -0.481737              0.055771             -0.064194
# std                0.522714              0.298124              0.281645
# min               -0.999380             -0.995073             -1.000000
# 25%               -0.814060             -0.017413             -0.148445
# 50%               -0.708911              0.178814             -0.002243
# 75%               -0.486534              0.248126              0.096674
# max                1.000000              0.432496              0.992766
#
#            subject
# count  1471.000000
# mean     17.539089
# std       9.122876
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# * 세부 요구사항
#     - Label 추가 : 1단계 모델을 위한 레이블 추가
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %% [markdown]
# ### (1) 1단계 모델링을 위한 레이블

# %%
model1_data = data1.copy()
model1_data['is_dynamic'] = model1_data['Activity'].map({'STANDING':0, 'SITTING':0, 'LAYING':0, 'WALKING':1, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':1})

# %% [markdown]
# ### (2) x, y 분리

# %%
target = 'is_dynamic'

model1_x = model1_data.drop(['is_dynamic', 'Activity', 'subject'], axis=1)
model1_y = model1_data.loc[:, target]

# %% [markdown]
# ### (3) 스케일링

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %%
scaler = MinMaxScaler()
model1_x = scaler.fit_transform(model1_x)

# %% [markdown]
# ### (4) 데이터 분할
# * train, val 분할

# %%
model1_x_train, model1_x_val, model1_y_train, model1_y_val = train_test_split(model1_x, model1_y, test_size=.2, random_state = 20)

# %% [markdown]
# ## **3.단계별 모델링**

# %% [markdown]
# ### (1) 단계1

# %% [markdown]
# * 세부 요구사항
#     * 적절한 단계로 구분한 후, 1단계를 분류하는 모델 생성
#         * 예시 : 정적 행동(Laying, Sitting, Standing)과 동적 행동(동적 : Walking, Walking-Up, Walking-Down)을 구분하는 모델 생성.
#     * 몇 가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# #### 1) 모델1

# %%
nfeatures = model1_x_train.shape[1]

# %%
clear_session()
model1 = Sequential([Input(shape = (nfeatures,)),
                     Dense(1, activation= 'sigmoid')])
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │             562 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 562 (2.20 KB)
#  Trainable params: 562 (2.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.compile(optimizer=Adam(learning_rate=0.008), loss='binary_crossentropy', metrics=['accuracy'])
history1 = model1.fit(model1_x_train, model1_y_train, epochs = 30, validation_split=0.2).history
dl_history_plot(history1)
# Out:
# Epoch 1/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9649 - loss: 0.1062 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 2/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 3/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9994 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 4/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9979 - val_loss: 0.0076
# Epoch 5/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 6/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 7/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 7.6680e-04
# Epoch 8/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.9381e-04
# Epoch 9/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.7978e-04
# Epoch 10/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.4913e-04 - val_accuracy: 1.0000 - val_loss: 3.6915e-04
# Epoch 11/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.6374e-04 - val_accuracy: 1.0000 - val_loss: 3.2657e-04
# Epoch 12/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.9225e-04 - val_accuracy: 1.0000 - val_loss: 5.1507e-04
# Epoch 13/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 4.5425e-04 - val_accuracy: 1.0000 - val_loss: 6.2891e-04
# Epoch 14/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.0750e-04 - val_accuracy: 1.0000 - val_loss: 3.3169e-04
# Epoch 15/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.1255e-04 - val_accuracy: 1.0000 - val_loss: 5.4547e-04
# Epoch 16/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.1196e-04 - val_accuracy: 1.0000 - val_loss: 4.0374e-04
# Epoch 17/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.1941e-04 - val_accuracy: 1.0000 - val_loss: 2.6499e-04
# Epoch 18/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2596e-04 - val_accuracy: 1.0000 - val_loss: 4.1543e-04
# Epoch 19/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.4178e-04 - val_accuracy: 1.0000 - val_loss: 3.7512e-04
# Epoch 20/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8581e-04 - val_accuracy: 1.0000 - val_loss: 1.8205e-04
# Epoch 21/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.2545e-04 - val_accuracy: 1.0000 - val_loss: 2.5970e-04
# Epoch 22/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.4787e-04 - val_accuracy: 1.0000 - val_loss: 1.7229e-04
# Epoch 23/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6890e-04 - val_accuracy: 1.0000 - val_loss: 2.1795e-04
# Epoch 24/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.6881e-04 - val_accuracy: 1.0000 - val_loss: 1.3041e-04
# Epoch 25/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.9473e-04 - val_accuracy: 1.0000 - val_loss: 1.2154e-04
# Epoch 26/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.2997e-04 - val_accuracy: 1.0000 - val_loss: 1.6702e-04
# Epoch 27/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4076e-04 - val_accuracy: 1.0000 - val_loss: 1.6696e-04
# Epoch 28/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6176e-04 - val_accuracy: 1.0000 - val_loss: 1.1444e-04
# Epoch 29/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.0368e-04 - val_accuracy: 1.0000 - val_loss: 1.2414e-04
# Epoch 30/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5651e-04 - val_accuracy: 1.0000 - val_loss: 1.0762e-04

# %%
model1_pred1 = model1.predict(model1_x_val)
model1_pred1 = np.where(model1_pred1 >= .5, 1, 0)
print(classification_report(model1_y_val, model1_pred1))
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       627
#            1       1.00      1.00      1.00       550
#
#     accuracy                           1.00      1177
#    macro avg       1.00      1.00      1.00      1177
# weighted avg       1.00      1.00      1.00      1177

# %% [markdown]
# ### (2) 단계2

# %% [markdown]
# #### 1) 단계2-1 : 정적 동작 세부 분류(Laying or (Sitting, Standing))

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동(Laying or (Sitting, Standing))인 데이터 추출
#     * Laying, (Sitting, Standing) 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
static_model_data = model1_data.loc[model1_data['Activity'].isin(['LAYING', 'SITTING', 'STANDING'])].copy()
static_model_data['Activity'] = static_model_data['Activity'].map({'LAYING':0, 'SITTING':1, 'STANDING':1})

static_model_x = static_model_data.drop(['is_dynamic', 'Activity', 'subject'], axis=1)
static_model_y = static_model_data.loc[:, 'Activity']

scaler = MinMaxScaler()
static_model_x = scaler.fit_transform(static_model_x)

# %%
static_model_x_train, static_model_x_val, static_model_y_train, static_model_y_val = train_test_split(static_model_x, static_model_y, test_size=.2, random_state = 20)

# %%
nfeatures = static_model_x_train.shape[1]

clear_session()

model2 = Sequential([
    Input(shape=(nfeatures,)),
    Dense(64, activation='relu'),
    Dropout(0.01),
    Dense(64, activation='relu'),
    Dropout(0.01),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])

model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │          35,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 4)                   │              68 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 42,809 (167.22 KB)
#  Trainable params: 42,809 (167.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model2.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
history2 = model2.fit(static_model_x_train, static_model_y_train, epochs=50, validation_split=.2, callbacks=[]).history
dl_history_plot(history2)
# Out:
# Epoch 1/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6759 - loss: 0.5822 - val_accuracy: 0.9826 - val_loss: 0.0992
# Epoch 2/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9745 - loss: 0.0827 - val_accuracy: 0.9942 - val_loss: 0.0144
# Epoch 3/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9944 - loss: 0.0191 - val_accuracy: 0.9961 - val_loss: 0.0069
# Epoch 4/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9956 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 5/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0062 - val_accuracy: 0.9961 - val_loss: 0.0040
# Epoch 6/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.0079 - val_accuracy: 0.9961 - val_loss: 0.0080
# Epoch 7/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 8/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.5040e-04 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 9/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 8.4132e-04
# Epoch 10/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 5.4100e-04 - val_accuracy: 1.0000 - val_loss: 8.4819e-04
# Epoch 11/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 3.6282e-04 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 12/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 5.8141e-04 - val_accuracy: 1.0000 - val_loss: 3.5850e-04
# Epoch 13/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 8.6712e-04 - val_accuracy: 1.0000 - val_loss: 4.8384e-04
# Epoch 14/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9981 - val_loss: 0.0032
# Epoch 15/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 7.2127e-04 - val_accuracy: 0.9981 - val_loss: 0.0030
# Epoch 16/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.0192e-04 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 17/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.4229e-04 - val_accuracy: 1.0000 - val_loss: 9.2947e-04
# Epoch 18/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 6.4819e-05 - val_accuracy: 1.0000 - val_loss: 5.9394e-04
# Epoch 19/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.5161e-05 - val_accuracy: 1.0000 - val_loss: 7.9209e-04
# Epoch 20/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.0721e-05 - val_accuracy: 1.0000 - val_loss: 5.2403e-04
# Epoch 21/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 1.3268e-04 - val_accuracy: 1.0000 - val_loss: 6.3273e-04
# Epoch 22/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9938 - loss: 0.0241 - val_accuracy: 0.9923 - val_loss: 0.0468
# Epoch 23/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9935 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 8.8277e-04
# Epoch 24/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.8855e-04 - val_accuracy: 1.0000 - val_loss: 5.7192e-04
# Epoch 25/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.1543e-04 - val_accuracy: 1.0000 - val_loss: 2.9165e-04
# Epoch 26/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 5.6457e-05 - val_accuracy: 1.0000 - val_loss: 2.2340e-04
# Epoch 27/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1221e-04 - val_accuracy: 1.0000 - val_loss: 1.9495e-04
# Epoch 28/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.2928e-05 - val_accuracy: 1.0000 - val_loss: 1.2915e-04
# Epoch 29/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 8.6189e-06 - val_accuracy: 1.0000 - val_loss: 1.0812e-04
# Epoch 30/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 9.2407e-06 - val_accuracy: 1.0000 - val_loss: 9.3506e-05
# Epoch 31/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.1621e-05 - val_accuracy: 1.0000 - val_loss: 8.3108e-05
# Epoch 32/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.7273e-05 - val_accuracy: 1.0000 - val_loss: 4.9928e-04
# Epoch 33/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.3765e-05 - val_accuracy: 1.0000 - val_loss: 6.4338e-05
# Epoch 34/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.2142e-06 - val_accuracy: 1.0000 - val_loss: 5.4534e-05
# Epoch 35/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.1819e-06 - val_accuracy: 1.0000 - val_loss: 4.8064e-05
# Epoch 36/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.9042e-06 - val_accuracy: 1.0000 - val_loss: 4.6493e-05
# Epoch 37/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.3282e-05 - val_accuracy: 1.0000 - val_loss: 6.1448e-05
# Epoch 38/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.7163e-06 - val_accuracy: 1.0000 - val_loss: 4.7085e-05
# Epoch 39/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.0026e-06 - val_accuracy: 1.0000 - val_loss: 4.0848e-05
# Epoch 40/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.6341e-06 - val_accuracy: 1.0000 - val_loss: 4.0183e-05
# Epoch 41/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.3849e-06 - val_accuracy: 1.0000 - val_loss: 3.8194e-05
# Epoch 42/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.8281e-06 - val_accuracy: 1.0000 - val_loss: 3.7028e-05
# Epoch 43/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 4.2429e-06 - val_accuracy: 1.0000 - val_loss: 3.9181e-05
# Epoch 44/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.8276e-06 - val_accuracy: 1.0000 - val_loss: 4.1098e-05
# Epoch 45/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.0555e-06 - val_accuracy: 1.0000 - val_loss: 4.1885e-05
# Epoch 46/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.3989e-06 - val_accuracy: 1.0000 - val_loss: 3.5958e-05
# Epoch 47/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.2693e-06 - val_accuracy: 1.0000 - val_loss: 3.1539e-05
# Epoch 48/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.5942e-06 - val_accuracy: 1.0000 - val_loss: 4.2849e-05
# Epoch 49/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.7351e-06 - val_accuracy: 1.0000 - val_loss: 2.4341e-05
# Epoch 50/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.8797e-06 - val_accuracy: 1.0000 - val_loss: 2.7066e-05

# %%
static_model_pred = model2.predict(static_model_x_val)
static_model_pred_1 = np.where(static_model_pred >= .5, 1, 0)
print(confusion_matrix(static_model_y_val, static_model_pred_1))
print(classification_report(static_model_y_val, static_model_pred_1))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [[224   0]
#  [  0 423]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       224
#            1       1.00      1.00      1.00       423
#
#     accuracy                           1.00       647
#    macro avg       1.00      1.00      1.00       647
# weighted avg       1.00      1.00      1.00       647

# %% [markdown]
# #### 1) 단계2-1-2 : 정적 동작 세부 분류2(SITTING, STANDING 구분 모델)

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동에서(Sitting, Standing)인 데이터 추출
#     * Sitting, Standing 를 분류하는 모델을 생성

# %%
static_b_model_data = model1_data.loc[model1_data['Activity'].isin(['SITTING', 'STANDING'])].copy()
static_b_model_data['Activity'] = static_b_model_data['Activity'].map({'SITTING':0, 'STANDING':1})

static_b_model_x = static_b_model_data.drop(['is_dynamic', 'Activity'], axis=1)
static_b_model_x = pd.get_dummies(static_b_model_x, columns=['subject'], dtype = int)
static_b_model_y = static_b_model_data.loc[:, 'Activity']

scaler = MinMaxScaler()
static_b_model_x = scaler.fit_transform(static_b_model_x)

# %%
static_b_model_x_train, static_b_model_x_val, static_b_model_y_train, static_b_model_y_val = train_test_split(static_b_model_x, static_b_model_y, test_size=.2)

# %%
clear_session()
nfeatures = static_b_model_x_train.shape[1]

model3 = Sequential([
    Input(shape=(nfeatures,)),
    Dense(32, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │          18,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,929 (73.94 KB)
#  Trainable params: 18,929 (73.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model3.compile(optimizer=Adam(learning_rate=0.002), loss='binary_crossentropy', metrics=['accuracy'])
history3 = model3.fit(static_b_model_x_train, static_b_model_y_train, epochs = 40, validation_split=0.2).history

dl_history_plot(history3)
# Out:
# Epoch 1/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5595 - loss: 0.6723 - val_accuracy: 0.7935 - val_loss: 0.5594
# Epoch 2/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8217 - loss: 0.5112 - val_accuracy: 0.8938 - val_loss: 0.3685
# Epoch 3/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8992 - loss: 0.3298 - val_accuracy: 0.9115 - val_loss: 0.2564
# Epoch 4/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9342 - loss: 0.2097 - val_accuracy: 0.9558 - val_loss: 0.1836
# Epoch 5/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9551 - loss: 0.1465 - val_accuracy: 0.9558 - val_loss: 0.1572
# Epoch 6/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9522 - loss: 0.1373 - val_accuracy: 0.9617 - val_loss: 0.1349
# Epoch 7/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.1158 - val_accuracy: 0.9440 - val_loss: 0.1540
# Epoch 8/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9636 - loss: 0.1111 - val_accuracy: 0.9735 - val_loss: 0.1045
# Epoch 9/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0856 - val_accuracy: 0.9676 - val_loss: 0.1100
# Epoch 10/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9735 - loss: 0.0844 - val_accuracy: 0.9469 - val_loss: 0.1437
# Epoch 11/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9660 - loss: 0.0819 - val_accuracy: 0.9764 - val_loss: 0.0907
# Epoch 12/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9835 - loss: 0.0645 - val_accuracy: 0.9794 - val_loss: 0.0998
# Epoch 13/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9744 - loss: 0.0768 - val_accuracy: 0.9735 - val_loss: 0.0721
# Epoch 14/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9805 - loss: 0.0534 - val_accuracy: 0.9469 - val_loss: 0.1335
# Epoch 15/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9550 - loss: 0.1002 - val_accuracy: 0.9440 - val_loss: 0.1274
# Epoch 16/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9783 - loss: 0.0547 - val_accuracy: 0.9882 - val_loss: 0.0679
# Epoch 17/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9798 - loss: 0.0566 - val_accuracy: 0.9823 - val_loss: 0.0624
# Epoch 18/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9694 - loss: 0.0747 - val_accuracy: 0.9882 - val_loss: 0.0673
# Epoch 19/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9901 - loss: 0.0401 - val_accuracy: 0.9705 - val_loss: 0.1020
# Epoch 20/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.0581 - val_accuracy: 0.9823 - val_loss: 0.0634
# Epoch 21/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0407 - val_accuracy: 0.9823 - val_loss: 0.0606
# Epoch 22/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9929 - loss: 0.0296 - val_accuracy: 0.9823 - val_loss: 0.0623
# Epoch 23/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9909 - loss: 0.0329 - val_accuracy: 0.9853 - val_loss: 0.0695
# Epoch 24/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9869 - loss: 0.0367 - val_accuracy: 0.9853 - val_loss: 0.0587
# Epoch 25/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9860 - loss: 0.0358 - val_accuracy: 0.9853 - val_loss: 0.0656
# Epoch 26/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.0275 - val_accuracy: 0.9823 - val_loss: 0.0703
# Epoch 27/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9887 - loss: 0.0300 - val_accuracy: 0.9853 - val_loss: 0.0837
# Epoch 28/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9893 - loss: 0.0378 - val_accuracy: 0.9853 - val_loss: 0.0839
# Epoch 29/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9969 - loss: 0.0204 - val_accuracy: 0.9823 - val_loss: 0.0711
# Epoch 30/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9830 - loss: 0.0394 - val_accuracy: 0.9882 - val_loss: 0.0813
# Epoch 31/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9953 - loss: 0.0213 - val_accuracy: 0.9853 - val_loss: 0.0765
# Epoch 32/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9954 - loss: 0.0199 - val_accuracy: 0.9853 - val_loss: 0.0744
# Epoch 33/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9946 - loss: 0.0271 - val_accuracy: 0.9823 - val_loss: 0.0854
# Epoch 34/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9938 - loss: 0.0222 - val_accuracy: 0.9882 - val_loss: 0.0796
# Epoch 35/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0175 - val_accuracy: 0.9882 - val_loss: 0.0804
# Epoch 36/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9949 - loss: 0.0227 - val_accuracy: 0.9764 - val_loss: 0.1039
# Epoch 37/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9892 - loss: 0.0316 - val_accuracy: 0.9882 - val_loss: 0.0823
# Epoch 38/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.0337 - val_accuracy: 0.9676 - val_loss: 0.1252
# Epoch 39/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9882 - loss: 0.0321 - val_accuracy: 0.9764 - val_loss: 0.1045
# Epoch 40/40
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9946 - loss: 0.0190 - val_accuracy: 0.9882 - val_loss: 0.0840

# %%
static_b_model_pred = model3.predict(static_b_model_x_val)
static_b_model_pred = np.where(static_b_model_pred >= .5, 1, 0)
print(classification_report(static_b_model_y_val, static_b_model_pred))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       218
#            1       0.98      0.98      0.98       206
#
#     accuracy                           0.98       424
#    macro avg       0.98      0.98      0.98       424
# weighted avg       0.98      0.98      0.98       424

# %% [markdown]
# #### 2) 단계2-2 : 동적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 동동적 행동(Walking, Walking Upstairs, Walking Downstairs)인 데이터 추출
#     * Walking, Walking Upstairs, Walking Downstairs 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
dynamic_model_data = model1_data.loc[model1_data['Activity'].isin(['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS'])].copy()
dynamic_model_data['Activity'] = dynamic_model_data['Activity'].map({'WALKING':0, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':2})

dynamic_model_x = dynamic_model_data.drop(['is_dynamic', 'Activity', 'subject'], axis=1)
dynamic_model_y = dynamic_model_data.loc[:, 'Activity']

scaler = MinMaxScaler()
dynamic_model_x = scaler.fit_transform(dynamic_model_x)

# %%
dynamic_model_x_train, dynamic_model_x_val, dynamic_model_y_train, dynamic_model_y_val = train_test_split(dynamic_model_x, dynamic_model_y, test_size=.2, random_state = 20)

# %%
nfeatures = dynamic_model_x_train.shape[1]

clear_session()
model4 = Sequential([Input(shape = (nfeatures,)),
                     Dense(3, activation = 'softmax', kernel_regularizer=l2(0.0001))])
model4.summary()

model4.compile(optimizer=Adam(learning_rate=0.01), loss= 'sparse_categorical_crossentropy')
history4 = model4.fit(dynamic_model_x_train, dynamic_model_y_train, epochs = 30, validation_split=0.2).history
dl_history_plot(history4)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 3)                   │           1,686 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,686 (6.59 KB)
#  Trainable params: 1,686 (6.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7309 - val_loss: 0.2407
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1955 - val_loss: 0.1731
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1393 - val_loss: 0.1213
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0994 - val_loss: 0.1086
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0832 - val_loss: 0.0853
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0660 - val_loss: 0.0774
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0677 - val_loss: 0.0735
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0594 - val_loss: 0.0700
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - val_loss: 0.0631
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0450 - val_loss: 0.0942
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - val_loss: 0.0569
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0383 - val_loss: 0.0557
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0391 - val_loss: 0.0518
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0385 - val_loss: 0.0529
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0375 - val_loss: 0.0487
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0362 - val_loss: 0.0463
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0338 - val_loss: 0.0544
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0411 - val_loss: 0.0461
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0308 - val_loss: 0.0445
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0316 - val_loss: 0.0434
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0355 - val_loss: 0.0424
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0316 - val_loss: 0.0479
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0314 - val_loss: 0.0534
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0313 - val_loss: 0.0459
# Epoch 25/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0297 - val_loss: 0.0426
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0273 - val_loss: 0.0419
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0287 - val_loss: 0.0461
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0358 - val_loss: 0.0405
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0283 - val_loss: 0.0395
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0280 - val_loss: 0.0572

# %%
dynamic_model_pred = model4.predict(dynamic_model_x_val)
dynamic_model_pred_1 = dynamic_model_pred.argmax(axis=1)
print(classification_report(dynamic_model_y_val, dynamic_model_pred_1))
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       199
#            1       0.99      0.98      0.99       175
#            2       0.99      0.99      0.99       156
#
#     accuracy                           0.98       530
#    macro avg       0.99      0.98      0.99       530
# weighted avg       0.99      0.98      0.98       530

# %% [markdown]
# ### (3) 분류 모델 파이프라인 구성

# %% [markdown]
# * 세부 요구사항
#     * 두 단계 모델을 통합하고, 새로운 데이터(test)에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
#     * 데이터 파이프라인 구축 : test데이터가 로딩되어 전처리 과정을 거치고, 예측 및 성능 평가 수행

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 1) 함수 만들기

# %%
def model_pipeline(model_data, models=[model1, model2, model3, model4]):
    m_data = model_data.copy()

    t_x2 = model_data.drop(['is_dynamic', 'Activity'], axis=1)
    t_x1 = model_data.drop(['is_dynamic', 'Activity', 'subject'], axis=1)
    t_y1 = model_data.loc[:, 'is_dynamic']
    t_y2 = model_data.loc[:, 'Activity']

    scaler = MinMaxScaler()
    t_x1 = scaler.fit_transform(t_x1)

    pred1 = model1.predict(t_x1)
    pred1 = np.where(pred1 >= .5, 1, 0)

    dynamic_x1 = t_x1[pred1.flatten() == 1]
    dynamic_y1 = t_y2[pred1.flatten() == 1]

    static_x1 = t_x1[pred1.flatten() == 0]
    static_x2 = t_x2[pred1.flatten() == 0]
    static_y1 = t_y2[pred1.flatten() == 0]

    static_pred1 = model2.predict(static_x1)
    static_pred1 = np.where(static_pred1 >= .5, 1, 0)

    static_b_x1 = static_x1[static_pred1.flatten() == 0]
    static_b_x2 = static_x2[static_pred1.flatten() == 1]
    static_b_y1 = static_y1[static_pred1.flatten() == 0]
    static_b_y2 = static_y1[static_pred1.flatten() == 1]


    static_b_pred1_1 = static_pred1[static_pred1.flatten() == 0]
    static_b_x2 = pd.get_dummies(static_b_x2, columns=['subject'], dtype = int)
    static_b_pred1_2 = model3.predict(static_b_x2)
    static_b_pred1_2 = np.where(static_b_pred1_2 >= .5, 2, 1)


    dynamic_pred1 = model4.predict(dynamic_x1)
    dynamic_pred_1 = dynamic_pred1.argmax(axis=1) + 3


    total_pred = np.concatenate((static_b_pred1_1.flatten(), static_b_pred1_2.flatten()), axis=0)
    total_pred = np.concatenate((total_pred, dynamic_pred_1), axis=0)
    total_y1 = pd.concat([static_b_y1, static_b_y2], axis = 0, join = 'outer')
    total_y1 = pd.concat([total_y1, dynamic_y1], axis = 0, join = 'outer')

    print(confusion_matrix(total_pred, total_y1))
    print(classification_report(total_pred, total_y1))

# %%
def data_pipeline(test_data):
    temp = test_data.copy()
    temp['is_dynamic'] = temp['Activity'].map({'STANDING':0, 'SITTING':0, 'LAYING':0, 'WALKING':1, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':1})
    temp['Activity'] = temp['Activity'].map({'LAYING':0, 'SITTING':1, 'STANDING':2, 'WALKING':3, 'WALKING_UPSTAIRS':4, 'WALKING_DOWNSTAIRS':5})

    model_pipeline(temp)

# %% [markdown]
# #### 2) test 셋으로 예측하고 평가하기

# %%
test_data = data2.copy()
data_pipeline(test_data)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[292   0   0   0   0   0]
#  [  0 237  10   0   0   0]
#  [  0  17 277   0   0   0]
#  [  0   0   0 228  15   0]
#  [  0   0   0   0 197   0]
#  [  0   0   0   0   3 195]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       0.93      0.96      0.95       247
#            2       0.97      0.94      0.95       294
#            3       1.00      0.94      0.97       243
#            4       0.92      1.00      0.96       197
#            5       1.00      0.98      0.99       198
#
#     accuracy                           0.97      1471
#    macro avg       0.97      0.97      0.97      1471
# weighted avg       0.97      0.97      0.97      1471
