# %% [markdown]
# # 딥러닝1 : 회귀

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 그래프

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv'
data = pd.read_csv(path)
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# |	변수	|	설명	|
# |	----	|	----	|
# |	medv	|	타운별 집값(중위수)	|
# |	crim	|	범죄율	|
# |	zn	|	25,000 평방피트를 초과 거주지역 비율	|
# |	indus	|	비소매상업지역 면적 비율	|
# |	chas	|	찰스강변 위치(범주 : 강변1, 아니면 0)	|
# |	nox	|	일산화질소 농도	|
# |	rm	|	주택당 방 수	|
# |	age	|	1940년 이전에 건축된 주택의 비율	|
# |	dis	|	직업센터의 거리	|
# |	rad	|	방사형 고속도로까지의 거리	|
# |	tax	|	재산세율	|
# |	ptratio	|	학생/교사 비율	|
# |	lstat	|	인구 중 하위 계층 비율	|

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# lstat, ptratio, crim 만 이용하여 medv를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 데이터 준비
# * x, y 나누기
#     * x : lstat, ptratio, crim
#     * y : medv

# %%
target = 'medv'
features = ['lstat', 'ptratio', 'crim']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) NaN 조치

# %% [markdown]
# ### (3) 가변수화

# %% [markdown]
# ### (4) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# ### (5) Scaling

# %%
# 스케일러 선언
scaler = MinMaxScaler()

# train 셋으로 fitting & 적용
x_train = scaler.fit_transform(x_train)

# validation 셋은 적용만!
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1 : 3개의 feature

# %% [markdown]
# ### (1) 모델설계

# %%
# 분석단위의 shape
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model = Sequential([Input(shape = (nfeatures, )), Dense(1)])

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4 (16.00 B)
#  Trainable params: 4 (16.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile
#     * optimizer = 'adam'    : 기본값으로 옵티마이저 사용(learning_rate = 0.001)
#     * optimizer = Adam(learning_rate = 0.1) : 옵션 값 조정 가능
#         * lr과 learning_rate은 같지만, learning_rate 사용을 권장

# %%
# model.compile(optimizer = 'adam', loss = 'mse')
model.compile(optimizer = Adam(learning_rate=0.1), loss='mse')

# %% [markdown]
# ### (2) 학습

# %% [markdown]
# validation_split=0.2 : 학습시, 학습용 데이터에서 0.2 만큼 떼어 내서 검증셋으로 활용

# %%
history = model.fit(x_train, y_train, epochs = 30, validation_split=0.2).history
# Out:
# Epoch 1/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 583.0583 - val_loss: 543.3409
# Epoch 2/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 466.8690 - val_loss: 469.2823
# Epoch 3/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 398.1001 - val_loss: 406.4664
# Epoch 4/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 316.3081 - val_loss: 355.9408
# Epoch 5/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 284.6498 - val_loss: 315.0804
# Epoch 6/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 281.2558 - val_loss: 282.8866
# Epoch 7/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 218.4156 - val_loss: 258.5030
# Epoch 8/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 233.3128 - val_loss: 238.4093
# Epoch 9/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 217.4734 - val_loss: 223.2992
# Epoch 10/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 162.6193 - val_loss: 211.6290
# Epoch 11/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 168.3202 - val_loss: 201.9970
# Epoch 12/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 175.7750 - val_loss: 194.3861
# Epoch 13/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 148.6752 - val_loss: 188.1736
# Epoch 14/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 155.7591 - val_loss: 182.8080
# Epoch 15/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 133.8575 - val_loss: 177.5271
# Epoch 16/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 137.8798 - val_loss: 172.5952
# Epoch 17/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 143.4001 - val_loss: 168.2678
# Epoch 18/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 133.5877 - val_loss: 164.1170
# Epoch 19/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 143.5720 - val_loss: 160.2835
# Epoch 20/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 128.0906 - val_loss: 156.6293
# Epoch 21/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 140.5958 - val_loss: 153.1165
# Epoch 22/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 136.0578 - val_loss: 149.9607
# Epoch 23/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 109.9392 - val_loss: 147.1417
# Epoch 24/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 115.7426 - val_loss: 144.5194
# Epoch 25/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 119.6548 - val_loss: 141.6754
# Epoch 26/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 114.4533 - val_loss: 138.7013
# Epoch 27/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.5522 - val_loss: 135.8335
# Epoch 28/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 115.8457 - val_loss: 133.1415
# Epoch 29/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 101.4673 - val_loss: 130.6149
# Epoch 30/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 95.1240 - val_loss: 128.1952

# %% [markdown]
# * 학습결과 그래프

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
print(f'RMSE : {mean_squared_error(y_val, pred, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred)}')
# Out:
# RMSE : 22.532660245654444
# MAE  : 21.029733469147313
# MAPE : 0.9670582671474387
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
clear_session()

nfeatures = x_train.shape[1]
nfeatures
# Out:
# 12

# %%
# 모델 선언
model_2 = Sequential([Input(shape=(nfeatures, )), Dense(1)])  # Dense(1) : 출력 노드가 한개
model_2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 1)                   │              13 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile

# %%
# 모델 컴파일
model_2.compile(optimizer = Adam(learning_rate=0.1), loss = 'mse')

# %% [markdown]
# * 학습

# %%
history = model_2.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 49.5624 - val_loss: 48.7436
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.8872 - val_loss: 48.4082
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.8476 - val_loss: 47.0402
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.2400 - val_loss: 45.7916
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.1256 - val_loss: 45.0827
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.5092 - val_loss: 44.3724
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.8008 - val_loss: 43.5919
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.3555 - val_loss: 42.9173
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.5109 - val_loss: 42.4092
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.9813 - val_loss: 41.8329
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.6734 - val_loss: 41.4486
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.4797 - val_loss: 41.3105
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.2849 - val_loss: 39.9603
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.7552 - val_loss: 39.3508
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.1314 - val_loss: 38.8089
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.3064 - val_loss: 38.1483
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.3490 - val_loss: 38.0350
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.8651 - val_loss: 37.8313
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.1323 - val_loss: 37.5019
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.7770 - val_loss: 36.4216
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.4385 - val_loss: 35.7057
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.0917 - val_loss: 35.0012
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.0128 - val_loss: 34.5098
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.2560 - val_loss: 34.4440
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.4663 - val_loss: 34.0955
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.5390 - val_loss: 33.2620
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.1934 - val_loss: 33.0424
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.7415 - val_loss: 32.9280
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.3982 - val_loss: 32.9548
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.7920 - val_loss: 32.7110
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 40.3251 - val_loss: 31.6279
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 38.2212 - val_loss: 31.8698
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.6014 - val_loss: 32.7728
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.7901 - val_loss: 31.7750
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.7539 - val_loss: 30.6699
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.3027 - val_loss: 30.5637
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.0944 - val_loss: 30.6774
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 34.5227 - val_loss: 31.4353
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.8271 - val_loss: 29.5006
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.7922 - val_loss: 29.0367
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.8624 - val_loss: 28.5085
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.1120 - val_loss: 28.1702
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33.2281 - val_loss: 28.5875
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.3271 - val_loss: 28.0488
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.0461 - val_loss: 27.9201
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.4158 - val_loss: 27.7504
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.0100 - val_loss: 27.3674
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.6453 - val_loss: 27.4149
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.2559 - val_loss: 27.1575
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.6427 - val_loss: 26.4461

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 평가

# %%
pred = model_2.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
print(root_mean_squared_error(y_val, pred))
print(mean_absolute_error(y_val, pred))
print(mean_absolute_percentage_error(y_val, pred))
# Out:
# 5.111327566538984
# 4.029857249353447
# 0.20626677290254214

# %% [markdown]
# ## 5.실습!
# * 위 4번에 이어서, 여러분은 다음을 조절할 수 있습니다.
#     * epochs(반복횟수), learning_rate(학습율)
# * 4번 코드를 그대로 보면서 작성하고 위 두가지를 조절하며 성능을 높여봅시다!

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %% [markdown]
# * compile

# %% [markdown]
# * 학습

# %% [markdown]
# * 학습결과 그래프

# %% [markdown]
# * 예측 및 평가

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer!
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 12

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언(입력은 리스트로!)
model3 = Sequential([Input(shape = (nfeatures,)),
                     Dense(2, activation = 'relu'),
                     Dense(1)   ])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 2)                   │              26 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29 (116.00 B)
#  Trainable params: 29 (116.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile

# %%
model3.compile(optimizer= Adam(learning_rate=0.1), loss = 'mse')

# %% [markdown]
# * 학습

# %%
result = model3.fit(x_train, y_train, epochs=50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 601.2888 - val_loss: 376.8949
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 242.9986 - val_loss: 210.0741
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 164.9360 - val_loss: 140.8859
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 111.3680 - val_loss: 110.3026
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 93.9418 - val_loss: 76.6158
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 81.4438 - val_loss: 60.7414
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 68.0231 - val_loss: 57.0425
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.8213 - val_loss: 48.5857
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 58.0482 - val_loss: 43.2049
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.6395 - val_loss: 40.3564
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.9206 - val_loss: 39.0882
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.9351 - val_loss: 36.6269
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 45.2944 - val_loss: 33.3376
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.4600 - val_loss: 32.6482
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.4413 - val_loss: 28.0935
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.1046 - val_loss: 26.2706
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.9916 - val_loss: 26.9795
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.3767 - val_loss: 24.7007
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.1097 - val_loss: 23.5817
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.5065 - val_loss: 22.7315
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.9804 - val_loss: 21.2923
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.7721 - val_loss: 20.4884
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.4951 - val_loss: 20.8719
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.4515 - val_loss: 19.4696
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.4130 - val_loss: 19.0217
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.8538 - val_loss: 19.0515
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.8019 - val_loss: 18.8691
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.5864 - val_loss: 17.6449
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.6556 - val_loss: 20.6746
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.3999 - val_loss: 17.8410
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.0750 - val_loss: 22.4167
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.3373 - val_loss: 18.6379
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.8175 - val_loss: 17.1706
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.7404 - val_loss: 20.1740
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.7498 - val_loss: 17.0948
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.7381 - val_loss: 18.3690
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.1599 - val_loss: 17.9724
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.5457 - val_loss: 17.1471
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.5093 - val_loss: 17.1007
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.3125 - val_loss: 19.2105
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.9130 - val_loss: 16.2148
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.5401 - val_loss: 16.7775
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.4522 - val_loss: 19.6171
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.2736 - val_loss: 16.1833
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.6825 - val_loss: 17.7388
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.1771 - val_loss: 16.0810
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.6735 - val_loss: 17.8585
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.4779 - val_loss: 15.8965
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.7520 - val_loss: 15.6226
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6688 - val_loss: 18.7824

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(result)

# %% [markdown]
# * 예측 및 평가

# %%
pred3 = model3.predict(x_val)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bd978670c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bd978670c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
print(root_mean_squared_error(y_val, pred3))
print(mean_absolute_error(y_val, pred3))
print(mean_absolute_percentage_error(y_val, pred3))
# Out:
# 4.5397127974432
# 3.3725621466543165
# 0.1669002966503861

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 104 |
# | dense_1 (Dense) | (None, 1) | 9 |

# %%
nfeatures = x_train.shape[1]

model4 = Sequential([Input(shape=(nfeatures, )),
                    Dense(8, activation = 'relu'),   # hidden layer
                    Dense(1)])

# %% [markdown]
# * 컴파일 + 학습

# %%
model4.compile(optimizer=Adam(learning_rate=0.01), loss = 'mse')

# %%
result = model4.fit(x_train, y_train, epochs=50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 596.4350 - val_loss: 616.3205
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 562.5896 - val_loss: 546.5406
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 475.1117 - val_loss: 436.0265
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 370.1567 - val_loss: 316.8936
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 253.3579 - val_loss: 227.5885
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 194.0083 - val_loss: 187.7988
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 156.3383 - val_loss: 171.4347
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 139.5367 - val_loss: 154.8569
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 148.9556 - val_loss: 138.3782
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 105.8384 - val_loss: 126.3190
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 110.7234 - val_loss: 113.4633
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 96.0567 - val_loss: 101.7289
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 82.0366 - val_loss: 91.0041
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 72.3005 - val_loss: 81.5202
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.3934 - val_loss: 72.4680
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 73.7478 - val_loss: 66.0988
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.0102 - val_loss: 60.5727
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.5178 - val_loss: 56.5022
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.4305 - val_loss: 53.2851
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.0253 - val_loss: 50.8088
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.6907 - val_loss: 48.7322
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.8509 - val_loss: 46.7068
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 52.0418 - val_loss: 44.5114
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 45.6554 - val_loss: 42.8511
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.5273 - val_loss: 40.8135
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.9126 - val_loss: 39.1887
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.3556 - val_loss: 37.0594
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.9660 - val_loss: 36.0780
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3016 - val_loss: 36.2218
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.6198 - val_loss: 32.0172
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.2019 - val_loss: 30.3444
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.8315 - val_loss: 29.0376
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 39.3953 - val_loss: 28.5748
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.6244 - val_loss: 26.5649
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.0818 - val_loss: 25.0799
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.5119 - val_loss: 23.7700
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.6592 - val_loss: 24.7358
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.7590 - val_loss: 23.5260
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 36.7236 - val_loss: 21.6363
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.8915 - val_loss: 21.7391
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.6238 - val_loss: 21.5028
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.4150 - val_loss: 22.1435
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.3654 - val_loss: 21.1564
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.6873 - val_loss: 19.8175
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.5819 - val_loss: 19.7129
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.3809 - val_loss: 18.9691
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.3533 - val_loss: 18.5883
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.4616 - val_loss: 18.5938
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.4834 - val_loss: 18.7815
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.9512 - val_loss: 16.2815

# %% [markdown]
# * 학습곡선

# %%
dl_history_plot(result)

# %% [markdown]
# * 검증

# %%
pred4 = model.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print(root_mean_squared_error(y_val, pred4))
print(mean_absolute_error(y_val, pred4))
print(mean_absolute_percentage_error(y_val, pred4))
# Out:
# 4.000133371919039
# 2.9655341774809596
# 0.15163498100432976

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 104 | node, input_shape, activation |
# | dense_1 (Dense) | (None, 4) | 36 | node, activation |
# | dense_2 (Dense) | (None, 1) | 5 | node |

# %%
nfeatures = x_train.shape[1]

model5 = Sequential([Input(shape = (nfeatures, )),
                     Dense(8, activation='relu'),
                     Dense(4, activation='relu'),
                     Dense(1)])

# %% [markdown]
# * 컴파일 + 학습

# %%
model5.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# %%
result = model5.fit(x_train, y_train, epochs=50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 591.0347 - val_loss: 647.3688
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 568.4385 - val_loss: 621.0948
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 549.6292 - val_loss: 546.0579
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 452.0203 - val_loss: 405.0975
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 350.2990 - val_loss: 248.8052
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 196.6244 - val_loss: 197.9686
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 152.2570 - val_loss: 183.8263
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 168.4871 - val_loss: 157.6497
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 128.1511 - val_loss: 146.2625
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 128.6513 - val_loss: 129.5533
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 113.8171 - val_loss: 114.3349
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 94.1220 - val_loss: 102.0872
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 84.4671 - val_loss: 92.1412
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 81.6983 - val_loss: 80.9108
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 75.0321 - val_loss: 74.2436
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 71.8763 - val_loss: 68.3608
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 79.8193 - val_loss: 61.7525
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.6480 - val_loss: 58.8815
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.4200 - val_loss: 55.6385
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 55.4398 - val_loss: 53.1227
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.9921 - val_loss: 51.4239
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.7325 - val_loss: 50.0360
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 58.6412 - val_loss: 47.8138
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 66.5939 - val_loss: 45.8455
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.5462 - val_loss: 46.1319
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.1804 - val_loss: 44.0286
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.4989 - val_loss: 42.7792
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 56.3705 - val_loss: 41.1731
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.2247 - val_loss: 39.9517
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 46.5090 - val_loss: 38.3740
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.7023 - val_loss: 36.5997
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.7053 - val_loss: 38.4994
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.8548 - val_loss: 35.7069
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.8193 - val_loss: 33.0258
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.0226 - val_loss: 34.1110
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.6139 - val_loss: 30.2014
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 42.5145 - val_loss: 30.0343
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.0869 - val_loss: 29.0302
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.8917 - val_loss: 28.4083
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.0150 - val_loss: 26.2270
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.4835 - val_loss: 26.7190
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.7313 - val_loss: 26.6298
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.5772 - val_loss: 24.7509
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.4889 - val_loss: 23.8896
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.9032 - val_loss: 23.5613
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3684 - val_loss: 21.3976
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.5903 - val_loss: 20.6234
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8674 - val_loss: 22.2947
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1226 - val_loss: 20.5628
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.0559 - val_loss: 18.9443

# %% [markdown]
# * 학습곡선

# %%
dl_history_plot(result)

# %% [markdown]
# * 검증

# %%
pred5 = model5.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
print(root_mean_squared_error(y_val, pred5))
print(mean_absolute_error(y_val, pred5))
print(mean_absolute_percentage_error(y_val, pred5))
# Out:
# 4.865151284036937
# 3.8358121741051776
# 0.2000399658247537

# %% [markdown]
# * 회귀 모델 예측값 vs 실제값 그래프

# %%
def visualization_result(y_val,pred):
    plt.figure(figsize = (5,5))
    y = x = np.linspace(y_val.min(), y_val.max(), 10)

    y_range = y_val.max() - y_val.min()
    mi, ma = y_val.min() - y_range*0.1 , y_val.max()+ y_range*0.1

    sns.scatterplot(x= pred.reshape(-1), y = y_val.values)
    sns.lineplot(x = x, y = y, color = 'r')
    plt.xlim(mi, ma)
    plt.ylim(mi, ma)
    plt.grid()

    plt.show()

visualization_result(y_val,pred4)

# %%
visualization_result(y_val,pred5)
