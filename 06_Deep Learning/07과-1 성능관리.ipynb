# %% [markdown]
# # **성능관리**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 로딩**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Flatten, Input
from keras.backend import clear_session
from keras.optimizers import Adam
from keras.datasets import mnist

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(2) 데이터로딩**

# %% [markdown]
# * 데이터 로딩
#     * 과적합을 위한 예제 데이터입니다.
#     * target
#     * feature : 0 ~ 299

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/overfit_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0       1 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1       0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2       0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3       1 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4       0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %%
data.shape
# Out:
# (250, 301)

# %% [markdown]
# ## **2. Early Stopping**

# %% [markdown]
# ### **(1) 데이터 준비**

# %%
# 데이터분할 : x, y
target = 'target'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# 데이터분할 : train, validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %%
# 스케일링
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### **(2) 모델링**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history  # verbose = 0 : 성능 로그를 보여주지말라는 뜻

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(3) 미리 멈춤!(Early Stopping)**

# %% [markdown]
# #### 1) 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### 2) 모델링 with early stopping

# %%
# 모델 선언
clear_session()

model2 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )
model2.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# EarlyStopping 설정 ------------
# min_delta 보다 개선이 안 됐으면 patience가 증가한다!!
min_de = 0.005  # 오차(loss)가 0.001이 되면 못참아.
pat = 3         # 5번까지는 오차 올라가는거 봐줄게.

es = EarlyStopping(monitor = 'val_loss', min_delta = min_de, patience = pat)
# --------------------------------

# 학습
hist = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2,
                  callbacks = [es]).history
dl_history_plot(hist)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.7941 - val_loss: 0.5984
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5725 - val_loss: 0.5832
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5778 - val_loss: 0.5844
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5606 - val_loss: 0.5836
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5526 - val_loss: 0.5877

# %%
print(d2_log_loss_score(y_val, model2.predict(x_val)))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# -0.01589138615329766

# %% [markdown]
# ## 3.Dropout

# %%
from keras.layers import Dropout

# %% [markdown]
# ### **(1) 적용 전**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) 적용 후**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model3 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dropout(0.4),
                      Dense(64, activation= 'relu'),
                      Dropout(0.4),
                      Dense(32, activation= 'relu'),
                      Dropout(0.4),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model3.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 4.모델 저장하기

# %% [markdown]
# ### (1) 모델 저장하기
#
# * model.save(‘파일이름.keras’)
#     * 딥러닝 모델의 메소드로 .save가 제공됩니다.
#     * 파일이름.keras 파일이 저장됩니다.

# %%
model1.save('/content/drive/MyDrive/KT AIVLE_딥러닝/iyj.keras')

# %% [markdown]
# * 저장된 파일은 왼쪽 '파일'탭에서 확인 가능
# * 파일을 다운로드 받을 수 있다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### (2) 모델 로딩하기
#
# * load_model 함수는 별도로 불러와야 합니다.
# * 경로를 맞춰주고 h5 파일을 읽어오면 그대로 사용 가능합니다.

# %%
from keras.models import load_model
model2 = load_model('iyj.keras')

# %% [markdown]
# * 불러온 모델 사용하기

# %%
pred2 = model2.predict(x_val)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step

# %%
pred2
# Out:
# array([[7.0624892e-03],
#        [5.4321941e-02],
#        [9.3792802e-01],
#        [1.3537752e-03],
#        [6.6079985e-04],
#        [8.6228067e-01],
#        [3.4379878e-04],
#        [2.1568774e-03],
#        [1.3439793e-03],
#        [9.6624094e-01],
#        [9.3626278e-04],
#        [7.4457104e-04],
#        [1.6090213e-04],
#        [7.2684503e-01],
#        [1.0214199e-03],
#        [7.1025051e-02],
#        [1.2158998e-04],
#        [3.5993748e-03],
#        [4.7250041e-03],
#        [8.5968340e-06],
#        [5.7553422e-01],
#        [2.6431552e-01],
#        [7.4851355e-03],
#        [2.7906218e-01],
#        [9.6605311e-04],
#        [6.8257391e-02],
#        [7.9872198e-03],
#        [3.1940721e-02],
#        [5.0076534e-04],
#        [2.8140238e-03],
#        [2.4917573e-01],
#        [1.0282602e-03],
#        [4.5260493e-04],
#        [8.3945405e-01],
#        [3.4894291e-04],
#        [3.8765278e-04],
#        [2.5378159e-04],
#        [2.0404414e-03],
#        [4.7012982e-03],
#        [2.1536963e-01],
#        [2.7335405e-03],
#        [9.6609753e-01],
#        [9.9808854e-01],
#        [3.4886023e-05],
#        [6.0038400e-01],
#        [1.6471516e-01],
#        [9.0893867e-05],
#        [1.6692322e-03],
#        [3.6985538e-04],
#        [6.8318812e-05]], dtype=float32)

# %%
pred2_1 = np.where(pred2> .5, 1, 0)

# %%
print(accuracy_score(y_val,pred2_1))
print('-'*60)
print(confusion_matrix(y_val, pred2_1))
print('-'*60)
print(classification_report(y_val, pred2_1))
# Out:
# 0.68
# ------------------------------------------------------------
# [[30  5]
#  [11  4]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79        35
#            1       0.44      0.27      0.33        15
#
#     accuracy                           0.68        50
#    macro avg       0.59      0.56      0.56        50
# weighted avg       0.65      0.68      0.65        50

# %% [markdown]
# ### (3) 중간 체크포인트에 모델 저장하기

# %% [markdown]
# * 폴더 정리 : 위에서 저장한 파일들 제거하기

# %%
import os

def delete_h5_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".keras"):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# 삭제할 디렉토리 지정
directory_to_delete_from = "/content/"

# 확장자가 .h5인 파일 삭제
delete_h5_files(directory_to_delete_from)
# Out:
# Deleted: /content/iyj.keras

# %% [markdown]
# #### 1) 체크포인트 함수 불러오기

# %%
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### 2) 모델링 체크포인트 저장

# %% [markdown]
# * 모델 선언

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(16, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.0001), loss='binary_crossentropy')

# %% [markdown]
# * 체크포인트 저장
#     * 아래 코드에서 ModelCheckpoint 콜백은 검증 데이터의 정확도(val_accuracy)를 기준으로 모델 저장
#     * 모델의 성능이 이전에 저장된 모델보다 향상될 때만 저장되도록 save_best_only=True로 설정
#     * 또한, verbose=1로 설정하면 모델이 저장될 때마다 콘솔에 메시지가 표시됨.

# %%
cp_path = '/content/{epoch:03d}.keras'  # Keras 2.11 이상 버전에서 모델 확장자 .keras
mcp = ModelCheckpoint(cp_path, monitor='val_loss', verbose = 1, save_best_only=True)

# 학습
hist = model1.fit(x_train, y_train, epochs = 50, validation_split=.2, callbacks=[mcp]).history
# Out:
# Epoch 1/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 0.8131
# Epoch 1: val_loss improved from inf to 0.70048, saving model to /content/001.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.7636 - val_loss: 0.7005
# Epoch 2/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.7052
# Epoch 2: val_loss improved from 0.70048 to 0.65541, saving model to /content/002.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6898 - val_loss: 0.6554
# Epoch 3/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.6442
# Epoch 3: val_loss improved from 0.65541 to 0.62611, saving model to /content/003.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6399 - val_loss: 0.6261
# Epoch 4/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.5568
# Epoch 4: val_loss improved from 0.62611 to 0.61084, saving model to /content/004.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5955 - val_loss: 0.6108
# Epoch 5/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.6312
# Epoch 5: val_loss improved from 0.61084 to 0.60223, saving model to /content/005.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5963 - val_loss: 0.6022
# Epoch 6/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6310
# Epoch 6: val_loss improved from 0.60223 to 0.59833, saving model to /content/006.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5887 - val_loss: 0.5983
# Epoch 7/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.5714
# Epoch 7: val_loss improved from 0.59833 to 0.59713, saving model to /content/007.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5804 - val_loss: 0.5971
# Epoch 8/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6232
# Epoch 8: val_loss improved from 0.59713 to 0.59711, saving model to /content/008.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5921 - val_loss: 0.5971
# Epoch 9/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5852
# Epoch 9: val_loss did not improve from 0.59711
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5721 - val_loss: 0.5971
# Epoch 10/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.4542
# Epoch 10: val_loss did not improve from 0.59711
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5393 - val_loss: 0.5975
# Epoch 11/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6088
# Epoch 11: val_loss did not improve from 0.59711
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5913 - val_loss: 0.5974
# Epoch 12/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6191
# Epoch 12: val_loss did not improve from 0.59711
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5707 - val_loss: 0.5974
# Epoch 13/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4596
# Epoch 13: val_loss did not improve from 0.59711
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5245 - val_loss: 0.5978
# Epoch 14/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5057
# Epoch 14: val_loss did not improve from 0.59711
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5497 - val_loss: 0.5973
# Epoch 15/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5025
# Epoch 15: val_loss improved from 0.59711 to 0.59704, saving model to /content/015.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5433 - val_loss: 0.5970
# Epoch 16/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.5013
# Epoch 16: val_loss improved from 0.59704 to 0.59668, saving model to /content/016.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5371 - val_loss: 0.5967
# Epoch 17/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4989
# Epoch 17: val_loss improved from 0.59668 to 0.59652, saving model to /content/017.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5285 - val_loss: 0.5965
# Epoch 18/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5670
# Epoch 18: val_loss did not improve from 0.59652
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5453 - val_loss: 0.5966
# Epoch 19/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6015
# Epoch 19: val_loss improved from 0.59652 to 0.59606, saving model to /content/019.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5681 - val_loss: 0.5961
# Epoch 20/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5640
# Epoch 20: val_loss improved from 0.59606 to 0.59601, saving model to /content/020.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5653 - val_loss: 0.5960
# Epoch 21/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6276
# Epoch 21: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5647 - val_loss: 0.5962
# Epoch 22/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4858
# Epoch 22: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5379 - val_loss: 0.5964
# Epoch 23/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.5854
# Epoch 23: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5649 - val_loss: 0.5963
# Epoch 24/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5654
# Epoch 24: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5436 - val_loss: 0.5966
# Epoch 25/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5635
# Epoch 25: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5381 - val_loss: 0.5969
# Epoch 26/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5734
# Epoch 26: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5526 - val_loss: 0.5969
# Epoch 27/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5782
# Epoch 27: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5378 - val_loss: 0.5971
# Epoch 28/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6457
# Epoch 28: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5733 - val_loss: 0.5969
# Epoch 29/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4965
# Epoch 29: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5281 - val_loss: 0.5974
# Epoch 30/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.5061
# Epoch 30: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5387 - val_loss: 0.5975
# Epoch 31/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.6379
# Epoch 31: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5714 - val_loss: 0.5974
# Epoch 32/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.4704
# Epoch 32: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5290 - val_loss: 0.5979
# Epoch 33/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5972
# Epoch 33: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5553 - val_loss: 0.5979
# Epoch 34/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.5769
# Epoch 34: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5338 - val_loss: 0.5984
# Epoch 35/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5331
# Epoch 35: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5419 - val_loss: 0.5984
# Epoch 36/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4830
# Epoch 36: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5143 - val_loss: 0.5988
# Epoch 37/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.7428
# Epoch 37: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5854 - val_loss: 0.5986
# Epoch 38/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4728
# Epoch 38: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5313 - val_loss: 0.5991
# Epoch 39/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5221
# Epoch 39: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5258 - val_loss: 0.5997
# Epoch 40/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4122
# Epoch 40: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5059 - val_loss: 0.6001
# Epoch 41/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5091
# Epoch 41: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5260 - val_loss: 0.5997
# Epoch 42/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4163
# Epoch 42: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4991 - val_loss: 0.6004
# Epoch 43/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4459
# Epoch 43: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5302 - val_loss: 0.5996
# Epoch 44/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.5714
# Epoch 44: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5463 - val_loss: 0.5993
# Epoch 45/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5735
# Epoch 45: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5449 - val_loss: 0.5995
# Epoch 46/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5873
# Epoch 46: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5565 - val_loss: 0.5995
# Epoch 47/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4960
# Epoch 47: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5195 - val_loss: 0.6005
# Epoch 48/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5752
# Epoch 48: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5317 - val_loss: 0.6004
# Epoch 49/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5808
# Epoch 49: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5289 - val_loss: 0.6003
# Epoch 50/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5416
# Epoch 50: val_loss did not improve from 0.59601
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5306 - val_loss: 0.6001

# %%
# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## **5.[참조]가중치 규제(Regularization)**

# %%
# 규제를 위해 필요한 함수 불러오기
from keras.regularizers import l1, l2

# %% [markdown]
# ### **(1) L1 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model4 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model4.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model4.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) L2 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model5 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model5.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model5.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)
