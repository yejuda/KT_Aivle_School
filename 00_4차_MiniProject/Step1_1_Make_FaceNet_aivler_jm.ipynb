# %% [markdown]
# # **Make Pretrained-Model FaceNet !**

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (3) 미션3
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project4'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install keras-nightly
# Out:
# Collecting keras-nightly
#   Downloading keras_nightly-3.7.0.dev2024103103-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras-nightly) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)
# Downloading keras_nightly-3.7.0.dev2024103103-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: keras-nightly
# Successfully installed keras-nightly-3.7.0.dev2024103103

# %% [markdown]
# ## 3.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 데이터셋은 두 개의 압축 파일이어야 합니다.
#             1. lfw-deepfunneled.zip : Labeled Faces in the Wild 데이터셋
#             2. 여러분의 얼굴 이미지 데이터셋
#                 - 여러분의 얼굴 이미지가 담긴 **압축 파일**을 **Google Drive에 업로드** 하기를 권장합니다.
#                     - 이미지 파일 하나하나 업로드 하면 시간이 오래 걸립니다.
#     - 데이터셋 압축 파일을 **Colab에 폴더를 생성한 후 해제**하세요.
#         - 데이터셋 폴더를 **본인 얼굴 폴더, LFW 폴더로 나누어** 생성하는 것을 권장합니다.
#         - 만일 두 압축 파일을 하나의 폴더에 모두 해제하면 전처리가 더 까다로워질 것입니다.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %% [markdown]
# #### 1) 본인 얼굴 이미지 데이터셋 불러오기

# %%
import os
import zipfile

# %%
data_myFace = path + '/Keras/ms_face_images_D.zip'
data_myFace
# Out:
# '/content/drive/MyDrive/project4/Keras/ms_face_images_B.zip'

# %%
## Colab에 생성할 본인 얼굴 폴더 경로
extract_folder = '/content/my_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_myFace, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 본인 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 5436

# %% [markdown]
# #### 2) 다른 얼굴 이미지 데이터셋 불러오기

# %%
data_other = path + '/Keras/lfw-deepfunneled.zip'
data_other
# Out:
# '/content/drive/MyDrive/project4/Keras/crop.zip'

# %%
## Colab에 생성할 다른 얼굴 폴더 경로
extract_folder = '/content/other_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_other, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 다른 사람 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 13353

# %% [markdown]
# ### (2) 데이터셋 전처리
# * **세부 요구사항**
#     - 데이터셋을 전처리 합니다.
#         - Training set, Validation set, Test set으로 데이터셋을 나누어 주세요.
#             - 학습 과정에서 Training set, Validation set을 사용해야 합니다.
#             - 추론 과정에서 Test set을 사용해야 합니다.
#         - Keras의 **특정 함수**가 실제 존재하는 이미지 파일에 대한 전처리를 쉽게 도와줍니다.
#         - **특정 함수**에서 요구하는 폴더 구조가 있습니다. **특정 함수**를 사용한다면 이에 맞춰서 폴더를 생성해야 합니다.
#         - 각 데이터셋에 스케일링도 적용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - glob, random, shutil, numpy, keras

# %% [markdown]
# #### 1) 데이터셋 분할

# %%
import glob
import random
import shutil
import numpy as np

from keras.utils import load_img, img_to_array
from keras.utils import image_dataset_from_directory

# %%
## image_dataset_from_directory를 사용하기 위해 Colab에 폴더 생성

## 생성될 폴더의 경로
tr_data = '/content/tr_data'
te_data = '/content/te_data'

## 폴더가 존재하지 않을 때 폴더를 생성
if not os.path.exists(tr_data) :
    os.makedirs(tr_data)

if not os.path.exists(te_data) :
    os.makedirs(te_data)

## 폴더 생성 확인
print(os.path.exists(tr_data) )
print(os.path.exists(te_data) )
# Out:
# True
# True

# %%
## Keras의 image_dataset_from_directory를 사용하기 위해 Colab에 하위 폴더 생성

## 생성될 폴더에 대한 하위 폴더 생성
class_names = ['my', 'other']

for cn in class_names :
    temp = os.path.join(tr_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))

for cn in class_names :
    temp = os.path.join(te_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))
# Out:
# True
# True
# True
# True

# %%
## 본인 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_my = sorted(glob.glob('/content/my_face/*',))

## 다른 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_other = sorted(glob.glob('/content/other_face/*'))

## 이미지 갯수 확인
len(img_list_my), len(img_list_other)
# Out:
# (5436, 13353)

# %%
## 얼굴 데이터를 Training set, Test set으로 분할하기 위한 사전 작업
## 분할 재현성을 위한 난수 고정
random.seed(2024)
random.shuffle(img_list_my)
random.shuffle(img_list_other)

img_list_my[:5], img_list_other[:5]
# Out:
# (['/content/my_face/jn_face_79.jpg',
#   '/content/my_face/img_2070_0.jpg',
#   '/content/my_face/jn_face_207.jpg',
#   '/content/my_face/jn_face_2821.jpg',
#   '/content/my_face/img_1081_0.jpg'],
#  ['/content/other_face/00097A03_face0.jpg',
#   '/content/other_face/05284A40_face0.jpg',
#   '/content/other_face/11952A49_face0.jpg',
#   '/content/other_face/01616A22_face0.jpg',
#   '/content/other_face/12646A59_face0.jpg'])

# %%
## Test set의 비율 설정
test_size = 0.2

## 나의 얼굴 파일 리스트와 다른 얼굴 파일 리스트에 대한 반복문
for i_l in [img_list_my, img_list_other] :
    ## 리스트의 길이 체크
    list_len = 8400  ## 예시 파일의 이미지 갯수가 맞지 않아서 5400개까지만 사용
    ## 데이터 분할을 위한 인덱스 설정
    split_idx = int(list_len * (1 - test_size) )

    ## 인덱스를 이용해 상위 리스트를 Training set, Test set 2가지로 세분화
    list_tr = i_l[ : split_idx]
    list_te = i_l[split_idx : list_len]

    ## 현재 리스트가 나의 얼굴 파일 리스트와 같다면
    if i_l == img_list_my :
        ## "나의 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "나의 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

    ## 현재 리스트가 "나의 얼굴 파일 리스트"가 아니라면 (즉, "다른 사람 얼굴 파일 리스트"라면)
    else :
        ## "다른 사람 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/other/'+f_name[-1],
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "다른 사람 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/other/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')
# Out:
# Streaming output truncated to the last 5000 lines.
# 파일 이동 완료 : 00977A16_face0.jpg
# 파일 이동 완료 : 07150A70_face0.jpg
# 파일 이동 완료 : 09230A29_face0.jpg
# 파일 이동 완료 : 12945A66_face0.jpg
# 파일 이동 완료 : 05531A42_face0.jpg
# 파일 이동 완료 : 10596A36_face0.jpg
# 파일 이동 완료 : 08353A19_face0.jpg
# 파일 이동 완료 : 01051A17_face0.jpg
# 파일 이동 완료 : 00485A09_face0.jpg
# 파일 이동 완료 : 10655A37_face0.jpg
# 파일 이동 완료 : 05925A46_face0.jpg
# 파일 이동 완료 : 00087A03_face0.jpg
# 파일 이동 완료 : 09412A29_face0.jpg
# 파일 이동 완료 : 12251A53_face0.jpg
# 파일 이동 완료 : 03300A29_face0.jpg
# 파일 이동 완료 : 10952A39_face0.jpg
# 파일 이동 완료 : 11179A41_face0.jpg
# 파일 이동 완료 : 05198A40_face0.jpg
# 파일 이동 완료 : 12988A68_face0.jpg
# 파일 이동 완료 : 12369A55_face0.jpg
# 파일 이동 완료 : 05983A46_face0.jpg
# 파일 이동 완료 : 05940A46_face0.jpg
# 파일 이동 완료 : 01213A19_face0.jpg
# 파일 이동 완료 : 10139A33_face0.jpg
# 파일 이동 완료 : 05817A45_face0.jpg
# 파일 이동 완료 : 02299A26_face0.jpg
# 파일 이동 완료 : 10124A33_face0.jpg
# 파일 이동 완료 : 07026A66_face0.jpg
# 파일 이동 완료 : 07871A09_face0.jpg
# 파일 이동 완료 : 01333A20_face0.jpg
# 파일 이동 완료 : 11428A43_face0.jpg
# 파일 이동 완료 : 07104A68_face0.jpg
# 파일 이동 완료 : 01084A18_face0.jpg
# 파일 이동 완료 : 13223A77_face0.jpg
# 파일 이동 완료 : 10497A36_face0.jpg
# 파일 이동 완료 : 11763A46_face0.jpg
# 파일 이동 완료 : 07502A03_face0.jpg
# 파일 이동 완료 : 07536A04_face0.jpg
# 파일 이동 완료 : 05192A40_face0.jpg
# 파일 이동 완료 : 05041A39_face0.jpg
# 파일 이동 완료 : 03887A32_face0.jpg
# 파일 이동 완료 : 12286A54_face1.jpg
# 파일 이동 완료 : 03350A29_face0.jpg
# 파일 이동 완료 : 05220A40_face0.jpg
# 파일 이동 완료 : 10059A33_face0.jpg
# 파일 이동 완료 : 03677A31_face0.jpg
# 파일 이동 완료 : 04224A34_face0.jpg
# 파일 이동 완료 : 08803A25_face0.jpg
# 파일 이동 완료 : 00052A02_face0.jpg
# 파일 이동 완료 : 01360A20_face0.jpg
# 파일 이동 완료 : 11621A45_face0.jpg
# 파일 이동 완료 : 04974A38_face0.jpg
# 파일 이동 완료 : 05571A42_face0.jpg
# 파일 이동 완료 : 02491A26_face0.jpg
# 파일 이동 완료 : 05785A44_face0.jpg
# 파일 이동 완료 : 10961A39_face0.jpg
# 파일 이동 완료 : 07628A06_face0.jpg
# 파일 이동 완료 : 01567A22_face0.jpg
# 파일 이동 완료 : 08018A12_face0.jpg
# 파일 이동 완료 : 09200A28_face0.jpg
# 파일 이동 완료 : 00800A14_face1.jpg
# 파일 이동 완료 : 06329A51_face0.jpg
# 파일 이동 완료 : 10208A34_face0.jpg
# 파일 이동 완료 : 10575A36_face0.jpg
# 파일 이동 완료 : 11752A46_face0.jpg
# 파일 이동 완료 : 08699A24_face0.jpg
# 파일 이동 완료 : 06770A60_face0.jpg
# 파일 이동 완료 : 09787A32_face0.jpg
# 파일 이동 완료 : 00152A03_face0.jpg
# 파일 이동 완료 : 08691A24_face0.jpg
# 파일 이동 완료 : 05466A42_face0.jpg
# 파일 이동 완료 : 02695A27_face0.jpg
# 파일 이동 완료 : 00237A05_face0.jpg
# 파일 이동 완료 : 02284A26_face0.jpg
# 파일 이동 완료 : 08126A14_face0.jpg
# 파일 이동 완료 : 05066A39_face0.jpg
# 파일 이동 완료 : 07177A71_face1.jpg
# 파일 이동 완료 : 12468A56_face0.jpg
# 파일 이동 완료 : 10121A33_face0.jpg
# 파일 이동 완료 : 07047A67_face0.jpg
# 파일 이동 완료 : 00341A06_face0.jpg
# 파일 이동 완료 : 02145A25_face0.jpg
# 파일 이동 완료 : 10253A34_face0.jpg
# 파일 이동 완료 : 08514A22_face0.jpg
# 파일 이동 완료 : 07651A06_face0.jpg
# 파일 이동 완료 : 05418A41_face0.jpg
# 파일 이동 완료 : 02222A26_face0.jpg
# 파일 이동 완료 : 06895A62_face0.jpg
# 파일 이동 완료 : 09048A27_face0.jpg
# 파일 이동 완료 : 03851A32_face0.jpg
# 파일 이동 완료 : 03852A32_face0.jpg
# 파일 이동 완료 : 00882A15_face0.jpg
# 파일 이동 완료 : 12702A60_face0.jpg
# 파일 이동 완료 : 06810A60_face0.jpg
# 파일 이동 완료 : 09032A27_face0.jpg
# 파일 이동 완료 : 09343A29_face0.jpg
# 파일 이동 완료 : 09104A28_face0.jpg
# 파일 이동 완료 : 07028A66_face0.jpg
# 파일 이동 완료 : 02546A27_face0.jpg
# 파일 이동 완료 : 06072A47_face0.jpg
# 파일 이동 완료 : 10310A34_face0.jpg
# 파일 이동 완료 : 08615A23_face0.jpg
# 파일 이동 완료 : 08650A23_face0.jpg
# 파일 이동 완료 : 09634A31_face0.jpg
# 파일 이동 완료 : 06925A63_face0.jpg
# 파일 이동 완료 : 12697A60_face0.jpg
# 파일 이동 완료 : 04669A36_face0.jpg
# 파일 이동 완료 : 11797A47_face0.jpg
# 파일 이동 완료 : 12258A53_face0.jpg
# 파일 이동 완료 : 10511A36_face0.jpg
# 파일 이동 완료 : 09161A28_face0.jpg
# 파일 이동 완료 : 06291A50_face0.jpg
# 파일 이동 완료 : 02015A24_face0.jpg
# 파일 이동 완료 : 04730A36_face0.jpg
# 파일 이동 완료 : 12261A53_face0.jpg
# 파일 이동 완료 : 08867A26_face0.jpg
# 파일 이동 완료 : 06607A56_face0.jpg
# 파일 이동 완료 : 01540A22_face0.jpg
# 파일 이동 완료 : 04849A37_face1.jpg
# 파일 이동 완료 : 03739A31_face0.jpg
# 파일 이동 완료 : 08493A22_face0.jpg
# 파일 이동 완료 : 01206A19_face0.jpg
# 파일 이동 완료 : 05157A39_face1.jpg
# 파일 이동 완료 : 04401A35_face0.jpg
# 파일 이동 완료 : 08603A23_face0.jpg
# 파일 이동 완료 : 00407A07_face0.jpg
# 파일 이동 완료 : 05445A41_face0.jpg
# 파일 이동 완료 : 08445A20_face0.jpg
# 파일 이동 완료 : 08428A20_face0.jpg
# 파일 이동 완료 : 02226A26_face0.jpg
# 파일 이동 완료 : 00712A12_face0.jpg
# 파일 이동 완료 : 05132A39_face0.jpg
# 파일 이동 완료 : 12398A55_face0.jpg
# 파일 이동 완료 : 04971A38_face0.jpg
# 파일 이동 완료 : 05692A43_face0.jpg
# 파일 이동 완료 : 11356A42_face0.jpg
# 파일 이동 완료 : 01248A19_face0.jpg
# 파일 이동 완료 : 10174A34_face0.jpg
# 파일 이동 완료 : 11841A47_face0.jpg
# 파일 이동 완료 : 06686A58_face0.jpg
# 파일 이동 완료 : 03155A29_face0.jpg
# 파일 이동 완료 : 03822A32_face0.jpg
# 파일 이동 완료 : 07552A04_face0.jpg
# 파일 이동 완료 : 08973A27_face0.jpg
# 파일 이동 완료 : 10081A33_face0.jpg
# 파일 이동 완료 : 13197A76_face0.jpg
# 파일 이동 완료 : 03963A32_face0.jpg
# 파일 이동 완료 : 04529A35_face0.jpg
# 파일 이동 완료 : 03931A32_face0.jpg
# 파일 이동 완료 : 09004A27_face0.jpg
# 파일 이동 완료 : 00041A02_face0.jpg
# 파일 이동 완료 : 08553A22_face0.jpg
# 파일 이동 완료 : 08836A25_face0.jpg
# 파일 이동 완료 : 00696A12_face0.jpg
# 파일 이동 완료 : 01312A20_face0.jpg
# 파일 이동 완료 : 11133A40_face0.jpg
# 파일 이동 완료 : 07626A06_face0.jpg
# 파일 이동 완료 : 12544A57_face0.jpg
# 파일 이동 완료 : 01197A19_face0.jpg
# 파일 이동 완료 : 13060A71_face0.jpg
# 파일 이동 완료 : 11508A44_face0.jpg
# 파일 이동 완료 : 03269A29_face0.jpg
# 파일 이동 완료 : 05630A43_face0.jpg
# 파일 이동 완료 : 11116A40_face0.jpg
# 파일 이동 완료 : 09749A32_face0.jpg
# 파일 이동 완료 : 04781A37_face0.jpg
# 파일 이동 완료 : 12812A63_face0.jpg
# 파일 이동 완료 : 08632A23_face0.jpg
# 파일 이동 완료 : 02088A25_face0.jpg
# 파일 이동 완료 : 09717A31_face0.jpg
# 파일 이동 완료 : 12067A50_face0.jpg
# 파일 이동 완료 : 12109A51_face0.jpg
# 파일 이동 완료 : 00230A05_face0.jpg
# 파일 이동 완료 : 00724A13_face0.jpg
# 파일 이동 완료 : 06363A52_face0.jpg
# 파일 이동 완료 : 09939A33_face0.jpg
# 파일 이동 완료 : 02515A26_face0.jpg
# 파일 이동 완료 : 07368A80_face0.jpg
# 파일 이동 완료 : 06397A52_face0.jpg
# 파일 이동 완료 : 03567A30_face0.jpg
# 파일 이동 완료 : 12010A49_face0.jpg
# 파일 이동 완료 : 01901A24_face0.jpg
# 파일 이동 완료 : 06147A48_face0.jpg
# 파일 이동 완료 : 08956A27_face0.jpg
# 파일 이동 완료 : 08147A15_face0.jpg
# 파일 이동 완료 : 08750A25_face0.jpg
# 파일 이동 완료 : 06355A51_face0.jpg
# 파일 이동 완료 : 12433A56_face0.jpg
# 파일 이동 완료 : 01093A18_face0.jpg
# 파일 이동 완료 : 08356A19_face0.jpg
# 파일 이동 완료 : 06983A65_face0.jpg
# 파일 이동 완료 : 05425A41_face0.jpg
# 파일 이동 완료 : 01986A24_face0.jpg
# 파일 이동 완료 : 03591A31_face0.jpg
# 파일 이동 완료 : 02522A26_face0.jpg
# 파일 이동 완료 : 05236A40_face0.jpg
# 파일 이동 완료 : 03466A30_face0.jpg
# 파일 이동 완료 : 06358A51_face0.jpg
# 파일 이동 완료 : 03484A30_face0.jpg
# 파일 이동 완료 : 09462A30_face0.jpg
# 파일 이동 완료 : 10893A38_face0.jpg
# 파일 이동 완료 : 10181A34_face0.jpg
# 파일 이동 완료 : 04623A36_face0.jpg
# 파일 이동 완료 : 03694A31_face0.jpg
# 파일 이동 완료 : 04862A37_face0.jpg
# 파일 이동 완료 : 12224A53_face0.jpg
# 파일 이동 완료 : 01766A23_face0.jpg
# 파일 이동 완료 : 01826A24_face0.jpg
# 파일 이동 완료 : 10881A38_face0.jpg
# 파일 이동 완료 : 10821A37_face0.jpg
# 파일 이동 완료 : 02069A25_face0.jpg
# 파일 이동 완료 : 00316A06_face0.jpg
# 파일 이동 완료 : 06003A46_face0.jpg
# 파일 이동 완료 : 01448A21_face0.jpg
# 파일 이동 완료 : 02590A27_face0.jpg
# 파일 이동 완료 : 12935A66_face0.jpg
# 파일 이동 완료 : 08885A26_face0.jpg
# 파일 이동 완료 : 09320A29_face0.jpg
# 파일 이동 완료 : 02991A28_face0.jpg
# 파일 이동 완료 : 06856A61_face0.jpg
# 파일 이동 완료 : 08343A18_face1.jpg
# 파일 이동 완료 : 07448A02_face0.jpg
# 파일 이동 완료 : 12279A53_face0.jpg
# 파일 이동 완료 : 08069A13_face0.jpg
# 파일 이동 완료 : 12565A57_face0.jpg
# 파일 이동 완료 : 12847A63_face0.jpg
# 파일 이동 완료 : 03980A32_face0.jpg
# 파일 이동 완료 : 04665A36_face0.jpg
# 파일 이동 완료 : 00595A10_face0.jpg
# 파일 이동 완료 : 01026A17_face0.jpg
# 파일 이동 완료 : 00971A16_face0.jpg
# 파일 이동 완료 : 05677A43_face0.jpg
# 파일 이동 완료 : 10448A35_face0.jpg
# 파일 이동 완료 : 09793A32_face0.jpg
# 파일 이동 완료 : 06748A59_face0.jpg
# 파일 이동 완료 : 10070A33_face0.jpg
# 파일 이동 완료 : 09251A29_face0.jpg
# 파일 이동 완료 : 09920A32_face0.jpg
# 파일 이동 완료 : 00151A03_face0.jpg
# 파일 이동 완료 : 05000A38_face0.jpg
# 파일 이동 완료 : 04773A37_face0.jpg
# 파일 이동 완료 : 13166A75_face0.jpg
# 파일 이동 완료 : 07485A03_face0.jpg
# 파일 이동 완료 : 06444A53_face0.jpg
# 파일 이동 완료 : 08421A20_face0.jpg
# 파일 이동 완료 : 05058A39_face0.jpg
# 파일 이동 완료 : 00419A08_face0.jpg
# 파일 이동 완료 : 08905A26_face0.jpg
# 파일 이동 완료 : 04768A37_face0.jpg
# 파일 이동 완료 : 09536A30_face0.jpg
# 파일 이동 완료 : 02237A26_face0.jpg
# 파일 이동 완료 : 10405A35_face0.jpg
# 파일 이동 완료 : 09457A30_face0.jpg
# 파일 이동 완료 : 02498A26_face0.jpg
# 파일 이동 완료 : 11084A40_face0.jpg
# 파일 이동 완료 : 08131A14_face0.jpg
# 파일 이동 완료 : 01706A23_face0.jpg
# 파일 이동 완료 : 02932A28_face0.jpg
# 파일 이동 완료 : 03682A31_face0.jpg
# 파일 이동 완료 : 04407A35_face0.jpg
# 파일 이동 완료 : 02335A26_face0.jpg
# 파일 이동 완료 : 07650A06_face0.jpg
# 파일 이동 완료 : 04806A37_face0.jpg
# 파일 이동 완료 : 11461A43_face0.jpg
# 파일 이동 완료 : 02836A27_face0.jpg
# 파일 이동 완료 : 11740A46_face0.jpg
# 파일 이동 완료 : 13204A76_face0.jpg
# 파일 이동 완료 : 06908A63_face0.jpg
# 파일 이동 완료 : 01748A23_face0.jpg
# 파일 이동 완료 : 10023A33_face0.jpg
# 파일 이동 완료 : 10401A35_face0.jpg
# 파일 이동 완료 : 09977A33_face0.jpg
# 파일 이동 완료 : 05686A43_face0.jpg
# 파일 이동 완료 : 09505A30_face0.jpg
# 파일 이동 완료 : 12373A55_face0.jpg
# 파일 이동 완료 : 06915A63_face1.jpg
# 파일 이동 완료 : 00498A09_face0.jpg
# 파일 이동 완료 : 11938A48_face0.jpg
# 파일 이동 완료 : 09144A28_face0.jpg
# 파일 이동 완료 : 04893A37_face0.jpg
# 파일 이동 완료 : 05568A42_face0.jpg
# 파일 이동 완료 : 03146A29_face0.jpg
# 파일 이동 완료 : 00860A14_face0.jpg
# 파일 이동 완료 : 07600A05_face1.jpg
# 파일 이동 완료 : 03601A31_face0.jpg
# 파일 이동 완료 : 11415A43_face0.jpg
# 파일 이동 완료 : 08056A13_face0.jpg
# 파일 이동 완료 : 11343A42_face0.jpg
# 파일 이동 완료 : 03641A31_face0.jpg
# 파일 이동 완료 : 02377A26_face0.jpg
# 파일 이동 완료 : 11598A45_face0.jpg
# 파일 이동 완료 : 02232A26_face0.jpg
# 파일 이동 완료 : 04258A34_face0.jpg
# 파일 이동 완료 : 03549A30_face0.jpg
# 파일 이동 완료 : 06338A51_face0.jpg
# 파일 이동 완료 : 06315A51_face0.jpg
# 파일 이동 완료 : 01979A24_face0.jpg
# 파일 이동 완료 : 04225A34_face0.jpg
# 파일 이동 완료 : 12146A51_face0.jpg
# 파일 이동 완료 : 04651A36_face0.jpg
# 파일 이동 완료 : 09112A28_face0.jpg
# 파일 이동 완료 : 07459A02_face0.jpg
# 파일 이동 완료 : 06421A53_face0.jpg
# 파일 이동 완료 : 06598A56_face1.jpg
# 파일 이동 완료 : 11191A41_face0.jpg
# 파일 이동 완료 : 08333A18_face0.jpg
# 파일 이동 완료 : 11147A40_face0.jpg
# 파일 이동 완료 : 06767A60_face0.jpg
# 파일 이동 완료 : 09103A28_face0.jpg
# 파일 이동 완료 : 00957A16_face0.jpg
# 파일 이동 완료 : 05114A39_face0.jpg
# 파일 이동 완료 : 08766A25_face0.jpg
# 파일 이동 완료 : 06933A63_face0.jpg
# 파일 이동 완료 : 09905A32_face0.jpg
# 파일 이동 완료 : 11902A48_face0.jpg
# 파일 이동 완료 : 04420A35_face0.jpg
# 파일 이동 완료 : 11131A40_face0.jpg
# 파일 이동 완료 : 01665A23_face0.jpg
# 파일 이동 완료 : 02681A27_face1.jpg
# 파일 이동 완료 : 07714A07_face0.jpg
# 파일 이동 완료 : 00009A02_face0.jpg
# 파일 이동 완료 : 02089A25_face0.jpg
# 파일 이동 완료 : 12586A58_face0.jpg
# 파일 이동 완료 : 01279A20_face0.jpg
# 파일 이동 완료 : 05422A41_face0.jpg
# 파일 이동 완료 : 02728A27_face0.jpg
# 파일 이동 완료 : 06816A60_face0.jpg
# 파일 이동 완료 : 08394A19_face0.jpg
# 파일 이동 완료 : 01421A21_face0.jpg
# 파일 이동 완료 : 02764A27_face0.jpg
# 파일 이동 완료 : 03259A29_face0.jpg
# 파일 이동 완료 : 00508A09_face0.jpg
# 파일 이동 완료 : 12117A51_face0.jpg
# 파일 이동 완료 : 11846A47_face0.jpg
# 파일 이동 완료 : 06217A49_face0.jpg
# 파일 이동 완료 : 13195A76_face0.jpg
# 파일 이동 완료 : 08137A14_face0.jpg
# 파일 이동 완료 : 11497A44_face0.jpg
# 파일 이동 완료 : 02951A28_face0.jpg
# 파일 이동 완료 : 02923A28_face0.jpg
# 파일 이동 완료 : 05343A41_face0.jpg
# 파일 이동 완료 : 09540A30_face0.jpg
# 파일 이동 완료 : 01950A24_face0.jpg
# 파일 이동 완료 : 08189A15_face0.jpg
# 파일 이동 완료 : 04045A33_face0.jpg
# 파일 이동 완료 : 06283A50_face0.jpg
# 파일 이동 완료 : 00868A15_face1.jpg
# 파일 이동 완료 : 00777A13_face0.jpg
# 파일 이동 완료 : 05987A46_face0.jpg
# 파일 이동 완료 : 01644A22_face0.jpg
# 파일 이동 완료 : 07011A66_face0.jpg
# 파일 이동 완료 : 08093A13_face0.jpg
# 파일 이동 완료 : 09081A28_face0.jpg
# 파일 이동 완료 : 03040A28_face0.jpg
# 파일 이동 완료 : 04976A38_face0.jpg
# 파일 이동 완료 : 03469A30_face0.jpg
# 파일 이동 완료 : 10577A36_face0.jpg
# 파일 이동 완료 : 07398A02_face0.jpg
# 파일 이동 완료 : 08678A24_face0.jpg
# 파일 이동 완료 : 09615A31_face0.jpg
# 파일 이동 완료 : 09735A32_face0.jpg
# 파일 이동 완료 : 04428A35_face0.jpg
# 파일 이동 완료 : 09503A30_face0.jpg
# 파일 이동 완료 : 07923A11_face0.jpg
# 파일 이동 완료 : 07036A67_face0.jpg
# 파일 이동 완료 : 05579A42_face0.jpg
# 파일 이동 완료 : 13234A77_face0.jpg
# 파일 이동 완료 : 04797A37_face0.jpg
# 파일 이동 완료 : 05854A45_face0.jpg
# 파일 이동 완료 : 11863A47_face0.jpg
# 파일 이동 완료 : 03877A32_face0.jpg
# 파일 이동 완료 : 10404A35_face0.jpg
# 파일 이동 완료 : 03771A32_face0.jpg
# 파일 이동 완료 : 05476A42_face0.jpg
# 파일 이동 완료 : 01681A23_face0.jpg
# 파일 이동 완료 : 03681A31_face0.jpg
# 파일 이동 완료 : 02198A25_face0.jpg
# 파일 이동 완료 : 05749A44_face0.jpg
# 파일 이동 완료 : 11364A42_face0.jpg
# 파일 이동 완료 : 00535A09_face0.jpg
# 파일 이동 완료 : 09193A28_face0.jpg
# 파일 이동 완료 : 00817A14_face0.jpg
# 파일 이동 완료 : 01012A17_face0.jpg
# 파일 이동 완료 : 10873A38_face0.jpg
# 파일 이동 완료 : 04222A34_face0.jpg
# 파일 이동 완료 : 00624A11_face1.jpg
# 파일 이동 완료 : 08037A12_face0.jpg
# 파일 이동 완료 : 12556A57_face0.jpg
# 파일 이동 완료 : 12316A54_face0.jpg
# 파일 이동 완료 : 05176A40_face0.jpg
# 파일 이동 완료 : 10053A33_face0.jpg
# 파일 이동 완료 : 03022A28_face0.jpg
# 파일 이동 완료 : 01593A22_face0.jpg
# 파일 이동 완료 : 05959A46_face0.jpg
# 파일 이동 완료 : 00017A02_face0.jpg
# 파일 이동 완료 : 11540A44_face0.jpg
# 파일 이동 완료 : 09446A30_face0.jpg
# 파일 이동 완료 : 09378A29_face0.jpg
# 파일 이동 완료 : 11012A39_face0.jpg
# 파일 이동 완료 : 10990A39_face0.jpg
# 파일 이동 완료 : 00898A15_face0.jpg
# 파일 이동 완료 : 01411A21_face0.jpg
# 파일 이동 완료 : 02565A27_face0.jpg
# 파일 이동 완료 : 04909A38_face0.jpg
# 파일 이동 완료 : 06618A56_face0.jpg
# 파일 이동 완료 : 04082A33_face0.jpg
# 파일 이동 완료 : 13000A68_face0.jpg
# 파일 이동 완료 : 09122A28_face0.jpg
# 파일 이동 완료 : 00672A12_face0.jpg
# 파일 이동 완료 : 00059A02_face0.jpg
# 파일 이동 완료 : 05362A41_face0.jpg
# 파일 이동 완료 : 08473A21_face0.jpg
# 파일 이동 완료 : 00533A09_face0.jpg
# 파일 이동 완료 : 03004A28_face0.jpg
# 파일 이동 완료 : 11672A45_face0.jpg
# 파일 이동 완료 : 03723A31_face0.jpg
# 파일 이동 완료 : 07657A06_face0.jpg
# 파일 이동 완료 : 06170A49_face0.jpg
# 파일 이동 완료 : 04391A35_face0.jpg
# 파일 이동 완료 : 08063A13_face0.jpg
# 파일 이동 완료 : 02803A27_face0.jpg
# 파일 이동 완료 : 04593A36_face0.jpg
# 파일 이동 완료 : 06420A53_face0.jpg
# 파일 이동 완료 : 09351A29_face0.jpg
# 파일 이동 완료 : 02420A26_face0.jpg
# 파일 이동 완료 : 05321A41_face0.jpg
# 파일 이동 완료 : 11075A40_face0.jpg
# 파일 이동 완료 : 12795A62_face0.jpg
# 파일 이동 완료 : 09166A28_face0.jpg
# 파일 이동 완료 : 08095A13_face0.jpg
# 파일 이동 완료 : 05325A41_face0.jpg
# 파일 이동 완료 : 09274A29_face0.jpg
# 파일 이동 완료 : 13168A75_face0.jpg
# 파일 이동 완료 : 03331A29_face0.jpg
# 파일 이동 완료 : 04009A33_face0.jpg
# 파일 이동 완료 : 12250A53_face0.jpg
# 파일 이동 완료 : 07438A02_face0.jpg
# 파일 이동 완료 : 03680A31_face0.jpg
# 파일 이동 완료 : 04999A38_face0.jpg
# 파일 이동 완료 : 05174A40_face0.jpg
# 파일 이동 완료 : 05173A40_face0.jpg
# 파일 이동 완료 : 09510A30_face0.jpg
# 파일 이동 완료 : 09050A27_face0.jpg
# 파일 이동 완료 : 02862A27_face0.jpg
# 파일 이동 완료 : 00470A08_face0.jpg
# 파일 이동 완료 : 03921A32_face0.jpg
# 파일 이동 완료 : 10271A34_face0.jpg
# 파일 이동 완료 : 11851A47_face0.jpg
# 파일 이동 완료 : 12841A63_face0.jpg
# 파일 이동 완료 : 09030A27_face0.jpg
# 파일 이동 완료 : 03908A32_face0.jpg
# 파일 이동 완료 : 10726A37_face0.jpg
# 파일 이동 완료 : 07170A70_face0.jpg
# 파일 이동 완료 : 07863A09_face0.jpg
# 파일 이동 완료 : 09924A32_face0.jpg
# 파일 이동 완료 : 12832A63_face0.jpg
# 파일 이동 완료 : 01575A22_face0.jpg
# 파일 이동 완료 : 01430A21_face0.jpg
# 파일 이동 완료 : 07594A05_face0.jpg
# 파일 이동 완료 : 09434A30_face1.jpg
# 파일 이동 완료 : 06675A58_face0.jpg
# 파일 이동 완료 : 04658A36_face0.jpg
# 파일 이동 완료 : 09600A31_face0.jpg
# 파일 이동 완료 : 02682A27_face0.jpg
# 파일 이동 완료 : 12031A49_face0.jpg
# 파일 이동 완료 : 11156A41_face0.jpg
# 파일 이동 완료 : 06720A59_face0.jpg
# 파일 이동 완료 : 05369A41_face0.jpg
# 파일 이동 완료 : 07171A70_face0.jpg
# 파일 이동 완료 : 01973A24_face0.jpg
# 파일 이동 완료 : 06395A52_face0.jpg
# 파일 이동 완료 : 02612A27_face0.jpg
# 파일 이동 완료 : 06541A55_face1.jpg
# 파일 이동 완료 : 12712A60_face0.jpg
# 파일 이동 완료 : 00703A12_face0.jpg
# 파일 이동 완료 : 00976A16_face0.jpg
# 파일 이동 완료 : 12596A58_face0.jpg
# 파일 이동 완료 : 00159A04_face0.jpg
# 파일 이동 완료 : 09179A28_face0.jpg
# 파일 이동 완료 : 11950A49_face0.jpg
# 파일 이동 완료 : 01944A24_face0.jpg
# 파일 이동 완료 : 09268A29_face0.jpg
# 파일 이동 완료 : 09713A31_face0.jpg
# 파일 이동 완료 : 11173A41_face0.jpg
# 파일 이동 완료 : 01661A22_face0.jpg
# 파일 이동 완료 : 03246A29_face0.jpg
# 파일 이동 완료 : 12573A57_face0.jpg
# 파일 이동 완료 : 11656A45_face0.jpg
# 파일 이동 완료 : 09077A28_face0.jpg
# 파일 이동 완료 : 07052A67_face0.jpg
# 파일 이동 완료 : 13308A80_face0.jpg
# 파일 이동 완료 : 03032A28_face0.jpg
# 파일 이동 완료 : 02545A27_face0.jpg
# 파일 이동 완료 : 03780A32_face1.jpg
# 파일 이동 완료 : 06206A49_face0.jpg
# 파일 이동 완료 : 01582A22_face0.jpg
# 파일 이동 완료 : 07225A73_face0.jpg
# 파일 이동 완료 : 06446A53_face0.jpg
# 파일 이동 완료 : 00856A14_face0.jpg
# 파일 이동 완료 : 01036A17_face0.jpg
# 파일 이동 완료 : 07001A66_face0.jpg
# 파일 이동 완료 : 02771A27_face1.jpg
# 파일 이동 완료 : 02610A27_face0.jpg
# 파일 이동 완료 : 12831A63_face0.jpg
# 파일 이동 완료 : 06773A60_face0.jpg
# 파일 이동 완료 : 05729A44_face0.jpg
# 파일 이동 완료 : 08466A21_face0.jpg
# 파일 이동 완료 : 11036A39_face0.jpg
# 파일 이동 완료 : 02686A27_face0.jpg
# 파일 이동 완료 : 06758A59_face0.jpg
# 파일 이동 완료 : 05275A40_face0.jpg
# 파일 이동 완료 : 11874A48_face0.jpg
# 파일 이동 완료 : 05052A39_face0.jpg
# 파일 이동 완료 : 07851A09_face0.jpg
# 파일 이동 완료 : 07569A05_face0.jpg
# 파일 이동 완료 : 12088A51_face0.jpg
# 파일 이동 완료 : 11661A45_face0.jpg
# 파일 이동 완료 : 01669A23_face0.jpg
# 파일 이동 완료 : 05967A46_face0.jpg
# 파일 이동 완료 : 11109A40_face0.jpg
# 파일 이동 완료 : 04605A36_face0.jpg
# 파일 이동 완료 : 06492A54_face0.jpg
# 파일 이동 완료 : 03104A28_face0.jpg
# 파일 이동 완료 : 10890A38_face0.jpg
# 파일 이동 완료 : 11650A45_face0.jpg
# 파일 이동 완료 : 01032A17_face0.jpg
# 파일 이동 완료 : 07978A12_face0.jpg
# 파일 이동 완료 : 03871A32_face0.jpg
# 파일 이동 완료 : 11139A40_face0.jpg
# 파일 이동 완료 : 13055A70_face0.jpg
# 파일 이동 완료 : 02303A26_face0.jpg
# 파일 이동 완료 : 09480A30_face0.jpg
# 파일 이동 완료 : 08425A20_face0.jpg
# 파일 이동 완료 : 11272A41_face0.jpg
# 파일 이동 완료 : 03626A31_face0.jpg
# 파일 이동 완료 : 06598A56_face0.jpg
# 파일 이동 완료 : 12983A68_face0.jpg
# 파일 이동 완료 : 04830A37_face0.jpg
# 파일 이동 완료 : 05226A40_face0.jpg
# 파일 이동 완료 : 04883A37_face0.jpg
# 파일 이동 완료 : 10260A34_face1.jpg
# 파일 이동 완료 : 07775A08_face0.jpg
# 파일 이동 완료 : 05833A45_face0.jpg
# 파일 이동 완료 : 12671A59_face0.jpg
# 파일 이동 완료 : 12465A56_face0.jpg
# 파일 이동 완료 : 11896A48_face0.jpg
# 파일 이동 완료 : 06534A55_face0.jpg
# 파일 이동 완료 : 01751A23_face0.jpg
# 파일 이동 완료 : 06526A55_face0.jpg
# 파일 이동 완료 : 08290A18_face0.jpg
# 파일 이동 완료 : 05590A42_face0.jpg
# 파일 이동 완료 : 00940A16_face0.jpg
# 파일 이동 완료 : 01024A17_face0.jpg
# 파일 이동 완료 : 01746A23_face0.jpg
# 파일 이동 완료 : 03621A31_face0.jpg
# 파일 이동 완료 : 05021A38_face0.jpg
# 파일 이동 완료 : 07846A09_face0.jpg
# 파일 이동 완료 : 00834A14_face0.jpg
# 파일 이동 완료 : 02722A27_face0.jpg
# 파일 이동 완료 : 06163A49_face0.jpg
# 파일 이동 완료 : 06280A50_face0.jpg
# 파일 이동 완료 : 08035A12_face0.jpg
# 파일 이동 완료 : 03302A29_face0.jpg
# 파일 이동 완료 : 04313A34_face0.jpg
# 파일 이동 완료 : 09157A28_face0.jpg
# 파일 이동 완료 : 12715A60_face0.jpg
# 파일 이동 완료 : 10262A34_face0.jpg
# 파일 이동 완료 : 02985A28_face0.jpg
# 파일 이동 완료 : 05719A43_face0.jpg
# 파일 이동 완료 : 08987A27_face0.jpg
# 파일 이동 완료 : 00446A08_face0.jpg
# 파일 이동 완료 : 05782A44_face0.jpg
# 파일 이동 완료 : 11222A41_face0.jpg
# 파일 이동 완료 : 07895A10_face1.jpg
# 파일 이동 완료 : 11711A46_face0.jpg
# 파일 이동 완료 : 03421A30_face0.jpg
# 파일 이동 완료 : 10272A34_face0.jpg
# 파일 이동 완료 : 05728A44_face0.jpg
# 파일 이동 완료 : 00513A09_face0.jpg
# 파일 이동 완료 : 10800A37_face0.jpg
# 파일 이동 완료 : 04855A37_face0.jpg
# 파일 이동 완료 : 13174A75_face0.jpg
# 파일 이동 완료 : 06954A64_face0.jpg
# 파일 이동 완료 : 06940A64_face0.jpg
# 파일 이동 완료 : 12366A55_face0.jpg
# 파일 이동 완료 : 12047A50_face0.jpg
# 파일 이동 완료 : 06374A52_face0.jpg
# 파일 이동 완료 : 13175A75_face0.jpg
# 파일 이동 완료 : 10813A37_face0.jpg
# 파일 이동 완료 : 05843A45_face0.jpg
# 파일 이동 완료 : 05936A46_face0.jpg
# 파일 이동 완료 : 05714A43_face0.jpg
# 파일 이동 완료 : 10474A35_face0.jpg
# 파일 이동 완료 : 00271A05_face0.jpg
# 파일 이동 완료 : 11641A45_face0.jpg
# 파일 이동 완료 : 03737A31_face0.jpg
# 파일 이동 완료 : 08019A12_face0.jpg
# 파일 이동 완료 : 08138A14_face0.jpg
# 파일 이동 완료 : 00326A06_face0.jpg
# 파일 이동 완료 : 01830A24_face0.jpg
# 파일 이동 완료 : 02101A25_face0.jpg
# 파일 이동 완료 : 09100A28_face0.jpg
# 파일 이동 완료 : 10159A34_face0.jpg
# 파일 이동 완료 : 10868A38_face0.jpg
# 파일 이동 완료 : 08952A27_face0.jpg
# 파일 이동 완료 : 00055A02_face0.jpg
# 파일 이동 완료 : 01001A17_face0.jpg
# 파일 이동 완료 : 02663A27_face0.jpg
# 파일 이동 완료 : 13084A72_face0.jpg
# 파일 이동 완료 : 12555A57_face0.jpg
# 파일 이동 완료 : 04398A35_face0.jpg
# 파일 이동 완료 : 07056A67_face0.jpg
# 파일 이동 완료 : 08863A26_face0.jpg
# 파일 이동 완료 : 02519A26_face0.jpg
# 파일 이동 완료 : 00820A14_face0.jpg
# 파일 이동 완료 : 09283A29_face0.jpg
# 파일 이동 완료 : 11464A43_face0.jpg
# 파일 이동 완료 : 04203A34_face0.jpg
# 파일 이동 완료 : 12350A54_face0.jpg
# 파일 이동 완료 : 03923A32_face0.jpg
# 파일 이동 완료 : 13312A80_face0.jpg
# 파일 이동 완료 : 13011A69_face0.jpg
# 파일 이동 완료 : 05027A39_face0.jpg
# 파일 이동 완료 : 03715A31_face0.jpg
# 파일 이동 완료 : 12048A50_face0.jpg
# 파일 이동 완료 : 00501A09_face0.jpg
# 파일 이동 완료 : 02710A27_face0.jpg
# 파일 이동 완료 : 02643A27_face0.jpg
# 파일 이동 완료 : 09681A31_face0.jpg
# 파일 이동 완료 : 05217A40_face0.jpg
# 파일 이동 완료 : 03647A31_face0.jpg
# 파일 이동 완료 : 00042A02_face0.jpg
# 파일 이동 완료 : 02354A26_face0.jpg
# 파일 이동 완료 : 09327A29_face0.jpg
# 파일 이동 완료 : 10632A36_face0.jpg
# 파일 이동 완료 : 07976A12_face0.jpg
# 파일 이동 완료 : 10100A33_face0.jpg
# 파일 이동 완료 : 08195A16_face0.jpg
# 파일 이동 완료 : 00100A03_face0.jpg
# 파일 이동 완료 : 00158A04_face0.jpg
# 파일 이동 완료 : 07108A69_face0.jpg
# 파일 이동 완료 : 01650A22_face0.jpg
# 파일 이동 완료 : 00523A09_face0.jpg
# 파일 이동 완료 : 00392A07_face0.jpg
# 파일 이동 완료 : 12628A59_face0.jpg
# 파일 이동 완료 : 01285A20_face0.jpg
# 파일 이동 완료 : 01126A18_face0.jpg
# 파일 이동 완료 : 00124A03_face0.jpg
# 파일 이동 완료 : 05676A43_face0.jpg
# 파일 이동 완료 : 04394A35_face0.jpg
# 파일 이동 완료 : 09655A31_face0.jpg
# 파일 이동 완료 : 04913A38_face0.jpg
# 파일 이동 완료 : 02658A27_face0.jpg
# 파일 이동 완료 : 02953A28_face0.jpg
# 파일 이동 완료 : 12293A54_face0.jpg
# 파일 이동 완료 : 08003A12_face0.jpg
# 파일 이동 완료 : 00144A03_face0.jpg
# 파일 이동 완료 : 07121A69_face0.jpg
# 파일 이동 완료 : 07686A06_face0.jpg
# 파일 이동 완료 : 01522A21_face0.jpg
# 파일 이동 완료 : 10187A34_face0.jpg
# 파일 이동 완료 : 01158A18_face0.jpg
# 파일 이동 완료 : 07790A08_face0.jpg
# 파일 이동 완료 : 03330A29_face0.jpg
# 파일 이동 완료 : 08542A22_face0.jpg
# 파일 이동 완료 : 12460A56_face0.jpg
# 파일 이동 완료 : 09009A27_face0.jpg
# 파일 이동 완료 : 10619A36_face0.jpg
# 파일 이동 완료 : 09700A31_face0.jpg
# 파일 이동 완료 : 11423A43_face0.jpg
# 파일 이동 완료 : 00706A12_face0.jpg
# 파일 이동 완료 : 08177A15_face0.jpg
# 파일 이동 완료 : 06479A54_face0.jpg
# 파일 이동 완료 : 07287A77_face0.jpg
# 파일 이동 완료 : 07911A10_face1.jpg
# 파일 이동 완료 : 03561A30_face0.jpg
# 파일 이동 완료 : 02706A27_face0.jpg
# 파일 이동 완료 : 10943A38_face0.jpg
# 파일 이동 완료 : 00391A07_face0.jpg
# 파일 이동 완료 : 09860A32_face0.jpg
# 파일 이동 완료 : 08992A27_face0.jpg
# 파일 이동 완료 : 08030A12_face0.jpg
# 파일 이동 완료 : 08881A26_face0.jpg
# 파일 이동 완료 : 09732A32_face0.jpg
# 파일 이동 완료 : 02685A27_face0.jpg
# 파일 이동 완료 : 11494A44_face0.jpg
# 파일 이동 완료 : 08321A18_face0.jpg
# 파일 이동 완료 : 11426A43_face0.jpg
# 파일 이동 완료 : 04975A38_face0.jpg
# 파일 이동 완료 : 04013A33_face0.jpg
# 파일 이동 완료 : 12700A60_face0.jpg
# 파일 이동 완료 : 09159A28_face0.jpg
# 파일 이동 완료 : 10996A39_face0.jpg
# 파일 이동 완료 : 01771A23_face0.jpg
# 파일 이동 완료 : 12445A56_face0.jpg
# 파일 이동 완료 : 09602A31_face0.jpg
# 파일 이동 완료 : 12698A60_face0.jpg
# 파일 이동 완료 : 01657A22_face0.jpg
# 파일 이동 완료 : 10720A37_face0.jpg
# 파일 이동 완료 : 12259A53_face0.jpg
# 파일 이동 완료 : 07116A69_face0.jpg
# 파일 이동 완료 : 08048A13_face0.jpg
# 파일 이동 완료 : 00379A07_face0.jpg
# 파일 이동 완료 : 05085A39_face0.jpg
# 파일 이동 완료 : 07717A07_face0.jpg
# 파일 이동 완료 : 12148A51_face0.jpg
# 파일 이동 완료 : 01812A23_face0.jpg
# 파일 이동 완료 : 02031A25_face0.jpg
# 파일 이동 완료 : 11956A49_face0.jpg
# 파일 이동 완료 : 11340A42_face0.jpg
# 파일 이동 완료 : 08960A27_face0.jpg
# 파일 이동 완료 : 13238A78_face0.jpg
# 파일 이동 완료 : 03316A29_face0.jpg
# 파일 이동 완료 : 06567A56_face0.jpg
# 파일 이동 완료 : 06684A58_face0.jpg
# 파일 이동 완료 : 02358A26_face0.jpg
# 파일 이동 완료 : 03505A30_face0.jpg
# 파일 이동 완료 : 11725A46_face0.jpg
# 파일 이동 완료 : 02945A28_face0.jpg
# 파일 이동 완료 : 00217A04_face0.jpg
# 파일 이동 완료 : 09683A31_face0.jpg
# 파일 이동 완료 : 12420A55_face0.jpg
# 파일 이동 완료 : 02462A26_face0.jpg
# 파일 이동 완료 : 07418A02_face0.jpg
# 파일 이동 완료 : 07605A05_face0.jpg
# 파일 이동 완료 : 11346A42_face0.jpg
# 파일 이동 완료 : 10501A36_face0.jpg
# 파일 이동 완료 : 05760A44_face0.jpg
# 파일 이동 완료 : 09996A33_face0.jpg
# 파일 이동 완료 : 03247A29_face0.jpg
# 파일 이동 완료 : 12057A50_face0.jpg
# 파일 이동 완료 : 09492A30_face0.jpg
# 파일 이동 완료 : 08617A23_face0.jpg
# 파일 이동 완료 : 06286A50_face0.jpg
# 파일 이동 완료 : 05401A41_face0.jpg
# 파일 이동 완료 : 01141A18_face0.jpg
# 파일 이동 완료 : 10175A34_face0.jpg
# 파일 이동 완료 : 00205A04_face0.jpg
# 파일 이동 완료 : 00011A02_face0.jpg
# 파일 이동 완료 : 06764A60_face0.jpg
# 파일 이동 완료 : 08720A24_face0.jpg
# 파일 이동 완료 : 07793A08_face0.jpg
# 파일 이동 완료 : 04192A33_face0.jpg
# 파일 이동 완료 : 05144A39_face0.jpg
# 파일 이동 완료 : 00732A13_face0.jpg
# 파일 이동 완료 : 11900A48_face0.jpg
# 파일 이동 완료 : 09330A29_face0.jpg
# 파일 이동 완료 : 07123A69_face0.jpg
# 파일 이동 완료 : 09560A31_face0.jpg
# 파일 이동 완료 : 03676A31_face0.jpg
# 파일 이동 완료 : 05644A43_face0.jpg
# 파일 이동 완료 : 02821A27_face0.jpg
# 파일 이동 완료 : 09708A31_face0.jpg
# 파일 이동 완료 : 06466A54_face0.jpg
# 파일 이동 완료 : 12347A54_face0.jpg
# 파일 이동 완료 : 10878A38_face0.jpg
# 파일 이동 완료 : 04659A36_face1.jpg
# 파일 이동 완료 : 10125A33_face0.jpg
# 파일 이동 완료 : 12133A51_face0.jpg
# 파일 이동 완료 : 10017A33_face0.jpg
# 파일 이동 완료 : 00397A07_face0.jpg
# 파일 이동 완료 : 07803A08_face0.jpg
# 파일 이동 완료 : 11209A41_face0.jpg
# 파일 이동 완료 : 08587A23_face0.jpg
# 파일 이동 완료 : 05029A39_face0.jpg
# 파일 이동 완료 : 01968A24_face0.jpg
# 파일 이동 완료 : 10040A33_face0.jpg
# 파일 이동 완료 : 06573A56_face0.jpg
# 파일 이동 완료 : 12637A59_face0.jpg
# 파일 이동 완료 : 03077A28_face0.jpg
# 파일 이동 완료 : 06352A51_face0.jpg
# 파일 이동 완료 : 05637A43_face0.jpg
# 파일 이동 완료 : 12904A65_face0.jpg
# 파일 이동 완료 : 00650A11_face0.jpg
# 파일 이동 완료 : 11534A44_face0.jpg
# 파일 이동 완료 : 02194A25_face0.jpg
# 파일 이동 완료 : 00212A04_face0.jpg
# 파일 이동 완료 : 03338A29_face0.jpg
# 파일 이동 완료 : 00131A03_face0.jpg
# 파일 이동 완료 : 03917A32_face0.jpg
# 파일 이동 완료 : 07053A67_face1.jpg
# 파일 이동 완료 : 09186A28_face0.jpg
# 파일 이동 완료 : 12343A54_face0.jpg
# 파일 이동 완료 : 04733A36_face0.jpg
# 파일 이동 완료 : 06644A57_face0.jpg
# 파일 이동 완료 : 01059A17_face0.jpg
# 파일 이동 완료 : 11349A42_face0.jpg
# 파일 이동 완료 : 04933A38_face0.jpg
# 파일 이동 완료 : 02514A26_face0.jpg
# 파일 이동 완료 : 10946A38_face0.jpg
# 파일 이동 완료 : 04522A35_face0.jpg
# 파일 이동 완료 : 00225A05_face0.jpg
# 파일 이동 완료 : 10550A36_face0.jpg
# 파일 이동 완료 : 01459A21_face0.jpg
# 파일 이동 완료 : 07187A71_face0.jpg
# 파일 이동 완료 : 12643A59_face0.jpg
# 파일 이동 완료 : 10741A37_face0.jpg
# 파일 이동 완료 : 10177A34_face0.jpg
# 파일 이동 완료 : 03097A28_face0.jpg
# 파일 이동 완료 : 02530A27_face0.jpg
# 파일 이동 완료 : 03353A29_face0.jpg
# 파일 이동 완료 : 09756A32_face0.jpg
# 파일 이동 완료 : 08739A24_face0.jpg
# 파일 이동 완료 : 10871A38_face0.jpg
# 파일 이동 완료 : 12168A52_face0.jpg
# 파일 이동 완료 : 07687A06_face0.jpg
# 파일 이동 완료 : 08641A23_face0.jpg
# 파일 이동 완료 : 02364A26_face0.jpg
# 파일 이동 완료 : 01643A22_face1.jpg
# 파일 이동 완료 : 09319A29_face0.jpg
# 파일 이동 완료 : 07903A10_face0.jpg
# 파일 이동 완료 : 12749A61_face0.jpg
# 파일 이동 완료 : 01151A18_face0.jpg
# 파일 이동 완료 : 03403A30_face0.jpg
# 파일 이동 완료 : 07200A72_face0.jpg
# 파일 이동 완료 : 13266A78_face0.jpg
# 파일 이동 완료 : 07556A04_face0.jpg
# 파일 이동 완료 : 01792A23_face0.jpg
# 파일 이동 완료 : 08064A13_face0.jpg
# 파일 이동 완료 : 08687A24_face0.jpg
# 파일 이동 완료 : 08118A14_face0.jpg
# 파일 이동 완료 : 06548A55_face0.jpg
# 파일 이동 완료 : 06628A57_face0.jpg
# 파일 이동 완료 : 08507A22_face0.jpg
# 파일 이동 완료 : 10093A33_face0.jpg
# 파일 이동 완료 : 00684A12_face0.jpg
# 파일 이동 완료 : 12949A67_face0.jpg
# 파일 이동 완료 : 07941A11_face0.jpg
# 파일 이동 완료 : 10694A37_face0.jpg
# 파일 이동 완료 : 10202A34_face0.jpg
# 파일 이동 완료 : 06819A60_face0.jpg
# 파일 이동 완료 : 10049A33_face0.jpg
# 파일 이동 완료 : 10908A38_face0.jpg
# 파일 이동 완료 : 08120A14_face0.jpg
# 파일 이동 완료 : 13133A73_face0.jpg
# 파일 이동 완료 : 02694A27_face0.jpg
# 파일 이동 완료 : 03037A28_face0.jpg
# 파일 이동 완료 : 05305A41_face0.jpg
# 파일 이동 완료 : 03644A31_face0.jpg
# 파일 이동 완료 : 10190A34_face0.jpg
# 파일 이동 완료 : 09898A32_face0.jpg
# 파일 이동 완료 : 12508A56_face0.jpg
# 파일 이동 완료 : 13037A69_face0.jpg
# 파일 이동 완료 : 11291A42_face0.jpg
# 파일 이동 완료 : 06305A50_face0.jpg
# 파일 이동 완료 : 11019A39_face0.jpg
# 파일 이동 완료 : 01147A18_face0.jpg
# 파일 이동 완료 : 06057A47_face0.jpg
# 파일 이동 완료 : 07444A02_face0.jpg
# 파일 이동 완료 : 12510A56_face0.jpg
# 파일 이동 완료 : 10834A38_face0.jpg
# 파일 이동 완료 : 00336A06_face0.jpg
# 파일 이동 완료 : 02766A27_face0.jpg
# 파일 이동 완료 : 07644A06_face0.jpg
# 파일 이동 완료 : 09072A27_face0.jpg
# 파일 이동 완료 : 01499A21_face0.jpg
# 파일 이동 완료 : 08455A20_face1.jpg
# 파일 이동 완료 : 02867A27_face0.jpg
# 파일 이동 완료 : 12480A56_face0.jpg
# 파일 이동 완료 : 07567A05_face0.jpg
# 파일 이동 완료 : 11190A41_face0.jpg
# 파일 이동 완료 : 05669A43_face0.jpg
# 파일 이동 완료 : 03897A32_face0.jpg
# 파일 이동 완료 : 10387A35_face0.jpg
# 파일 이동 완료 : 01798A23_face0.jpg
# 파일 이동 완료 : 11720A46_face0.jpg
# 파일 이동 완료 : 08955A27_face0.jpg
# 파일 이동 완료 : 03978A32_face0.jpg
# 파일 이동 완료 : 10424A35_face0.jpg
# 파일 이동 완료 : 05516A42_face0.jpg
# 파일 이동 완료 : 01427A21_face0.jpg
# 파일 이동 완료 : 07035A67_face0.jpg
# 파일 이동 완료 : 07740A07_face0.jpg
# 파일 이동 완료 : 00339A06_face0.jpg
# 파일 이동 완료 : 00323A06_face0.jpg
# 파일 이동 완료 : 08242A17_face0.jpg
# 파일 이동 완료 : 03989A32_face0.jpg
# 파일 이동 완료 : 09921A32_face0.jpg
# 파일 이동 완료 : 00770A13_face1.jpg
# 파일 이동 완료 : 12180A52_face0.jpg
# 파일 이동 완료 : 08438A20_face0.jpg
# 파일 이동 완료 : 11914A48_face0.jpg
# 파일 이동 완료 : 00948A16_face0.jpg
# 파일 이동 완료 : 09531A30_face0.jpg
# 파일 이동 완료 : 12477A56_face0.jpg
# 파일 이동 완료 : 03507A30_face0.jpg
# 파일 이동 완료 : 04122A33_face0.jpg
# 파일 이동 완료 : 07386A02_face0.jpg
# 파일 이동 완료 : 09927A32_face0.jpg
# 파일 이동 완료 : 01238A19_face0.jpg
# 파일 이동 완료 : 11448A43_face0.jpg
# 파일 이동 완료 : 03291A29_face0.jpg
# 파일 이동 완료 : 05081A39_face0.jpg
# 파일 이동 완료 : 03712A31_face0.jpg
# 파일 이동 완료 : 01684A23_face0.jpg
# 파일 이동 완료 : 00388A07_face0.jpg
# 파일 이동 완료 : 13087A72_face0.jpg
# 파일 이동 완료 : 12387A55_face0.jpg
# 파일 이동 완료 : 08667A24_face0.jpg
# 파일 이동 완료 : 04111A33_face0.jpg
# 파일 이동 완료 : 07881A09_face0.jpg
# 파일 이동 완료 : 00465A08_face0.jpg
# 파일 이동 완료 : 01629A22_face0.jpg
# 파일 이동 완료 : 03945A32_face0.jpg
# 파일 이동 완료 : 13140A74_face0.jpg
# 파일 이동 완료 : 07069A67_face0.jpg
# 파일 이동 완료 : 03590A31_face0.jpg
# 파일 이동 완료 : 09610A31_face0.jpg
# 파일 이동 완료 : 09187A28_face0.jpg
# 파일 이동 완료 : 07842A09_face0.jpg
# 파일 이동 완료 : 04041A33_face0.jpg
# 파일 이동 완료 : 04803A37_face0.jpg
# 파일 이동 완료 : 06825A61_face0.jpg
# 파일 이동 완료 : 01237A19_face0.jpg
# 파일 이동 완료 : 13014A69_face0.jpg
# 파일 이동 완료 : 03799A32_face0.jpg
# 파일 이동 완료 : 03114A28_face0.jpg
# 파일 이동 완료 : 02307A26_face0.jpg
# 파일 이동 완료 : 01422A21_face1.jpg
# 파일 이동 완료 : 07511A04_face0.jpg
# 파일 이동 완료 : 04692A36_face0.jpg
# 파일 이동 완료 : 07446A02_face0.jpg
# 파일 이동 완료 : 05442A41_face0.jpg
# 파일 이동 완료 : 10160A34_face0.jpg
# 파일 이동 완료 : 03179A29_face0.jpg
# 파일 이동 완료 : 08700A24_face0.jpg
# 파일 이동 완료 : 08427A20_face0.jpg
# 파일 이동 완료 : 00207A04_face0.jpg
# 파일 이동 완료 : 11493A44_face0.jpg
# 파일 이동 완료 : 09783A32_face0.jpg
# 파일 이동 완료 : 12147A51_face0.jpg
# 파일 이동 완료 : 02799A27_face0.jpg
# 파일 이동 완료 : 02365A26_face0.jpg
# 파일 이동 완료 : 05790A44_face0.jpg
# 파일 이동 완료 : 09497A30_face0.jpg
# 파일 이동 완료 : 08337A18_face0.jpg
# 파일 이동 완료 : 10453A35_face0.jpg
# 파일 이동 완료 : 10260A34_face0.jpg
# 파일 이동 완료 : 04778A37_face0.jpg
# 파일 이동 완료 : 09646A31_face1.jpg
# 파일 이동 완료 : 07886A10_face0.jpg
# 파일 이동 완료 : 11760A46_face0.jpg
# 파일 이동 완료 : 04219A34_face0.jpg
# 파일 이동 완료 : 12299A54_face1.jpg
# 파일 이동 완료 : 09848A32_face0.jpg
# 파일 이동 완료 : 11572A44_face0.jpg
# 파일 이동 완료 : 07577A05_face0.jpg
# 파일 이동 완료 : 07920A11_face0.jpg
# 파일 이동 완료 : 11188A41_face0.jpg
# 파일 이동 완료 : 05668A43_face0.jpg
# 파일 이동 완료 : 12963A67_face0.jpg
# 파일 이동 완료 : 06399A52_face0.jpg
# 파일 이동 완료 : 09546A30_face0.jpg
# 파일 이동 완료 : 06885A62_face0.jpg
# 파일 이동 완료 : 11395A43_face0.jpg
# 파일 이동 완료 : 08025A12_face0.jpg
# 파일 이동 완료 : 04070A33_face0.jpg
# 파일 이동 완료 : 02306A26_face0.jpg
# 파일 이동 완료 : 09885A32_face0.jpg
# 파일 이동 완료 : 09768A32_face0.jpg
# 파일 이동 완료 : 06700A58_face1.jpg
# 파일 이동 완료 : 13067A71_face0.jpg
# 파일 이동 완료 : 08190A15_face0.jpg
# 파일 이동 완료 : 00192A04_face0.jpg
# 파일 이동 완료 : 10994A39_face0.jpg
# 파일 이동 완료 : 12231A53_face0.jpg
# 파일 이동 완료 : 04981A38_face0.jpg
# 파일 이동 완료 : 00248A05_face0.jpg
# 파일 이동 완료 : 01307A20_face0.jpg
# 파일 이동 완료 : 12235A53_face0.jpg
# 파일 이동 완료 : 07413A02_face0.jpg
# 파일 이동 완료 : 12737A61_face0.jpg
# 파일 이동 완료 : 10288A34_face0.jpg
# 파일 이동 완료 : 08338A18_face0.jpg
# 파일 이동 완료 : 07813A08_face1.jpg
# 파일 이동 완료 : 08335A18_face0.jpg
# 파일 이동 완료 : 12588A58_face0.jpg
# 파일 이동 완료 : 11941A48_face0.jpg
# 파일 이동 완료 : 02834A27_face0.jpg
# 파일 이동 완료 : 05963A46_face0.jpg
# 파일 이동 완료 : 00289A06_face0.jpg
# 파일 이동 완료 : 09852A32_face0.jpg
# 파일 이동 완료 : 06877A62_face0.jpg
# 파일 이동 완료 : 07322A78_face0.jpg
# 파일 이동 완료 : 08165A15_face0.jpg
# 파일 이동 완료 : 01782A23_face0.jpg
# 파일 이동 완료 : 01974A24_face0.jpg
# 파일 이동 완료 : 12052A50_face0.jpg
# 파일 이동 완료 : 04813A37_face0.jpg
# 파일 이동 완료 : 08055A13_face0.jpg
# 파일 이동 완료 : 06392A52_face0.jpg
# 파일 이동 완료 : 12063A50_face0.jpg
# 파일 이동 완료 : 03986A32_face0.jpg
# 파일 이동 완료 : 12663A59_face0.jpg
# 파일 이동 완료 : 03012A28_face0.jpg
# 파일 이동 완료 : 12612A58_face0.jpg
# 파일 이동 완료 : 07678A06_face0.jpg
# 파일 이동 완료 : 03969A32_face0.jpg
# 파일 이동 완료 : 06125A48_face0.jpg
# 파일 이동 완료 : 03334A29_face0.jpg
# 파일 이동 완료 : 12665A59_face0.jpg
# 파일 이동 완료 : 01053A17_face0.jpg
# 파일 이동 완료 : 13162A74_face0.jpg
# 파일 이동 완료 : 10574A36_face0.jpg
# 파일 이동 완료 : 04662A36_face0.jpg
# 파일 이동 완료 : 13073A71_face0.jpg
# 파일 이동 완료 : 01452A21_face0.jpg
# 파일 이동 완료 : 10364A35_face0.jpg
# 파일 이동 완료 : 11300A42_face0.jpg
# 파일 이동 완료 : 04161A33_face0.jpg
# 파일 이동 완료 : 00899A15_face0.jpg
# 파일 이동 완료 : 01455A21_face0.jpg
# 파일 이동 완료 : 06682A58_face0.jpg
# 파일 이동 완료 : 09496A30_face0.jpg
# 파일 이동 완료 : 01887A24_face0.jpg
# 파일 이동 완료 : 10568A36_face0.jpg
# 파일 이동 완료 : 11945A48_face0.jpg
# 파일 이동 완료 : 08107A14_face0.jpg
# 파일 이동 완료 : 10793A37_face0.jpg
# 파일 이동 완료 : 00386A07_face0.jpg
# 파일 이동 완료 : 04446A35_face0.jpg
# 파일 이동 완료 : 09563A31_face0.jpg
# 파일 이동 완료 : 06721A59_face0.jpg
# 파일 이동 완료 : 05004A38_face0.jpg
# 파일 이동 완료 : 00544A10_face0.jpg
# 파일 이동 완료 : 04894A37_face0.jpg
# 파일 이동 완료 : 00601A10_face0.jpg
# 파일 이동 완료 : 05353A41_face0.jpg
# 파일 이동 완료 : 10513A36_face0.jpg
# 파일 이동 완료 : 02742A27_face0.jpg
# 파일 이동 완료 : 04980A38_face0.jpg
# 파일 이동 완료 : 01708A23_face0.jpg
# 파일 이동 완료 : 02628A27_face0.jpg
# 파일 이동 완료 : 07909A10_face0.jpg
# 파일 이동 완료 : 03479A30_face0.jpg
# 파일 이동 완료 : 11027A39_face0.jpg
# 파일 이동 완료 : 09266A29_face0.jpg
# 파일 이동 완료 : 09246A29_face0.jpg
# 파일 이동 완료 : 12018A49_face0.jpg
# 파일 이동 완료 : 06998A66_face0.jpg
# 파일 이동 완료 : 08563A22_face0.jpg
# 파일 이동 완료 : 10639A36_face0.jpg
# 파일 이동 완료 : 02451A26_face0.jpg
# 파일 이동 완료 : 04751A37_face1.jpg
# 파일 이동 완료 : 04348A34_face0.jpg
# 파일 이동 완료 : 10323A35_face0.jpg
# 파일 이동 완료 : 11821A47_face0.jpg
# 파일 이동 완료 : 00474A09_face0.jpg
# 파일 이동 완료 : 12162A52_face0.jpg
# 파일 이동 완료 : 07247A75_face0.jpg
# 파일 이동 완료 : 08926A26_face0.jpg
# 파일 이동 완료 : 00328A06_face0.jpg
# 파일 이동 완료 : 07374A80_face0.jpg
# 파일 이동 완료 : 03600A31_face0.jpg
# 파일 이동 완료 : 08146A14_face0.jpg
# 파일 이동 완료 : 07189A71_face0.jpg
# 파일 이동 완료 : 04978A38_face0.jpg
# 파일 이동 완료 : 03586A31_face0.jpg
# 파일 이동 완료 : 10773A37_face0.jpg
# 파일 이동 완료 : 05712A43_face0.jpg
# 파일 이동 완료 : 09365A29_face0.jpg
# 파일 이동 완료 : 02626A27_face0.jpg
# 파일 이동 완료 : 01510A21_face0.jpg
# 파일 이동 완료 : 02087A25_face0.jpg
# 파일 이동 완료 : 04771A37_face0.jpg
# 파일 이동 완료 : 12217A52_face0.jpg
# 파일 이동 완료 : 06966A64_face0.jpg
# 파일 이동 완료 : 10505A36_face0.jpg
# 파일 이동 완료 : 09281A29_face0.jpg
# 파일 이동 완료 : 06137A48_face0.jpg
# 파일 이동 완료 : 06449A54_face0.jpg
# 파일 이동 완료 : 09074A28_face0.jpg
# 파일 이동 완료 : 09611A31_face0.jpg
# 파일 이동 완료 : 10361A35_face0.jpg
# 파일 이동 완료 : 01304A20_face0.jpg
# 파일 이동 완료 : 02828A27_face0.jpg
# 파일 이동 완료 : 08250A17_face0.jpg
# 파일 이동 완료 : 10065A33_face0.jpg
# 파일 이동 완료 : 08859A26_face0.jpg
# 파일 이동 완료 : 01668A23_face0.jpg
# 파일 이동 완료 : 05464A42_face0.jpg
# 파일 이동 완료 : 04367A34_face0.jpg
# 파일 이동 완료 : 12826A63_face0.jpg
# 파일 이동 완료 : 13167A75_face0.jpg
# 파일 이동 완료 : 04615A36_face0.jpg
# 파일 이동 완료 : 09931A33_face0.jpg
# 파일 이동 완료 : 01703A23_face0.jpg
# 파일 이동 완료 : 03151A29_face0.jpg
# 파일 이동 완료 : 04387A35_face0.jpg
# 파일 이동 완료 : 01483A21_face0.jpg
# 파일 이동 완료 : 02060A25_face0.jpg
# 파일 이동 완료 : 03142A29_face0.jpg
# 파일 이동 완료 : 07253A75_face0.jpg
# 파일 이동 완료 : 01680A23_face0.jpg
# 파일 이동 완료 : 01128A18_face0.jpg
# 파일 이동 완료 : 02660A27_face0.jpg
# 파일 이동 완료 : 12869A64_face0.jpg
# 파일 이동 완료 : 10478A36_face0.jpg
# 파일 이동 완료 : 05702A43_face0.jpg
# 파일 이동 완료 : 08838A25_face0.jpg
# 파일 이동 완료 : 04737A36_face0.jpg
# 파일 이동 완료 : 06714A58_face0.jpg
# 파일 이동 완료 : 12849A63_face0.jpg
# 파일 이동 완료 : 09605A31_face0.jpg
# 파일 이동 완료 : 11973A49_face0.jpg
# 파일 이동 완료 : 02921A28_face0.jpg
# 파일 이동 완료 : 02848A27_face0.jpg
# 파일 이동 완료 : 05402A41_face0.jpg
# 파일 이동 완료 : 12670A59_face0.jpg
# 파일 이동 완료 : 04462A35_face0.jpg
# 파일 이동 완료 : 02325A26_face0.jpg
# 파일 이동 완료 : 05454A42_face0.jpg
# 파일 이동 완료 : 06518A55_face0.jpg
# 파일 이동 완료 : 08230A16_face0.jpg
# 파일 이동 완료 : 00492A09_face0.jpg
# 파일 이동 완료 : 03435A30_face0.jpg
# 파일 이동 완료 : 09108A28_face0.jpg
# 파일 이동 완료 : 06049A47_face0.jpg
# 파일 이동 완료 : 07709A07_face0.jpg
# 파일 이동 완료 : 08435A20_face0.jpg
# 파일 이동 완료 : 11987A49_face0.jpg
# 파일 이동 완료 : 00805A14_face0.jpg
# 파일 이동 완료 : 02158A25_face0.jpg
# 파일 이동 완료 : 09307A29_face0.jpg
# 파일 이동 완료 : 06074A47_face0.jpg
# 파일 이동 완료 : 11647A45_face0.jpg
# 파일 이동 완료 : 11972A49_face0.jpg
# 파일 이동 완료 : 01774A23_face0.jpg
# 파일 이동 완료 : 03749A31_face0.jpg
# 파일 이동 완료 : 11264A41_face0.jpg
# 파일 이동 완료 : 11481A43_face0.jpg
# 파일 이동 완료 : 11007A39_face0.jpg
# 파일 이동 완료 : 01838A24_face0.jpg
# 파일 이동 완료 : 07624A06_face0.jpg
# 파일 이동 완료 : 04006A33_face0.jpg
# 파일 이동 완료 : 04361A34_face0.jpg
# 파일 이동 완료 : 04762A37_face0.jpg
# 파일 이동 완료 : 10942A38_face0.jpg
# 파일 이동 완료 : 05928A46_face0.jpg
# 파일 이동 완료 : 13156A74_face0.jpg
# 파일 이동 완료 : 07996A12_face0.jpg
# 파일 이동 완료 : 10638A36_face0.jpg
# 파일 이동 완료 : 09893A32_face0.jpg
# 파일 이동 완료 : 09445A30_face0.jpg
# 파일 이동 완료 : 12758A61_face0.jpg
# 파일 이동 완료 : 00668A12_face0.jpg
# 파일 이동 완료 : 05271A40_face0.jpg
# 파일 이동 완료 : 11922A48_face0.jpg
# 파일 이동 완료 : 09441A30_face0.jpg
# 파일 이동 완료 : 03122A28_face0.jpg
# 파일 이동 완료 : 07122A69_face0.jpg
# 파일 이동 완료 : 10832A38_face1.jpg
# 파일 이동 완료 : 06575A56_face0.jpg
# 파일 이동 완료 : 04289A34_face0.jpg
# 파일 이동 완료 : 10880A38_face0.jpg
# 파일 이동 완료 : 09877A32_face0.jpg
# 파일 이동 완료 : 04095A33_face0.jpg
# 파일 이동 완료 : 05698A43_face0.jpg
# 파일 이동 완료 : 06158A48_face0.jpg
# 파일 이동 완료 : 10986A39_face0.jpg
# 파일 이동 완료 : 07969A11_face0.jpg
# 파일 이동 완료 : 09308A29_face0.jpg
# 파일 이동 완료 : 07655A06_face0.jpg
# 파일 이동 완료 : 07499A03_face0.jpg
# 파일 이동 완료 : 10915A38_face0.jpg
# 파일 이동 완료 : 09721A32_face0.jpg
# 파일 이동 완료 : 02027A25_face0.jpg
# 파일 이동 완료 : 07000A66_face0.jpg
# 파일 이동 완료 : 06975A65_face1.jpg
# 파일 이동 완료 : 10540A36_face0.jpg
# 파일 이동 완료 : 02292A26_face0.jpg
# 파일 이동 완료 : 06398A52_face0.jpg
# 파일 이동 완료 : 10242A34_face0.jpg
# 파일 이동 완료 : 00997A17_face0.jpg
# 파일 이동 완료 : 07627A06_face0.jpg
# 파일 이동 완료 : 03911A32_face0.jpg
# 파일 이동 완료 : 13006A68_face0.jpg
# 파일 이동 완료 : 07251A75_face0.jpg
# 파일 이동 완료 : 11425A43_face1.jpg
# 파일 이동 완료 : 03898A32_face0.jpg
# 파일 이동 완료 : 11739A46_face0.jpg
# 파일 이동 완료 : 01044A17_face0.jpg
# 파일 이동 완료 : 11251A41_face0.jpg
# 파일 이동 완료 : 12143A51_face0.jpg
# 파일 이동 완료 : 03378A29_face0.jpg
# 파일 이동 완료 : 00169A04_face0.jpg
# 파일 이동 완료 : 12574A57_face0.jpg
# 파일 이동 완료 : 00983A16_face0.jpg
# 파일 이동 완료 : 12995A68_face0.jpg
# 파일 이동 완료 : 12653A59_face0.jpg
# 파일 이동 완료 : 12638A59_face0.jpg
# 파일 이동 완료 : 00157A04_face0.jpg
# 파일 이동 완료 : 02353A26_face0.jpg
# 파일 이동 완료 : 08843A25_face0.jpg
# 파일 이동 완료 : 02490A26_face0.jpg
# 파일 이동 완료 : 05376A41_face0.jpg
# 파일 이동 완료 : 09089A28_face0.jpg
# 파일 이동 완료 : 10979A39_face0.jpg
# 파일 이동 완료 : 13083A72_face0.jpg
# 파일 이동 완료 : 11288A42_face0.jpg
# 파일 이동 완료 : 07178A71_face0.jpg
# 파일 이동 완료 : 02154A25_face0.jpg
# 파일 이동 완료 : 00809A14_face0.jpg
# 파일 이동 완료 : 04848A37_face0.jpg
# 파일 이동 완료 : 11469A43_face0.jpg
# 파일 이동 완료 : 08709A24_face0.jpg
# 파일 이동 완료 : 00605A10_face0.jpg
# 파일 이동 완료 : 12349A54_face0.jpg
# 파일 이동 완료 : 08560A22_face0.jpg
# 파일 이동 완료 : 02790A27_face0.jpg
# 파일 이동 완료 : 04087A33_face0.jpg
# 파일 이동 완료 : 05384A41_face0.jpg
# 파일 이동 완료 : 05247A40_face0.jpg
# 파일 이동 완료 : 11335A42_face0.jpg
# 파일 이동 완료 : 09447A30_face0.jpg
# 파일 이동 완료 : 06224A49_face0.jpg
# 파일 이동 완료 : 10029A33_face0.jpg
# 파일 이동 완료 : 12419A55_face0.jpg
# 파일 이동 완료 : 07299A77_face0.jpg
# 파일 이동 완료 : 02373A26_face0.jpg
# 파일 이동 완료 : 06327A51_face0.jpg
# 파일 이동 완료 : 02259A26_face0.jpg
# 파일 이동 완료 : 05446A41_face0.jpg
# 파일 이동 완료 : 11287A42_face0.jpg
# 파일 이동 완료 : 06503A54_face0.jpg
# 파일 이동 완료 : 08715A24_face0.jpg
# 파일 이동 완료 : 10554A36_face0.jpg
# 파일 이동 완료 : 07915A10_face0.jpg
# 파일 이동 완료 : 11755A46_face0.jpg
# 파일 이동 완료 : 02048A25_face0.jpg
# 파일 이동 완료 : 06541A55_face0.jpg
# 파일 이동 완료 : 09675A31_face0.jpg
# 파일 이동 완료 : 04959A38_face0.jpg
# 파일 이동 완료 : 07821A08_face0.jpg
# 파일 이동 완료 : 01796A23_face0.jpg
# 파일 이동 완료 : 09854A32_face0.jpg
# 파일 이동 완료 : 10774A37_face0.jpg
# 파일 이동 완료 : 12222A53_face0.jpg
# 파일 이동 완료 : 05646A43_face0.jpg
# 파일 이동 완료 : 06838A61_face0.jpg
# 파일 이동 완료 : 07937A11_face0.jpg
# 파일 이동 완료 : 11348A42_face0.jpg
# 파일 이동 완료 : 05254A40_face0.jpg
# 파일 이동 완료 : 11509A44_face0.jpg
# 파일 이동 완료 : 07213A73_face0.jpg
# 파일 이동 완료 : 06274A50_face0.jpg
# 파일 이동 완료 : 07919A11_face0.jpg
# 파일 이동 완료 : 08175A15_face0.jpg
# 파일 이동 완료 : 10031A33_face0.jpg
# 파일 이동 완료 : 11181A41_face0.jpg
# 파일 이동 완료 : 10539A36_face0.jpg
# 파일 이동 완료 : 09371A29_face0.jpg
# 파일 이동 완료 : 12532A57_face0.jpg
# 파일 이동 완료 : 02151A25_face0.jpg
# 파일 이동 완료 : 03048A28_face0.jpg
# 파일 이동 완료 : 11770A46_face0.jpg
# 파일 이동 완료 : 06635A57_face0.jpg
# 파일 이동 완료 : 08635A23_face0.jpg
# 파일 이동 완료 : 12389A55_face0.jpg
# 파일 이동 완료 : 03308A29_face0.jpg
# 파일 이동 완료 : 02252A26_face0.jpg
# 파일 이동 완료 : 09825A32_face0.jpg
# 파일 이동 완료 : 05716A43_face0.jpg
# 파일 이동 완료 : 03486A30_face0.jpg
# 파일 이동 완료 : 08264A17_face0.jpg
# 파일 이동 완료 : 02178A25_face0.jpg
# 파일 이동 완료 : 12901A65_face0.jpg
# 파일 이동 완료 : 11244A41_face0.jpg
# 파일 이동 완료 : 08452A20_face0.jpg
# 파일 이동 완료 : 06045A47_face0.jpg
# 파일 이동 완료 : 07063A67_face0.jpg
# 파일 이동 완료 : 06322A51_face0.jpg
# 파일 이동 완료 : 00054A02_face0.jpg
# 파일 이동 완료 : 10104A33_face0.jpg
# 파일 이동 완료 : 10899A38_face0.jpg
# 파일 이동 완료 : 02475A26_face0.jpg
# 파일 이동 완료 : 10809A37_face0.jpg
# 파일 이동 완료 : 04035A33_face0.jpg
# 파일 이동 완료 : 12482A56_face0.jpg
# 파일 이동 완료 : 08454A20_face0.jpg
# 파일 이동 완료 : 03013A28_face0.jpg
# 파일 이동 완료 : 01294A20_face0.jpg
# 파일 이동 완료 : 04396A35_face0.jpg
# 파일 이동 완료 : 07895A10_face0.jpg
# 파일 이동 완료 : 02175A25_face0.jpg
# 파일 이동 완료 : 06424A53_face0.jpg
# 파일 이동 완료 : 05333A41_face0.jpg
# 파일 이동 완료 : 01135A18_face0.jpg
# 파일 이동 완료 : 08729A24_face0.jpg
# 파일 이동 완료 : 04086A33_face0.jpg
# 파일 이동 완료 : 09741A32_face0.jpg
# 파일 이동 완료 : 00490A09_face0.jpg
# 파일 이동 완료 : 05598A43_face0.jpg
# 파일 이동 완료 : 08406A20_face0.jpg
# 파일 이동 완료 : 08743A24_face0.jpg
# 파일 이동 완료 : 12183A52_face0.jpg
# 파일 이동 완료 : 01865A24_face0.jpg
# 파일 이동 완료 : 04510A35_face0.jpg
# 파일 이동 완료 : 00917A15_face0.jpg
# 파일 이동 완료 : 07753A07_face0.jpg
# 파일 이동 완료 : 10328A35_face0.jpg
# 파일 이동 완료 : 06442A53_face0.jpg
# 파일 이동 완료 : 05001A38_face0.jpg
# 파일 이동 완료 : 08668A24_face0.jpg
# 파일 이동 완료 : 07968A11_face0.jpg
# 파일 이동 완료 : 11595A45_face0.jpg
# 파일 이동 완료 : 10617A36_face0.jpg
# 파일 이동 완료 : 12299A54_face0.jpg
# 파일 이동 완료 : 01891A24_face0.jpg
# 파일 이동 완료 : 11866A47_face0.jpg
# 파일 이동 완료 : 07211A73_face0.jpg
# 파일 이동 완료 : 03575A31_face0.jpg
# 파일 이동 완료 : 00302A06_face0.jpg
# 파일 이동 완료 : 12410A55_face0.jpg
# 파일 이동 완료 : 05171A40_face0.jpg
# 파일 이동 완료 : 08634A23_face0.jpg
# 파일 이동 완료 : 07994A12_face0.jpg
# 파일 이동 완료 : 12549A57_face0.jpg
# 파일 이동 완료 : 09335A29_face0.jpg
# 파일 이동 완료 : 09866A32_face0.jpg
# 파일 이동 완료 : 05096A39_face0.jpg
# 파일 이동 완료 : 06616A56_face0.jpg
# 파일 이동 완료 : 00755A13_face0.jpg
# 파일 이동 완료 : 13152A74_face0.jpg
# 파일 이동 완료 : 13115A73_face0.jpg
# 파일 이동 완료 : 10602A36_face0.jpg
# 파일 이동 완료 : 05279A40_face0.jpg
# 파일 이동 완료 : 07128A69_face0.jpg
# 파일 이동 완료 : 08409A20_face0.jpg
# 파일 이동 완료 : 12690A60_face1.jpg
# 파일 이동 완료 : 11473A43_face0.jpg
# 파일 이동 완료 : 01672A23_face0.jpg
# 파일 이동 완료 : 00257A05_face0.jpg
# 파일 이동 완료 : 09516A30_face0.jpg
# 파일 이동 완료 : 00047A02_face0.jpg
# 파일 이동 완료 : 00515A09_face0.jpg
# 파일 이동 완료 : 11623A45_face0.jpg
# 파일 이동 완료 : 10763A37_face0.jpg
# 파일 이동 완료 : 10732A37_face0.jpg
# 파일 이동 완료 : 07326A78_face0.jpg
# 파일 이동 완료 : 10508A36_face0.jpg
# 파일 이동 완료 : 07397A02_face0.jpg
# 파일 이동 완료 : 04694A36_face0.jpg
# 파일 이동 완료 : 08328A18_face0.jpg
# 파일 이동 완료 : 04218A34_face0.jpg
# 파일 이동 완료 : 01636A22_face0.jpg
# 파일 이동 완료 : 08880A26_face0.jpg
# 파일 이동 완료 : 11383A42_face0.jpg
# 파일 이동 완료 : 05910A46_face0.jpg
# 파일 이동 완료 : 10287A34_face0.jpg
# 파일 이동 완료 : 05800A44_face0.jpg
# 파일 이동 완료 : 11311A42_face0.jpg
# 파일 이동 완료 : 00731A13_face0.jpg
# 파일 이동 완료 : 07575A05_face0.jpg
# 파일 이동 완료 : 09534A30_face0.jpg
# 파일 이동 완료 : 02654A27_face0.jpg
# 파일 이동 완료 : 04845A37_face0.jpg
# 파일 이동 완료 : 01439A21_face0.jpg
# 파일 이동 완료 : 01853A24_face0.jpg
# 파일 이동 완료 : 11796A47_face0.jpg
# 파일 이동 완료 : 05927A46_face0.jpg
# 파일 이동 완료 : 08294A18_face0.jpg
# 파일 이동 완료 : 09925A32_face0.jpg
# 파일 이동 완료 : 13076A71_face0.jpg
# 파일 이동 완료 : 00445A08_face0.jpg
# 파일 이동 완료 : 01711A23_face0.jpg
# 파일 이동 완료 : 09821A32_face0.jpg
# 파일 이동 완료 : 03393A30_face0.jpg
# 파일 이동 완료 : 01548A22_face1.jpg
# 파일 이동 완료 : 06106A48_face0.jpg
# 파일 이동 완료 : 05886A45_face0.jpg
# 파일 이동 완료 : 04126A33_face0.jpg
# 파일 이동 완료 : 03303A29_face0.jpg
# 파일 이동 완료 : 12069A50_face0.jpg
# 파일 이동 완료 : 09904A32_face0.jpg
# 파일 이동 완료 : 11975A49_face0.jpg
# 파일 이동 완료 : 08312A18_face0.jpg
# 파일 이동 완료 : 02966A28_face0.jpg
# 파일 이동 완료 : 11100A40_face0.jpg
# 파일 이동 완료 : 07621A06_face0.jpg
# 파일 이동 완료 : 13203A76_face0.jpg
# 파일 이동 완료 : 10846A38_face0.jpg
# 파일 이동 완료 : 07441A02_face0.jpg
# 파일 이동 완료 : 05434A41_face0.jpg
# 파일 이동 완료 : 03863A32_face0.jpg
# 파일 이동 완료 : 13136A74_face1.jpg
# 파일 이동 완료 : 01185A19_face0.jpg
# 파일 이동 완료 : 01236A19_face0.jpg
# 파일 이동 완료 : 11372A42_face0.jpg
# 파일 이동 완료 : 00640A11_face0.jpg
# 파일 이동 완료 : 04758A37_face0.jpg
# 파일 이동 완료 : 09684A31_face0.jpg
# 파일 이동 완료 : 02786A27_face0.jpg
# 파일 이동 완료 : 03770A31_face0.jpg
# 파일 이동 완료 : 10048A33_face0.jpg
# 파일 이동 완료 : 00236A05_face0.jpg
# 파일 이동 완료 : 08812A25_face0.jpg
# 파일 이동 완료 : 00819A14_face0.jpg
# 파일 이동 완료 : 13071A71_face0.jpg
# 파일 이동 완료 : 06678A58_face0.jpg
# 파일 이동 완료 : 02435A26_face0.jpg
# 파일 이동 완료 : 06157A48_face0.jpg
# 파일 이동 완료 : 01043A17_face0.jpg
# 파일 이동 완료 : 06151A48_face0.jpg
# 파일 이동 완료 : 12068A50_face0.jpg
# 파일 이동 완료 : 05842A45_face0.jpg
# 파일 이동 완료 : 06597A56_face0.jpg
# 파일 이동 완료 : 13235A77_face0.jpg
# 파일 이동 완료 : 05834A45_face0.jpg
# 파일 이동 완료 : 13146A74_face0.jpg
# 파일 이동 완료 : 02827A27_face0.jpg
# 파일 이동 완료 : 03924A32_face0.jpg
# 파일 이동 완료 : 00607A10_face0.jpg
# 파일 이동 완료 : 03234A29_face0.jpg
# 파일 이동 완료 : 11504A44_face0.jpg
# 파일 이동 완료 : 08212A16_face0.jpg
# 파일 이동 완료 : 08439A20_face0.jpg
# 파일 이동 완료 : 12616A59_face0.jpg
# 파일 이동 완료 : 12408A55_face0.jpg
# 파일 이동 완료 : 07550A04_face0.jpg
# 파일 이동 완료 : 11359A42_face0.jpg
# 파일 이동 완료 : 12987A68_face0.jpg
# 파일 이동 완료 : 06413A53_face0.jpg
# 파일 이동 완료 : 06023A47_face0.jpg
# 파일 이동 완료 : 04358A34_face0.jpg
# 파일 이동 완료 : 00318A06_face0.jpg
# 파일 이동 완료 : 11603A45_face0.jpg
# 파일 이동 완료 : 07802A08_face0.jpg
# 파일 이동 완료 : 01576A22_face0.jpg
# 파일 이동 완료 : 10781A37_face0.jpg
# 파일 이동 완료 : 06989A65_face0.jpg
# 파일 이동 완료 : 13119A73_face0.jpg
# 파일 이동 완료 : 08577A23_face0.jpg
# 파일 이동 완료 : 00484A09_face0.jpg
# 파일 이동 완료 : 01227A19_face0.jpg
# 파일 이동 완료 : 08183A15_face0.jpg
# 파일 이동 완료 : 01913A24_face0.jpg
# 파일 이동 완료 : 09616A31_face0.jpg
# 파일 이동 완료 : 00546A10_face0.jpg
# 파일 이동 완료 : 13245A78_face0.jpg
# 파일 이동 완료 : 10872A38_face0.jpg
# 파일 이동 완료 : 12215A52_face0.jpg
# 파일 이동 완료 : 05759A44_face0.jpg
# 파일 이동 완료 : 13300A80_face0.jpg
# 파일 이동 완료 : 12095A51_face0.jpg
# 파일 이동 완료 : 08235A16_face1.jpg
# 파일 이동 완료 : 11596A45_face0.jpg
# 파일 이동 완료 : 11575A44_face0.jpg
# 파일 이동 완료 : 13144A74_face0.jpg
# 파일 이동 완료 : 02314A26_face0.jpg
# 파일 이동 완료 : 06621A56_face0.jpg
# 파일 이동 완료 : 01679A23_face0.jpg
# 파일 이동 완료 : 10641A36_face0.jpg
# 파일 이동 완료 : 00413A08_face0.jpg
# 파일 이동 완료 : 00487A09_face0.jpg
# 파일 이동 완료 : 04688A36_face0.jpg
# 파일 이동 완료 : 09422A29_face0.jpg
# 파일 이동 완료 : 00288A06_face0.jpg
# 파일 이동 완료 : 11308A42_face0.jpg
# 파일 이동 완료 : 06978A65_face0.jpg
# 파일 이동 완료 : 10366A35_face0.jpg
# 파일 이동 완료 : 00244A05_face0.jpg
# 파일 이동 완료 : 11175A41_face0.jpg
# 파일 이동 완료 : 05473A42_face0.jpg
# 파일 이동 완료 : 01687A23_face0.jpg
# 파일 이동 완료 : 12527A57_face0.jpg
# 파일 이동 완료 : 13024A69_face0.jpg
# 파일 이동 완료 : 06252A50_face0.jpg
# 파일 이동 완료 : 04237A34_face0.jpg
# 파일 이동 완료 : 02350A26_face0.jpg
# 파일 이동 완료 : 10738A37_face0.jpg
# 파일 이동 완료 : 04196A33_face0.jpg
# 파일 이동 완료 : 08954A27_face0.jpg
# 파일 이동 완료 : 06039A47_face0.jpg
# 파일 이동 완료 : 07277A76_face0.jpg
# 파일 이동 완료 : 06205A49_face0.jpg
# 파일 이동 완료 : 00303A06_face0.jpg
# 파일 이동 완료 : 03128A28_face0.jpg
# 파일 이동 완료 : 13031A69_face0.jpg
# 파일 이동 완료 : 00734A13_face0.jpg
# 파일 이동 완료 : 09311A29_face0.jpg
# 파일 이동 완료 : 03323A29_face0.jpg
# 파일 이동 완료 : 07454A02_face0.jpg
# 파일 이동 완료 : 03036A28_face0.jpg
# 파일 이동 완료 : 06704A58_face0.jpg
# 파일 이동 완료 : 07013A66_face0.jpg
# 파일 이동 완료 : 06139A48_face0.jpg
# 파일 이동 완료 : 00743A13_face0.jpg
# 파일 이동 완료 : 08875A26_face0.jpg
# 파일 이동 완료 : 07223A73_face1.jpg
# 파일 이동 완료 : 06431A53_face0.jpg
# 파일 이동 완료 : 00740A13_face0.jpg
# 파일 이동 완료 : 02469A26_face0.jpg
# 파일 이동 완료 : 09504A30_face0.jpg
# 파일 이동 완료 : 08419A20_face0.jpg
# 파일 이동 완료 : 12522A57_face0.jpg
# 파일 이동 완료 : 09067A27_face0.jpg
# 파일 이동 완료 : 07974A11_face0.jpg
# 파일 이동 완료 : 06415A53_face0.jpg
# 파일 이동 완료 : 12767A61_face0.jpg
# 파일 이동 완료 : 09392A29_face0.jpg
# 파일 이동 완료 : 11699A45_face0.jpg
# 파일 이동 완료 : 12938A66_face0.jpg
# 파일 이동 완료 : 05178A40_face0.jpg
# 파일 이동 완료 : 00206A04_face0.jpg
# 파일 이동 완료 : 11578A45_face0.jpg
# 파일 이동 완료 : 11270A41_face0.jpg
# 파일 이동 완료 : 09178A28_face0.jpg
# 파일 이동 완료 : 00864A15_face0.jpg
# 파일 이동 완료 : 03542A30_face0.jpg
# 파일 이동 완료 : 07906A10_face0.jpg
# 파일 이동 완료 : 11503A44_face0.jpg
# 파일 이동 완료 : 01943A24_face0.jpg
# 파일 이동 완료 : 11399A43_face0.jpg
# 파일 이동 완료 : 01530A22_face0.jpg
# 파일 이동 완료 : 01218A19_face0.jpg
# 파일 이동 완료 : 11563A44_face0.jpg
# 파일 이동 완료 : 00135A03_face0.jpg
# 파일 이동 완료 : 06638A57_face0.jpg
# 파일 이동 완료 : 07722A07_face0.jpg
# 파일 이동 완료 : 05128A39_face0.jpg
# 파일 이동 완료 : 00804A14_face0.jpg
# 파일 이동 완료 : 11037A39_face0.jpg
# 파일 이동 완료 : 05421A41_face0.jpg
# 파일 이동 완료 : 11927A48_face0.jpg
# 파일 이동 완료 : 10601A36_face0.jpg
# 파일 이동 완료 : 09648A31_face0.jpg
# 파일 이동 완료 : 05352A41_face0.jpg
# 파일 이동 완료 : 05123A39_face0.jpg
# 파일 이동 완료 : 02490A26_face1.jpg
# 파일 이동 완료 : 07238A74_face0.jpg
# 파일 이동 완료 : 07877A09_face0.jpg
# 파일 이동 완료 : 05092A39_face0.jpg
# 파일 이동 완료 : 12310A54_face0.jpg
# 파일 이동 완료 : 06707A58_face0.jpg
# 파일 이동 완료 : 07706A07_face0.jpg
# 파일 이동 완료 : 00711A12_face0.jpg
# 파일 이동 완료 : 03307A29_face0.jpg
# 파일 이동 완료 : 12400A55_face0.jpg
# 파일 이동 완료 : 07362A80_face0.jpg
# 파일 이동 완료 : 00456A08_face0.jpg
# 파일 이동 완료 : 06751A59_face0.jpg
# 파일 이동 완료 : 00026A02_face0.jpg
# 파일 이동 완료 : 08930A27_face0.jpg
# 파일 이동 완료 : 11810A47_face0.jpg
# 파일 이동 완료 : 12049A50_face0.jpg
# 파일 이동 완료 : 12097A51_face1.jpg
# 파일 이동 완료 : 00476A09_face0.jpg
# 파일 이동 완료 : 05693A43_face0.jpg
# 파일 이동 완료 : 02750A27_face0.jpg
# 파일 이동 완료 : 06472A54_face0.jpg
# 파일 이동 완료 : 02625A27_face0.jpg
# 파일 이동 완료 : 00854A14_face0.jpg
# 파일 이동 완료 : 01849A24_face0.jpg
# 파일 이동 완료 : 00475A09_face0.jpg
# 파일 이동 완료 : 10179A34_face0.jpg
# 파일 이동 완료 : 08571A22_face0.jpg
# 파일 이동 완료 : 03171A29_face0.jpg
# 파일 이동 완료 : 11232A41_face0.jpg
# 파일 이동 완료 : 01155A18_face0.jpg
# 파일 이동 완료 : 08472A21_face0.jpg
# 파일 이동 완료 : 08346A19_face0.jpg
# 파일 이동 완료 : 13047A70_face0.jpg
# 파일 이동 완료 : 10313A34_face0.jpg
# 파일 이동 완료 : 10918A38_face0.jpg
# 파일 이동 완료 : 07671A06_face0.jpg
# 파일 이동 완료 : 08220A16_face0.jpg
# 파일 이동 완료 : 03086A28_face0.jpg
# 파일 이동 완료 : 03465A30_face0.jpg
# 파일 이동 완료 : 09892A32_face0.jpg
# 파일 이동 완료 : 09016A27_face0.jpg
# 파일 이동 완료 : 10840A38_face0.jpg
# 파일 이동 완료 : 00438A08_face0.jpg
# 파일 이동 완료 : 04286A34_face0.jpg
# 파일 이동 완료 : 07715A07_face0.jpg
# 파일 이동 완료 : 09054A27_face0.jpg
# 파일 이동 완료 : 12270A53_face0.jpg
# 파일 이동 완료 : 07172A70_face0.jpg
# 파일 이동 완료 : 07709A07_face1.jpg
# 파일 이동 완료 : 03926A32_face1.jpg
# 파일 이동 완료 : 11333A42_face0.jpg
# 파일 이동 완료 : 04871A37_face0.jpg
# 파일 이동 완료 : 04804A37_face0.jpg
# 파일 이동 완료 : 10981A39_face0.jpg
# 파일 이동 완료 : 02493A26_face0.jpg
# 파일 이동 완료 : 00477A09_face0.jpg
# 파일 이동 완료 : 09135A28_face0.jpg
# 파일 이동 완료 : 11517A44_face0.jpg
# 파일 이동 완료 : 08791A25_face0.jpg
# 파일 이동 완료 : 05489A42_face0.jpg
# 파일 이동 완료 : 10907A38_face0.jpg
# 파일 이동 완료 : 07466A03_face0.jpg
# 파일 이동 완료 : 00062A02_face0.jpg
# 파일 이동 완료 : 04259A34_face0.jpg
# 파일 이동 완료 : 06669A57_face0.jpg
# 파일 이동 완료 : 11802A47_face0.jpg
# 파일 이동 완료 : 11210A41_face0.jpg
# 파일 이동 완료 : 07914A10_face0.jpg
# ...
# 파일 이동 완료 : 11627A45_face0.jpg
# 파일 이동 완료 : 02124A25_face0.jpg
# 파일 이동 완료 : 08848A25_face0.jpg
# 파일 이동 완료 : 04354A34_face0.jpg
# 파일 이동 완료 : 11867A48_face0.jpg
# 파일 이동 완료 : 07513A04_face0.jpg
# 파일 이동 완료 : 03513A30_face0.jpg
# 파일 이동 완료 : 05960A46_face0.jpg
# 파일 이동 완료 : 04280A34_face0.jpg
# 파일 이동 완료 : 02912A28_face0.jpg
# 파일 이동 완료 : 08735A24_face0.jpg
# 파일 이동 완료 : 01005A17_face0.jpg
# 파일 이동 완료 : 01855A24_face0.jpg
# 파일 이동 완료 : 07514A04_face0.jpg
# 파일 이동 완료 : 11482A43_face0.jpg
# 파일 이동 완료 : 11803A47_face0.jpg
# 파일 이동 완료 : 04613A36_face0.jpg
# 파일 이동 완료 : 00594A10_face0.jpg
# 파일 이동 완료 : 10225A34_face0.jpg
# 파일 이동 완료 : 00285A05_face0.jpg
# 파일 이동 완료 : 07306A77_face0.jpg
# 파일 이동 완료 : 07376A80_face0.jpg
# 파일 이동 완료 : 03428A30_face0.jpg
# 파일 이동 완료 : 01734A23_face0.jpg
# 파일 이동 완료 : 02815A27_face0.jpg
# 파일 이동 완료 : 00877A15_face0.jpg
# 파일 이동 완료 : 05330A41_face0.jpg
# 파일 이동 완료 : 05475A42_face1.jpg
# 파일 이동 완료 : 03164A29_face0.jpg
# 파일 이동 완료 : 07118A69_face0.jpg
# 파일 이동 완료 : 07817A08_face0.jpg
# 파일 이동 완료 : 10232A34_face0.jpg
# 파일 이동 완료 : 02029A25_face0.jpg
# 파일 이동 완료 : 02859A27_face0.jpg
# 파일 이동 완료 : 09191A28_face0.jpg
# 파일 이동 완료 : 09550A30_face0.jpg
# 파일 이동 완료 : 07082A68_face0.jpg
# 파일 이동 완료 : 08296A18_face0.jpg
# 파일 이동 완료 : 11303A42_face0.jpg
# 파일 이동 완료 : 07101A68_face0.jpg
# 파일 이동 완료 : 05924A46_face0.jpg
# 파일 이동 완료 : 08829A25_face0.jpg
# 파일 이동 완료 : 13139A74_face0.jpg
# 파일 이동 완료 : 11651A45_face0.jpg
# 파일 이동 완료 : 08573A22_face0.jpg
# 파일 이동 완료 : 11836A47_face0.jpg
# 파일 이동 완료 : 02286A26_face0.jpg
# 파일 이동 완료 : 06506A54_face0.jpg
# 파일 이동 완료 : 13279A79_face0.jpg
# 파일 이동 완료 : 12139A51_face0.jpg
# 파일 이동 완료 : 11751A46_face0.jpg
# 파일 이동 완료 : 12782A62_face0.jpg
# 파일 이동 완료 : 07339A79_face0.jpg
# 파일 이동 완료 : 03622A31_face0.jpg
# 파일 이동 완료 : 05109A39_face0.jpg
# 파일 이동 완료 : 05496A42_face0.jpg
# 파일 이동 완료 : 04101A33_face0.jpg
# 파일 이동 완료 : 11402A43_face0.jpg
# 파일 이동 완료 : 05472A42_face0.jpg
# 파일 이동 완료 : 02455A26_face0.jpg
# 파일 이동 완료 : 00166A04_face0.jpg
# 파일 이동 완료 : 09703A31_face0.jpg
# 파일 이동 완료 : 04702A36_face0.jpg
# 파일 이동 완료 : 06960A64_face0.jpg
# 파일 이동 완료 : 08461A21_face0.jpg
# 파일 이동 완료 : 01048A17_face0.jpg
# 파일 이동 완료 : 08483A21_face0.jpg
# 파일 이동 완료 : 07373A80_face0.jpg
# 파일 이동 완료 : 11134A40_face0.jpg
# 파일 이동 완료 : 11937A48_face0.jpg
# 파일 이동 완료 : 05511A42_face0.jpg
# 파일 이동 완료 : 03813A32_face0.jpg
# 파일 이동 완료 : 04523A35_face0.jpg
# 파일 이동 완료 : 03885A32_face0.jpg
# 파일 이동 완료 : 00015A02_face0.jpg
# 파일 이동 완료 : 02172A25_face0.jpg
# 파일 이동 완료 : 08631A23_face0.jpg
# 파일 이동 완료 : 09846A32_face0.jpg
# 파일 이동 완료 : 01673A23_face0.jpg
# 파일 이동 완료 : 09779A32_face0.jpg
# 파일 이동 완료 : 00974A16_face0.jpg
# 파일 이동 완료 : 01625A22_face0.jpg
# 파일 이동 완료 : 03255A29_face0.jpg
# 파일 이동 완료 : 13277A79_face0.jpg
# 파일 이동 완료 : 04336A34_face0.jpg
# 파일 이동 완료 : 00963A16_face0.jpg
# 파일 이동 완료 : 10705A37_face0.jpg
# 파일 이동 완료 : 08527A22_face1.jpg
# 파일 이동 완료 : 05098A39_face0.jpg
# 파일 이동 완료 : 04301A34_face0.jpg
# 파일 이동 완료 : 06353A51_face0.jpg
# 파일 이동 완료 : 03183A29_face0.jpg
# 파일 이동 완료 : 10804A37_face0.jpg
# 파일 이동 완료 : 10581A36_face0.jpg
# 파일 이동 완료 : 06600A56_face0.jpg
# 파일 이동 완료 : 07555A04_face0.jpg
# 파일 이동 완료 : 04729A36_face0.jpg
# 파일 이동 완료 : 10463A35_face0.jpg
# 파일 이동 완료 : 03236A29_face0.jpg
# 파일 이동 완료 : 07885A10_face0.jpg
# 파일 이동 완료 : 11930A48_face0.jpg
# 파일 이동 완료 : 06592A56_face0.jpg
# 파일 이동 완료 : 09881A32_face0.jpg
# 파일 이동 완료 : 08443A20_face0.jpg
# 파일 이동 완료 : 06665A57_face0.jpg
# 파일 이동 완료 : 00499A09_face0.jpg
# 파일 이동 완료 : 13230A77_face0.jpg
# 파일 이동 완료 : 11082A40_face0.jpg
# 파일 이동 완료 : 08492A21_face0.jpg
# 파일 이동 완료 : 04696A36_face0.jpg
# 파일 이동 완료 : 04117A33_face0.jpg
# 파일 이동 완료 : 04504A35_face0.jpg
# 파일 이동 완료 : 02278A26_face0.jpg
# 파일 이동 완료 : 02255A26_face0.jpg
# 파일 이동 완료 : 08565A22_face0.jpg
# 파일 이동 완료 : 07529A04_face0.jpg
# 파일 이동 완료 : 05916A46_face0.jpg
# 파일 이동 완료 : 08440A20_face0.jpg
# 파일 이동 완료 : 07696A07_face0.jpg
# 파일 이동 완료 : 07949A11_face0.jpg
# 파일 이동 완료 : 12660A59_face0.jpg
# 파일 이동 완료 : 04906A38_face0.jpg
# 파일 이동 완료 : 06997A65_face0.jpg
# 파일 이동 완료 : 01533A22_face0.jpg
# 파일 이동 완료 : 00405A07_face0.jpg
# 파일 이동 완료 : 12902A65_face0.jpg
# 파일 이동 완료 : 10526A36_face0.jpg
# 파일 이동 완료 : 05964A46_face0.jpg
# 파일 이동 완료 : 04718A36_face0.jpg
# 파일 이동 완료 : 13130A73_face0.jpg
# 파일 이동 완료 : 00190A04_face0.jpg
# 파일 이동 완료 : 10195A34_face0.jpg
# 파일 이동 완료 : 04673A36_face0.jpg
# 파일 이동 완료 : 06636A57_face0.jpg
# 파일 이동 완료 : 02090A25_face0.jpg
# 파일 이동 완료 : 01119A18_face0.jpg
# 파일 이동 완료 : 07940A11_face0.jpg
# 파일 이동 완료 : 09022A27_face0.jpg
# 파일 이동 완료 : 06435A53_face0.jpg
# 파일 이동 완료 : 11263A41_face0.jpg
# 파일 이동 완료 : 02978A28_face0.jpg
# 파일 이동 완료 : 01604A22_face0.jpg
# 파일 이동 완료 : 07874A09_face0.jpg
# 파일 이동 완료 : 08486A21_face0.jpg
# 파일 이동 완료 : 10811A37_face0.jpg
# 파일 이동 완료 : 03585A31_face0.jpg
# 파일 이동 완료 : 07726A07_face0.jpg
# 파일 이동 완료 : 02891A28_face0.jpg
# 파일 이동 완료 : 12801A62_face0.jpg
# 파일 이동 완료 : 09740A32_face0.jpg
# 파일 이동 완료 : 05961A46_face0.jpg
# 파일 이동 완료 : 00953A16_face0.jpg
# 파일 이동 완료 : 12434A56_face0.jpg
# 파일 이동 완료 : 13269A78_face0.jpg
# 파일 이동 완료 : 08114A14_face0.jpg
# 파일 이동 완료 : 06022A47_face0.jpg
# 파일 이동 완료 : 07075A68_face0.jpg
# 파일 이동 완료 : 09427A30_face0.jpg
# 파일 이동 완료 : 01710A23_face0.jpg
# 파일 이동 완료 : 09407A29_face0.jpg
# 파일 이동 완료 : 02707A27_face0.jpg
# 파일 이동 완료 : 10036A33_face1.jpg
# 파일 이동 완료 : 02621A27_face0.jpg
# 파일 이동 완료 : 01902A24_face0.jpg
# 파일 이동 완료 : 05696A43_face0.jpg
# 파일 이동 완료 : 10467A35_face0.jpg
# 파일 이동 완료 : 10500A36_face0.jpg
# 파일 이동 완료 : 04186A33_face0.jpg
# 파일 이동 완료 : 05540A42_face0.jpg
# 파일 이동 완료 : 12243A53_face0.jpg
# 파일 이동 완료 : 11275A42_face0.jpg
# 파일 이동 완료 : 03258A29_face0.jpg
# 파일 이동 완료 : 06660A57_face0.jpg
# 파일 이동 완료 : 05209A40_face0.jpg
# 파일 이동 완료 : 00618A11_face0.jpg
# 파일 이동 완료 : 02807A27_face0.jpg
# 파일 이동 완료 : 04375A34_face0.jpg
# 파일 이동 완료 : 02419A26_face0.jpg
# 파일 이동 완료 : 02933A28_face0.jpg
# 파일 이동 완료 : 06246A50_face0.jpg
# 파일 이동 완료 : 06823A61_face0.jpg
# 파일 이동 완료 : 03420A30_face0.jpg
# 파일 이동 완료 : 07805A08_face0.jpg
# 파일 이동 완료 : 12606A58_face0.jpg
# 파일 이동 완료 : 02676A27_face0.jpg
# 파일 이동 완료 : 03276A29_face0.jpg
# 파일 이동 완료 : 09192A28_face0.jpg
# 파일 이동 완료 : 02366A26_face0.jpg
# 파일 이동 완료 : 07302A77_face0.jpg
# 파일 이동 완료 : 00194A04_face0.jpg
# 파일 이동 완료 : 06522A55_face0.jpg
# 파일 이동 완료 : 09136A28_face0.jpg
# 파일 이동 완료 : 13200A76_face0.jpg
# 파일 이동 완료 : 12489A56_face0.jpg
# 파일 이동 완료 : 06662A57_face0.jpg
# 파일 이동 완료 : 05417A41_face0.jpg
# 파일 이동 완료 : 10318A35_face0.jpg
# 파일 이동 완료 : 00039A02_face0.jpg
# 파일 이동 완료 : 03954A32_face0.jpg
# 파일 이동 완료 : 03321A29_face0.jpg
# 파일 이동 완료 : 07112A69_face0.jpg
# 파일 이동 완료 : 11793A47_face0.jpg
# 파일 이동 완료 : 05323A41_face0.jpg
# 파일 이동 완료 : 11021A39_face0.jpg
# 파일 이동 완료 : 01321A20_face0.jpg
# 파일 이동 완료 : 09095A28_face0.jpg
# 파일 이동 완료 : 01972A24_face0.jpg
# 파일 이동 완료 : 10645A36_face0.jpg
# 파일 이동 완료 : 11833A47_face0.jpg
# 파일 이동 완료 : 03132A28_face0.jpg
# 파일 이동 완료 : 12658A59_face0.jpg
# 파일 이동 완료 : 05244A40_face0.jpg
# 파일 이동 완료 : 12238A53_face0.jpg
# 파일 이동 완료 : 08806A25_face0.jpg
# 파일 이동 완료 : 00924A16_face0.jpg
# 파일 이동 완료 : 02641A27_face0.jpg
# 파일 이동 완료 : 11576A44_face0.jpg
# 파일 이동 완료 : 04373A34_face1.jpg
# 파일 이동 완료 : 09601A31_face0.jpg
# 파일 이동 완료 : 06144A48_face0.jpg
# 파일 이동 완료 : 02572A27_face0.jpg
# 파일 이동 완료 : 05863A45_face0.jpg
# 파일 이동 완료 : 05351A41_face0.jpg
# 파일 이동 완료 : 12195A52_face0.jpg
# 파일 이동 완료 : 06927A63_face0.jpg
# 파일 이동 완료 : 07576A05_face0.jpg
# 파일 이동 완료 : 09644A31_face0.jpg
# 파일 이동 완료 : 03187A29_face0.jpg
# 파일 이동 완료 : 03625A31_face0.jpg
# 파일 이동 완료 : 01449A21_face0.jpg
# 파일 이동 완료 : 02465A26_face0.jpg
# 파일 이동 완료 : 10383A35_face0.jpg
# 파일 이동 완료 : 02526A26_face0.jpg
# 파일 이동 완료 : 09679A31_face0.jpg
# 파일 이동 완료 : 06520A55_face0.jpg
# 파일 이동 완료 : 13313A80_face0.jpg
# 파일 이동 완료 : 02979A28_face0.jpg
# 파일 이동 완료 : 04306A34_face0.jpg
# 파일 이동 완료 : 12495A56_face0.jpg
# 파일 이동 완료 : 11301A42_face0.jpg
# 파일 이동 완료 : 03734A31_face0.jpg
# 파일 이동 완료 : 05391A41_face0.jpg
# 파일 이동 완료 : 03888A32_face0.jpg
# 파일 이동 완료 : 01112A18_face0.jpg
# 파일 이동 완료 : 07530A04_face0.jpg
# 파일 이동 완료 : 09641A31_face0.jpg
# 파일 이동 완료 : 00884A15_face0.jpg
# 파일 이동 완료 : 01825A24_face0.jpg
# 파일 이동 완료 : 10724A37_face0.jpg
# 파일 이동 완료 : 06127A48_face0.jpg
# 파일 이동 완료 : 09555A31_face0.jpg
# 파일 이동 완료 : 08410A20_face0.jpg
# 파일 이동 완료 : 00803A14_face0.jpg
# 파일 이동 완료 : 06892A62_face0.jpg
# 파일 이동 완료 : 06372A52_face0.jpg
# 파일 이동 완료 : 08675A24_face0.jpg
# 파일 이동 완료 : 11855A47_face0.jpg
# 파일 이동 완료 : 07360A80_face0.jpg
# 파일 이동 완료 : 12429A56_face0.jpg
# 파일 이동 완료 : 13292A79_face0.jpg
# 파일 이동 완료 : 11825A47_face0.jpg
# 파일 이동 완료 : 04723A36_face0.jpg
# 파일 이동 완료 : 00572A10_face1.jpg
# 파일 이동 완료 : 08199A16_face0.jpg
# 파일 이동 완료 : 13274A78_face0.jpg
# 파일 이동 완료 : 05499A42_face0.jpg
# 파일 이동 완료 : 02949A28_face0.jpg
# 파일 이동 완료 : 06589A56_face0.jpg
# 파일 이동 완료 : 04739A36_face0.jpg
# 파일 이동 완료 : 04439A35_face0.jpg
# 파일 이동 완료 : 01697A23_face0.jpg
# 파일 이동 완료 : 12020A49_face0.jpg
# 파일 이동 완료 : 06341A51_face0.jpg
# 파일 이동 완료 : 00772A13_face0.jpg
# 파일 이동 완료 : 10245A34_face1.jpg
# 파일 이동 완료 : 03229A29_face0.jpg
# 파일 이동 완료 : 00516A09_face0.jpg
# 파일 이동 완료 : 10969A39_face0.jpg
# 파일 이동 완료 : 01228A19_face0.jpg
# 파일 이동 완료 : 07195A71_face0.jpg
# 파일 이동 완료 : 05536A42_face0.jpg
# 파일 이동 완료 : 06868A61_face0.jpg
# 파일 이동 완료 : 10355A35_face1.jpg
# 파일 이동 완료 : 13228A77_face0.jpg
# 파일 이동 완료 : 05127A39_face0.jpg
# 파일 이동 완료 : 04431A35_face0.jpg
# 파일 이동 완료 : 00113A03_face0.jpg
# 파일 이동 완료 : 09775A32_face0.jpg
# 파일 이동 완료 : 06809A60_face0.jpg
# 파일 이동 완료 : 04273A34_face0.jpg
# 파일 이동 완료 : 04378A34_face0.jpg
# 파일 이동 완료 : 02655A27_face0.jpg
# 파일 이동 완료 : 00121A03_face0.jpg
# 파일 이동 완료 : 08489A21_face0.jpg
# 파일 이동 완료 : 08142A14_face0.jpg
# 파일 이동 완료 : 01226A19_face0.jpg
# 파일 이동 완료 : 10621A36_face0.jpg
# 파일 이동 완료 : 08468A21_face0.jpg
# 파일 이동 완료 : 11234A41_face0.jpg
# 파일 이동 완료 : 00945A16_face0.jpg
# 파일 이동 완료 : 13099A72_face0.jpg
# 파일 이동 완료 : 04586A36_face0.jpg
# 파일 이동 완료 : 02917A28_face0.jpg
# 파일 이동 완료 : 03628A31_face0.jpg
# 파일 이동 완료 : 09764A32_face0.jpg
# 파일 이동 완료 : 07748A07_face0.jpg
# 파일 이동 완료 : 09784A32_face0.jpg
# 파일 이동 완료 : 09416A29_face0.jpg
# 파일 이동 완료 : 09985A33_face0.jpg
# 파일 이동 완료 : 05241A40_face0.jpg
# 파일 이동 완료 : 06601A56_face0.jpg
# 파일 이동 완료 : 10324A35_face0.jpg
# 파일 이동 완료 : 01880A24_face0.jpg
# 파일 이동 완료 : 07357A80_face0.jpg
# 파일 이동 완료 : 00737A13_face0.jpg
# 파일 이동 완료 : 00278A05_face0.jpg
# 파일 이동 완료 : 09604A31_face0.jpg
# 파일 이동 완료 : 00213A04_face0.jpg
# 파일 이동 완료 : 12346A54_face0.jpg
# 파일 이동 완료 : 12792A62_face0.jpg
# 파일 이동 완료 : 10196A34_face0.jpg
# 파일 이동 완료 : 06732A59_face0.jpg
# 파일 이동 완료 : 10564A36_face0.jpg
# 파일 이동 완료 : 02796A27_face0.jpg
# 파일 이동 완료 : 01240A19_face0.jpg
# 파일 이동 완료 : 12356A55_face0.jpg
# 파일 이동 완료 : 00965A16_face0.jpg
# 파일 이동 완료 : 05873A45_face0.jpg
# 파일 이동 완료 : 03282A29_face0.jpg
# 파일 이동 완료 : 01509A21_face0.jpg
# 파일 이동 완료 : 11573A44_face0.jpg
# 파일 이동 완료 : 08527A22_face0.jpg
# 파일 이동 완료 : 05219A40_face0.jpg
# 파일 이동 완료 : 12314A54_face0.jpg
# 파일 이동 완료 : 06458A54_face0.jpg
# 파일 이동 완료 : 01605A22_face0.jpg
# 파일 이동 완료 : 01632A22_face0.jpg
# 파일 이동 완료 : 10353A35_face0.jpg
# 파일 이동 완료 : 12156A52_face0.jpg
# 파일 이동 완료 : 09998A33_face0.jpg
# 파일 이동 완료 : 04430A35_face0.jpg
# 파일 이동 완료 : 01740A23_face0.jpg
# 파일 이동 완료 : 01399A21_face0.jpg
# 파일 이동 완료 : 09570A31_face0.jpg
# 파일 이동 완료 : 06609A56_face1.jpg
# 파일 이동 완료 : 06651A57_face0.jpg
# 파일 이동 완료 : 08457A20_face0.jpg
# 파일 이동 완료 : 08318A18_face0.jpg
# 파일 이동 완료 : 13023A69_face0.jpg
# 파일 이동 완료 : 00634A11_face0.jpg
# 파일 이동 완료 : 02251A26_face0.jpg
# 파일 이동 완료 : 05877A45_face0.jpg
# 파일 이동 완료 : 12169A52_face0.jpg
# 파일 이동 완료 : 04321A34_face1.jpg
# 파일 이동 완료 : 06270A50_face0.jpg
# 파일 이동 완료 : 03578A31_face0.jpg
# 파일 이동 완료 : 10179A34_face1.jpg
# 파일 이동 완료 : 10269A34_face0.jpg
# 파일 이동 완료 : 04473A35_face0.jpg
# 파일 이동 완료 : 10767A37_face0.jpg
# 파일 이동 완료 : 08679A24_face0.jpg
# 파일 이동 완료 : 00412A08_face0.jpg
# 파일 이동 완료 : 03198A29_face0.jpg
# 파일 이동 완료 : 09273A29_face0.jpg
# 파일 이동 완료 : 13019A69_face0.jpg
# 파일 이동 완료 : 11935A48_face0.jpg
# 파일 이동 완료 : 03711A31_face0.jpg
# 파일 이동 완료 : 11928A48_face0.jpg
# 파일 이동 완료 : 04539A35_face0.jpg
# 파일 이동 완료 : 08033A12_face0.jpg
# 파일 이동 완료 : 09553A30_face0.jpg
# 파일 이동 완료 : 04076A33_face0.jpg
# 파일 이동 완료 : 00545A10_face0.jpg
# 파일 이동 완료 : 03166A29_face0.jpg
# 파일 이동 완료 : 09177A28_face0.jpg
# 파일 이동 완료 : 11984A49_face0.jpg
# 파일 이동 완료 : 04800A37_face0.jpg
# 파일 이동 완료 : 08522A22_face0.jpg
# 파일 이동 완료 : 05169A40_face0.jpg
# 파일 이동 완료 : 08159A15_face0.jpg
# 파일 이동 완료 : 07004A66_face0.jpg
# 파일 이동 완료 : 04587A36_face0.jpg
# 파일 이동 완료 : 05075A39_face0.jpg
# 파일 이동 완료 : 02939A28_face0.jpg
# 파일 이동 완료 : 11140A40_face0.jpg
# 파일 이동 완료 : 03683A31_face0.jpg
# 파일 이동 완료 : 01273A20_face0.jpg
# 파일 이동 완료 : 08953A27_face0.jpg
# 파일 이동 완료 : 09374A29_face0.jpg
# 파일 이동 완료 : 08977A27_face0.jpg
# 파일 이동 완료 : 06894A62_face0.jpg
# 파일 이동 완료 : 05444A41_face0.jpg
# 파일 이동 완료 : 06727A59_face0.jpg
# 파일 이동 완료 : 09771A32_face0.jpg
# 파일 이동 완료 : 11979A49_face0.jpg
# 파일 이동 완료 : 00920A15_face0.jpg
# 파일 이동 완료 : 11777A47_face0.jpg
# 파일 이동 완료 : 09152A28_face0.jpg
# 파일 이동 완료 : 12600A58_face0.jpg
# 파일 이동 완료 : 12042A49_face0.jpg
# 파일 이동 완료 : 04018A33_face0.jpg
# 파일 이동 완료 : 00259A05_face0.jpg
# 파일 이동 완료 : 03662A31_face0.jpg
# 파일 이동 완료 : 13161A74_face0.jpg
# 파일 이동 완료 : 05013A38_face0.jpg
# 파일 이동 완료 : 10477A36_face0.jpg
# 파일 이동 완료 : 08927A26_face0.jpg
# 파일 이동 완료 : 13039A70_face0.jpg
# 파일 이동 완료 : 05374A41_face0.jpg
# 파일 이동 완료 : 06470A54_face0.jpg
# 파일 이동 완료 : 01596A22_face0.jpg
# 파일 이동 완료 : 11859A47_face0.jpg
# 파일 이동 완료 : 04989A38_face0.jpg
# 파일 이동 완료 : 10437A35_face0.jpg
# 파일 이동 완료 : 11279A42_face0.jpg
# 파일 이동 완료 : 06683A58_face0.jpg
# 파일 이동 완료 : 06427A53_face0.jpg
# 파일 이동 완료 : 00269A05_face0.jpg
# 파일 이동 완료 : 00061A02_face0.jpg
# 파일 이동 완료 : 12137A51_face1.jpg
# 파일 이동 완료 : 13293A79_face0.jpg
# 파일 이동 완료 : 00794A14_face0.jpg
# 파일 이동 완료 : 06713A58_face0.jpg
# 파일 이동 완료 : 10630A36_face0.jpg
# 파일 이동 완료 : 03374A29_face0.jpg
# 파일 이동 완료 : 01753A23_face0.jpg
# 파일 이동 완료 : 00156A04_face0.jpg
# 파일 이동 완료 : 11904A48_face0.jpg
# 파일 이동 완료 : 04720A36_face0.jpg
# 파일 이동 완료 : 11910A48_face0.jpg
# 파일 이동 완료 : 04080A33_face0.jpg
# 파일 이동 완료 : 07447A02_face0.jpg
# 파일 이동 완료 : 11243A41_face0.jpg
# 파일 이동 완료 : 08226A16_face0.jpg
# 파일 이동 완료 : 07708A07_face0.jpg
# 파일 이동 완료 : 06276A50_face0.jpg
# 파일 이동 완료 : 01660A22_face0.jpg
# 파일 이동 완료 : 05990A46_face0.jpg
# 파일 이동 완료 : 08618A23_face0.jpg
# 파일 이동 완료 : 06422A53_face0.jpg
# 파일 이동 완료 : 09691A31_face0.jpg
# 파일 이동 완료 : 00527A09_face0.jpg
# 파일 이동 완료 : 09073A28_face0.jpg
# 파일 이동 완료 : 13022A69_face0.jpg
# 파일 이동 완료 : 03912A32_face0.jpg
# 파일 이동 완료 : 08897A26_face0.jpg
# 파일 이동 완료 : 02875A27_face0.jpg
# 파일 이동 완료 : 00444A08_face0.jpg
# 파일 이동 완료 : 05999A46_face0.jpg
# 파일 이동 완료 : 02424A26_face0.jpg
# 파일 이동 완료 : 00748A13_face0.jpg
# 파일 이동 완료 : 12813A63_face0.jpg
# 파일 이동 완료 : 03207A29_face0.jpg
# 파일 이동 완료 : 10452A35_face0.jpg
# 파일 이동 완료 : 12009A49_face0.jpg
# 파일 이동 완료 : 11354A42_face0.jpg
# 파일 이동 완료 : 11051A40_face0.jpg
# 파일 이동 완료 : 03883A32_face0.jpg
# 파일 이동 완료 : 12497A56_face0.jpg
# 파일 이동 완료 : 02757A27_face0.jpg
# 파일 이동 완료 : 12459A56_face0.jpg
# 파일 이동 완료 : 12483A56_face0.jpg
# 파일 이동 완료 : 08191A15_face0.jpg
# 파일 이동 완료 : 04562A35_face0.jpg
# 파일 이동 완료 : 10118A33_face0.jpg
# 파일 이동 완료 : 07389A02_face0.jpg
# 파일 이동 완료 : 10660A37_face0.jpg
# 파일 이동 완료 : 00750A13_face0.jpg
# 파일 이동 완료 : 04666A36_face0.jpg
# 파일 이동 완료 : 03195A29_face0.jpg
# 파일 이동 완료 : 00330A06_face0.jpg
# 파일 이동 완료 : 04236A34_face0.jpg
# 파일 이동 완료 : 05100A39_face0.jpg
# 파일 이동 완료 : 06566A56_face0.jpg
# 파일 이동 완료 : 01739A23_face0.jpg
# 파일 이동 완료 : 04502A35_face0.jpg
# 파일 이동 완료 : 06187A49_face0.jpg
# 파일 이동 완료 : 08501A22_face0.jpg
# 파일 이동 완료 : 12030A49_face0.jpg
# 파일 이동 완료 : 04968A38_face0.jpg
# 파일 이동 완료 : 00496A09_face0.jpg
# 파일 이동 완료 : 05018A38_face0.jpg
# 파일 이동 완료 : 03929A32_face0.jpg
# 파일 이동 완료 : 08719A24_face0.jpg
# 파일 이동 완료 : 12875A64_face0.jpg
# 파일 이동 완료 : 06159A48_face0.jpg
# 파일 이동 완료 : 07425A02_face0.jpg
# 파일 이동 완료 : 03054A28_face0.jpg
# 파일 이동 완료 : 11933A48_face0.jpg
# 파일 이동 완료 : 07962A11_face0.jpg
# 파일 이동 완료 : 03026A28_face0.jpg
# 파일 이동 완료 : 08590A23_face0.jpg
# 파일 이동 완료 : 12201A52_face0.jpg
# 파일 이동 완료 : 06050A47_face0.jpg
# 파일 이동 완료 : 11267A41_face0.jpg
# 파일 이동 완료 : 11574A44_face0.jpg
# 파일 이동 완료 : 04178A33_face0.jpg
# 파일 이동 완료 : 01801A23_face0.jpg
# 파일 이동 완료 : 00551A10_face0.jpg
# 파일 이동 완료 : 04687A36_face0.jpg
# 파일 이동 완료 : 11193A41_face0.jpg
# 파일 이동 완료 : 08390A19_face0.jpg
# 파일 이동 완료 : 08579A23_face0.jpg
# 파일 이동 완료 : 09116A28_face0.jpg
# 파일 이동 완료 : 07957A11_face0.jpg
# 파일 이동 완료 : 05835A45_face0.jpg
# 파일 이동 완료 : 04508A35_face0.jpg
# 파일 이동 완료 : 05730A44_face0.jpg
# 파일 이동 완료 : 00122A03_face0.jpg
# 파일 이동 완료 : 01585A22_face0.jpg
# 파일 이동 완료 : 03572A31_face0.jpg
# 파일 이동 완료 : 02426A26_face0.jpg
# 파일 이동 완료 : 01463A21_face0.jpg
# 파일 이동 완료 : 04034A33_face0.jpg
# 파일 이동 완료 : 04002A33_face0.jpg
# 파일 이동 완료 : 01621A22_face0.jpg
# 파일 이동 완료 : 08647A23_face0.jpg
# 파일 이동 완료 : 03639A31_face0.jpg
# 파일 이동 완료 : 05530A42_face0.jpg
# 파일 이동 완료 : 04143A33_face0.jpg
# 파일 이동 완료 : 11438A43_face0.jpg
# 파일 이동 완료 : 07162A70_face0.jpg
# 파일 이동 완료 : 07662A06_face0.jpg
# 파일 이동 완료 : 05266A40_face0.jpg
# 파일 이동 완료 : 11380A42_face0.jpg
# 파일 이동 완료 : 00816A14_face0.jpg
# 파일 이동 완료 : 00935A16_face0.jpg
# 파일 이동 완료 : 07525A04_face0.jpg
# 파일 이동 완료 : 09744A32_face0.jpg
# 파일 이동 완료 : 07689A06_face0.jpg
# 파일 이동 완료 : 11297A42_face0.jpg
# 파일 이동 완료 : 00038A02_face0.jpg
# 파일 이동 완료 : 01758A23_face0.jpg

# %%
print('Training data의 my_face 이미지 수 : ', len(os.listdir('/content/tr_data/my')))
print('Training data의 other_face 이미지 수 : ', len(os.listdir('/content/tr_data/other')))

print('Test data의 my_face 이미지 수 : ', len(os.listdir('/content/te_data/my')))
print('Test data의 other_face 이미지 수 : ', len(os.listdir('/content/te_data/other')))
# Out:
# Training data의 my_face 이미지 수 :  4320
# Training data의 other_face 이미지 수 :  4320
# Test data의 my_face 이미지 수 :  1080
# Test data의 other_face 이미지 수 :  1080

# %% [markdown]
# #### 2) **특정 함수** 사용

# %%
## Training set 데이터 폴더를 데이터셋화
## 이 과정에서 Validation set도 생성
tr_idfd, val_idfd = image_dataset_from_directory(tr_data,                    ## Training 폴더 경로
                                                 class_names=['other','my'], ## 클래스 순서 지정
                                                 batch_size=32,              ## 이미지 덩어리 단위
                                                 image_size=(160,160),       ## 이미지 리사이즈
                                                 shuffle=True,               ## 섞어야 올바르게 분할됨
                                                 seed=2024,                  ## 재현성
                                                 validation_split=0.2,       ## 데이터 스플릿 비율
                                                 subset='both',              ## 데이터셋 나눔 방식
                                                 )
# Out:
# Found 8640 files belonging to 2 classes.
# Using 6912 files for training.
# Using 1728 files for validation.

# %%
## Test set 데이터 폴더를 데이터셋화
te_idfd = image_dataset_from_directory(te_data,                    ## Test 폴더 경로
                                       class_names=['other','my'], ## 클래스 순서 지정
                                       batch_size=32,              ## 이미지 덩어리 단위
                                       image_size=(160,160),       ## 이미지 리사이즈
                                       shuffle=True,               ## 섞어야 올바르게 분할됨
                                       seed=2024                   ## 재현성
                                       )
# Out:
# Found 2160 files belonging to 2 classes.

# %%
## 위에서 만든 이미지 데이터 덩어리가 몇 개인지 확인
len(tr_idfd), len(val_idfd), len(te_idfd)
# Out:
# (216, 54, 68)

# %%
192*32, 48*32, 60*32
# Out:
# (6144, 1536, 1920)

# %%
tr_idfd
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# #### 3) 스케일링

# %%
def rescale(image, label) :
    image = image / 255
    return image, label

# %%
tr_idfd_rescale = tr_idfd.map(rescale)
val_idfd_rescale = val_idfd.map(rescale)
te_idfd_rescale = te_idfd.map(rescale)

# %% [markdown]
# ## 4.미션2

# %% [markdown]
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (1) FaceNet 구조 생성

# %% [markdown]
# * **세부 요구사항**
#     - FaceNet의 구조를 생성합니다.
#         - FaceNet 구조 생성에 필요한 함수를 만듭니다.
#     - FaceNet의 구조에 **잘 학습된 가중치**를 부여합니다.
#         - FaceNet 원본 가중치 파일을 공유하였습니다.
#     - (선택사항) FaceNet 모델의 가중치 업데이트를 방지합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - numpy, functools, keras

# %% [markdown]
# #### 1) 모델 구조 생성

# %%
import numpy as np
from functools import partial


import keras
from keras.models import Model

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation
from keras.layers import BatchNormalization, Dropout, GlobalAveragePooling2D
from keras.layers import Lambda, Concatenate, add

from keras import backend as K
from keras.saving import register_keras_serializable

# %%
## 3.6.0.dev2024102803 OK
keras.__version__
# Out:
# '3.7.0.dev2024103103'

# %%
@register_keras_serializable()
def scaling(x, scale):
    return x * scale

@register_keras_serializable()
def conv2d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              use_bias=False,
              name=None):
    x = Conv2D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               use_bias=use_bias,
               name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, momentum=0.995, epsilon=0.001,
                               scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = _generate_layer_name('Activation', prefix=name)
        x = Activation(activation, name=ac_name)(x)
    return x

@register_keras_serializable()
def _generate_layer_name(name, branch_idx=None, prefix=None):
    if prefix is None:
        return None
    if branch_idx is None:
        return '_'.join((prefix, name))
    return '_'.join((prefix, 'Branch', str(branch_idx), name))

@register_keras_serializable()
def _inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    if block_idx is None:
        prefix = None
    else:
        prefix = '_'.join((block_type, str(block_idx)))
    name_fmt = partial(_generate_layer_name, prefix=prefix)

    if block_type == 'Block35':
        branch_0 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 32, 3, name=name_fmt('Conv2d_0b_3x3', 1))
        branch_2 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0b_3x3', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0c_3x3', 2))
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Block17':
        branch_0 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 128, [1, 7], name=name_fmt('Conv2d_0b_1x7', 1))
        branch_1 = conv2d_bn(branch_1, 128, [7, 1], name=name_fmt('Conv2d_0c_7x1', 1))
        branches = [branch_0, branch_1]
    elif block_type == 'Block8':
        branch_0 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 192, [1, 3], name=name_fmt('Conv2d_0b_1x3', 1))
        branch_1 = conv2d_bn(branch_1, 192, [3, 1], name=name_fmt('Conv2d_0c_3x1', 1))
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "Block35", "Block17" or "Block8", '
                         'but got: ' + str(block_type))

    mixed = Concatenate(axis=channel_axis, name=name_fmt('Concatenate'))(branches)
    up = conv2d_bn(mixed,
                #    K.int_shape(x)[channel_axis],
                   x.shape[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name=name_fmt('Conv2d_1x1'))
    up = Lambda(scaling,
                # output_shape=K.int_shape(up)[1:],
                output_shape=up.shape[1:],
                arguments={'scale': scale})(up)
    x = add([x, up])
    if activation is not None:
        x = Activation(activation, name=name_fmt('Activation'))(x)
    return x

# %%
@register_keras_serializable()
def InceptionResNetV1(input_shape=(160, 160, 3),
                      classes=128,
                      dropout_keep_prob=0.8,
                      weights_path=None):
    inputs = Input(shape=input_shape)
    x = conv2d_bn(inputs, 32, 3, strides=2, padding='valid', name='Conv2d_1a_3x3')
    x = conv2d_bn(x, 32, 3, padding='valid', name='Conv2d_2a_3x3')
    x = conv2d_bn(x, 64, 3, name='Conv2d_2b_3x3')
    x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
    x = conv2d_bn(x, 80, 1, padding='valid', name='Conv2d_3b_1x1')
    x = conv2d_bn(x, 192, 3, padding='valid', name='Conv2d_4a_3x3')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid', name='Conv2d_4b_3x3')

    # 5x Block35 (Inception-ResNet-A block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.17,
                                    block_type='Block35',
                                    block_idx=block_idx)

    # Mixed 6a (Reduction-A block):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    name_fmt = partial(_generate_layer_name, prefix='Mixed_6a')
    branch_0 = conv2d_bn(x,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1, 192, 3, name=name_fmt('Conv2d_0b_3x3', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 2))(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_6a')(branches)

    # 10x Block17 (Inception-ResNet-B block):
    for block_idx in range(1, 11):
        x = _inception_resnet_block(x,
                                    scale=0.1,
                                    block_type='Block17',
                                    block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    name_fmt = partial(_generate_layer_name, prefix='Mixed_7a')
    branch_0 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 0))
    branch_0 = conv2d_bn(branch_0,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_2 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 2))
    branch_2 = conv2d_bn(branch_2, 256, 3, name=name_fmt('Conv2d_0b_3x3', 2))
    branch_2 = conv2d_bn(branch_2,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 2))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 3))(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_7a')(branches)

    # 5x Block8 (Inception-ResNet-C block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.2,
                                    block_type='Block8',
                                    block_idx=block_idx)
    x = _inception_resnet_block(x,
                                scale=1.,
                                activation=None,
                                block_type='Block8',
                                block_idx=6)

    # Classification block
    x = GlobalAveragePooling2D(name='AvgPool')(x)
    x = Dropout(1.0 - dropout_keep_prob, name='Dropout')(x)
    # Bottleneck
    x = Dense(classes, use_bias=False, name='Bottleneck')(x)
    bn_name = _generate_layer_name('BatchNorm', prefix='Bottleneck')
    x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False,
                           name=bn_name)(x)

    # Create model
    model = Model(inputs, x, name='inception_resnet_v1')
    if weights_path is not None:
        model.load_weights(weights_path)

    return model

# %%
## FaceNet 구조 생성 코드
facenet_model = InceptionResNetV1()

# %%
## FaceNet 구조의 전체 레이어 길이
len(facenet_model.layers)
# Out:
# 447

# %%
## FaceNet 전체 구조 확인
facenet_model.summary()
# Out:
# Model: "inception_resnet_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 160, 160, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)    │ (None, 79, 79, 32)     │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm   │ (None, 79, 79, 32)     │             96 │ Conv2d_1a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_Activation  │ (None, 79, 79, 32)     │              0 │ Conv2d_1a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3 (Conv2D)    │ (None, 77, 77, 32)     │          9,216 │ Conv2d_1a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_BatchNorm   │ (None, 77, 77, 32)     │             96 │ Conv2d_2a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_Activation  │ (None, 77, 77, 32)     │              0 │ Conv2d_2a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3 (Conv2D)    │ (None, 77, 77, 64)     │         18,432 │ Conv2d_2a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_BatchNorm   │ (None, 77, 77, 64)     │            192 │ Conv2d_2b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_Activation  │ (None, 77, 77, 64)     │              0 │ Conv2d_2b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MaxPool_3a_3x3            │ (None, 38, 38, 64)     │              0 │ Conv2d_2b_3x3_Activat… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1 (Conv2D)    │ (None, 38, 38, 80)     │          5,120 │ MaxPool_3a_3x3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_BatchNorm   │ (None, 38, 38, 80)     │            240 │ Conv2d_3b_1x1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_Activation  │ (None, 38, 38, 80)     │              0 │ Conv2d_3b_1x1_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3 (Conv2D)    │ (None, 36, 36, 192)    │        138,240 │ Conv2d_3b_1x1_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_BatchNorm   │ (None, 36, 36, 192)    │            576 │ Conv2d_4a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_Activation  │ (None, 36, 36, 192)    │              0 │ Conv2d_4a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3 (Conv2D)    │ (None, 17, 17, 256)    │        442,368 │ Conv2d_4a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_BatchNorm   │ (None, 17, 17, 256)    │            768 │ Conv2d_4b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_Activation  │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_1_Branch_1_Co… │
# │                           │                        │                │ Block35_1_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 17, 17, 256)    │              0 │ Block35_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_Activat… │
# │                           │                        │                │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Activation      │ (None, 17, 17, 256)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_2_Branch_1_Co… │
# │                           │                        │                │ Block35_2_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_2_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_2_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_1_Activation[… │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Activation      │ (None, 17, 17, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_3_Branch_1_Co… │
# │                           │                        │                │ Block35_3_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_3_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_3_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_2_Activation[… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Activation      │ (None, 17, 17, 256)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_4_Branch_1_Co… │
# │                           │                        │                │ Block35_4_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_4_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_4_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_3_Activation[… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Activation      │ (None, 17, 17, 256)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_5_Branch_1_Co… │
# │                           │                        │                │ Block35_5_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_5_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_5_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_4_Activation[… │
# │                           │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Activation      │ (None, 17, 17, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │         49,152 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │        331,776 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │        884,736 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │        442,368 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │          1,152 │ Mixed_6a_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │            768 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │              0 │ Mixed_6a_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_2_MaxPoo… │ (None, 8, 8, 256)      │              0 │ Block35_5_Activation[… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a (Concatenate)    │ (None, 8, 8, 896)      │              0 │ Mixed_6a_Branch_0_Con… │
# │                           │                        │                │ Mixed_6a_Branch_1_Con… │
# │                           │                        │                │ Mixed_6a_Branch_2_Max… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Concatenate     │ (None, 8, 8, 256)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block17_1_Branch_1_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Conv2d_1x1      │ (None, 8, 8, 896)      │        230,272 │ Block17_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 8, 8, 896)      │              0 │ Block17_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 8, 896)      │              0 │ Mixed_6a[0][0],        │
# │                           │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Activation      │ (None, 8, 8, 896)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ add_17 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_2_Activation[0… │
# │                           │                        │                │ lambda_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_3_Activation       │ (None, 3, 3, 1792)     │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_4_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_4_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_18 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_4_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_3_Activation[0… │
# │                           │                        │                │ lambda_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Activation       │ (None, 3, 3, 1792)     │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_5_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_5_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_19 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_5_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_4_Activation[0… │
# │                           │                        │                │ lambda_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Activation       │ (None, 3, 3, 1792)     │              0 │ add_19[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_6_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_6_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_20 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_6_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_5_Activation[0… │
# │                           │                        │                │ lambda_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AvgPool                   │ (None, 1792)           │              0 │ add_20[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dropout (Dropout)         │ (None, 1792)           │              0 │ AvgPool[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck (Dense)        │ (None, 128)            │        229,376 │ Dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck_BatchNorm      │ (None, 128)            │            384 │ Bottleneck[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,808,144 (87.01 MB)
#  Trainable params: 22,779,312 (86.90 MB)
#  Non-trainable params: 28,832 (112.62 KB)

# %%
from keras.utils import plot_model

# %%
plot_model(facenet_model, show_shapes=True, show_layer_activations=True, show_trainable=True)

# %% [markdown]
# #### 2) 모델에 가중치 적용

# %%
## FaceNet 가중치 파일 경로 설정
weights_path = path + '/Keras/facenet_model_weights.npz'
weights_path
# Out:
# '/content/drive/MyDrive/project4/Keras/facenet_model_weights.npz'

# %%
## 가중치 파일 불러오기
loaded_weights = np.load(weights_path)

loaded_weights
# Out:
# NpzFile '/content/drive/MyDrive/project4/Keras/facenet_model_weights.npz' with keys: arr_0, arr_1, arr_2, arr_3, arr_4...

# %%
## FaceNet 각 레이어에 가중치 적용
facenet_model.set_weights([loaded_weights[key] for key in loaded_weights])

# %% [markdown]
# #### 3) 모델의 가중치 업데이트 방지 (선택사항)

# %%
## FaceNet 전체 레이어에서 마지막 2개의 레이어 확인
facenet_model.layers[-2:]
# Out:
# [<Dense name=Bottleneck, built=True>,
#  <BatchNormalization name=Bottleneck_BatchNorm, built=True>]

# %%
# ## FaceNet 전체 레이어에서 마지막 4개의 레이어에만 가중치 업데이트 적용
# for l in facenet_model.layers[:-4] :
#     l.trainable = False

# %%
# 사전 학습된 FaceNet 모델의 특정 층을 훈련 가능하게 설정
for layer in facenet_model.layers[:-2]:  # 최상위 2개 층을 Fine-Tuning하도록 설정
    layer.trainable = False
for layer in facenet_model.layers[-2:]:
    layer.trainable = True

# %% [markdown]
# ### (2) 모델 구조 변형

# %% [markdown]
# * **세부 요구사항**
#     - 우리의 문제에 맞게 모델을 변형해야 합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 추가 모델링

# %%
import tensorflow as tf

# 기존 FaceNet 모델에 새로운 출력층 추가
hl = facenet_model.output
# hl = Dense(512, activation='relu')(hl)       # 추가 Dense 층, 노드 수 증가
# hl = Dense(256, activation='relu')(hl)       # 추가 Dense 층, 노드 수 증가
hl = Dense(128, activation='relu')(hl)       # 추가 Dense 층, 노드 수 증가
hl = tf.keras.layers.BatchNormalization()(hl) # 배치 정규화
# hl = Dropout(0.5)(hl)                         # 과적합 방지용 드롭아웃
hl = Dense(64, activation='relu')(hl)
hl = Dropout(0.5)(hl)
ol = Dense(1, activation='sigmoid')(hl)       # 이진 분류용 최종 출력층

custom_model = Model(inputs=facenet_model.input, outputs=ol)

# %%
custom_model.summary() ## keras-nightly로는 정상 작동
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 160, 160, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)    │ (None, 79, 79, 32)     │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm   │ (None, 79, 79, 32)     │             96 │ Conv2d_1a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_Activation  │ (None, 79, 79, 32)     │              0 │ Conv2d_1a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3 (Conv2D)    │ (None, 77, 77, 32)     │          9,216 │ Conv2d_1a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_BatchNorm   │ (None, 77, 77, 32)     │             96 │ Conv2d_2a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_Activation  │ (None, 77, 77, 32)     │              0 │ Conv2d_2a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3 (Conv2D)    │ (None, 77, 77, 64)     │         18,432 │ Conv2d_2a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_BatchNorm   │ (None, 77, 77, 64)     │            192 │ Conv2d_2b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_Activation  │ (None, 77, 77, 64)     │              0 │ Conv2d_2b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MaxPool_3a_3x3            │ (None, 38, 38, 64)     │              0 │ Conv2d_2b_3x3_Activat… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1 (Conv2D)    │ (None, 38, 38, 80)     │          5,120 │ MaxPool_3a_3x3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_BatchNorm   │ (None, 38, 38, 80)     │            240 │ Conv2d_3b_1x1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_Activation  │ (None, 38, 38, 80)     │              0 │ Conv2d_3b_1x1_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3 (Conv2D)    │ (None, 36, 36, 192)    │        138,240 │ Conv2d_3b_1x1_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_BatchNorm   │ (None, 36, 36, 192)    │            576 │ Conv2d_4a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_Activation  │ (None, 36, 36, 192)    │              0 │ Conv2d_4a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3 (Conv2D)    │ (None, 17, 17, 256)    │        442,368 │ Conv2d_4a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_BatchNorm   │ (None, 17, 17, 256)    │            768 │ Conv2d_4b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_Activation  │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_1_Branch_1_Co… │
# │                           │                        │                │ Block35_1_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 17, 17, 256)    │              0 │ Block35_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_Activat… │
# │                           │                        │                │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Activation      │ (None, 17, 17, 256)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_2_Branch_1_Co… │
# │                           │                        │                │ Block35_2_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_2_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_2_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_1_Activation[… │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Activation      │ (None, 17, 17, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_3_Branch_1_Co… │
# │                           │                        │                │ Block35_3_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_3_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_3_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_2_Activation[… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Activation      │ (None, 17, 17, 256)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_4_Branch_1_Co… │
# │                           │                        │                │ Block35_4_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_4_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_4_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_3_Activation[… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Activation      │ (None, 17, 17, 256)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_5_Branch_1_Co… │
# │                           │                        │                │ Block35_5_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_5_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_5_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_4_Activation[… │
# │                           │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Activation      │ (None, 17, 17, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │         49,152 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │        331,776 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │        884,736 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │        442,368 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │          1,152 │ Mixed_6a_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │            768 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │              0 │ Mixed_6a_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_2_MaxPoo… │ (None, 8, 8, 256)      │              0 │ Block35_5_Activation[… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a (Concatenate)    │ (None, 8, 8, 896)      │              0 │ Mixed_6a_Branch_0_Con… │
# │                           │                        │                │ Mixed_6a_Branch_1_Con… │
# │                           │                        │                │ Mixed_6a_Branch_2_Max… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Concatenate     │ (None, 8, 8, 256)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block17_1_Branch_1_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Conv2d_1x1      │ (None, 8, 8, 896)      │        230,272 │ Block17_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 8, 8, 896)      │              0 │ Block17_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 8, 896)      │              0 │ Mixed_6a[0][0],        │
# │                           │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Activation      │ (None, 8, 8, 896)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_4_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_4_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_18 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_4_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_3_Activation[0… │
# │                           │                        │                │ lambda_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Activation       │ (None, 3, 3, 1792)     │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_5_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_5_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_19 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_5_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_4_Activation[0… │
# │                           │                        │                │ lambda_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Activation       │ (None, 3, 3, 1792)     │              0 │ add_19[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_6_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_6_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_20 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_6_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_5_Activation[0… │
# │                           │                        │                │ lambda_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AvgPool                   │ (None, 1792)           │              0 │ add_20[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dropout (Dropout)         │ (None, 1792)           │              0 │ AvgPool[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck (Dense)        │ (None, 128)            │        229,376 │ Dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck_BatchNorm      │ (None, 128)            │            384 │ Bottleneck[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         16,512 │ Bottleneck_BatchNorm[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 128)            │            512 │ dense[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 64)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │             65 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,833,489 (87.10 MB)
#  Trainable params: 254,593 (994.50 KB)
#  Non-trainable params: 22,578,896 (86.13 MB)

# %%
from tensorflow.keras.optimizers import Adam

custom_model.compile(
    optimizer=Adam(learning_rate=0.001),  # learn_rate 대신 learning_rate 사용
    loss='binary_crossentropy',
    metrics=['accuracy', 'Precision', 'Recall']  # 'Precision', 'Recall' 대문자로 표기
)

# %% [markdown]
# ## 5.미션3

# %% [markdown]
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ### (1) 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 모델 구조를 잘 변형하였다면, 학습도 진행해야 합니다.
#         - Keras에서 지원하는 다양한 함수를 사용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 학습에 유용한 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %%
# ## 얼리스토핑 설정
# es = EarlyStopping(patience=3, verbose=1, restore_best_weights=True)

## 얼리스토핑 설정
es = EarlyStopping(monitor = 'val_loss',  # ES 기준
                   patience = 3,  # 성능 개선이 발생하지 않을 때, epochs를 얼마나 더 볼 것인가
                   verbose = 1,
                   restore_best_weights = True, # 학습이 멈췄을 때, 최적의 가중치를 가진 epochs 시점으로 돌아가서 저장
                   )

# %% [markdown]
# #### 2) 모델 학습

# %%
## 모델 학습 ## 모델 학습 / 0~1로 리스케일한 train 데이터와 valid 데이터 사용
history = custom_model.fit(tr_idfd_rescale, validation_data=val_idfd_rescale,
                 epochs=10, verbose=1,
                 callbacks=[es]
                 ).history
# Out:
# Epoch 1/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 40s 86ms/step - Precision: 0.9145 - Recall: 0.9507 - accuracy: 0.9315 - loss: 0.1512 - val_Precision: 0.9737 - val_Recall: 1.0000 - val_accuracy: 0.9867 - val_loss: 0.0370
# Epoch 2/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 24s 58ms/step - Precision: 0.9876 - Recall: 0.9988 - accuracy: 0.9931 - loss: 0.0213 - val_Precision: 0.9953 - val_Recall: 1.0000 - val_accuracy: 0.9977 - val_loss: 0.0041
# Epoch 3/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - Precision: 0.9963 - Recall: 0.9970 - accuracy: 0.9966 - loss: 0.0123 - val_Precision: 0.9988 - val_Recall: 1.0000 - val_accuracy: 0.9994 - val_loss: 0.0015
# Epoch 4/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - Precision: 0.9970 - Recall: 0.9983 - accuracy: 0.9976 - loss: 0.0078 - val_Precision: 1.0000 - val_Recall: 1.0000 - val_accuracy: 1.0000 - val_loss: 4.4956e-04
# Epoch 5/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - Precision: 0.9996 - Recall: 0.9989 - accuracy: 0.9992 - loss: 0.0043 - val_Precision: 0.9988 - val_Recall: 1.0000 - val_accuracy: 0.9994 - val_loss: 0.0018
# Epoch 6/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - Precision: 0.9956 - Recall: 0.9988 - accuracy: 0.9972 - loss: 0.0081 - val_Precision: 1.0000 - val_Recall: 1.0000 - val_accuracy: 1.0000 - val_loss: 9.0566e-04
# Epoch 7/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - Precision: 0.9983 - Recall: 0.9990 - accuracy: 0.9987 - loss: 0.0041 - val_Precision: 0.9988 - val_Recall: 1.0000 - val_accuracy: 0.9994 - val_loss: 5.3289e-04
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
import matplotlib.pyplot as plt

# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %%
dl_history_plot(history)

# %% [markdown]
# ### (2) 모델 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습된 모델의 성능을 확인해보세요.
#         - 임계값 조절, 클래스 가중치 부여 등으로 모델의 성능을 높여보세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras, sklearn

# %% [markdown]
# #### 1) 모델 추론

# %%
## image_dataset_from_directory로 만든 Test set로 예측값 생성
y_pred = custom_model.predict(te_idfd_rescale)
y_pred
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 167ms/step
# array([[7.7166567e-07],
#        [9.9986088e-01],
#        [9.9981624e-01],
#        ...,
#        [9.9999511e-01],
#        [9.9993742e-01],
#        [9.9940228e-01]], dtype=float32)

# %%
## 예측값에 대한 임계값을 0.5로 설정하여 0과 1로 구분
y_pred_fix = np.where(y_pred>=0.5, 1, 0)
y_pred_fix = y_pred_fix.flatten()
y_pred_fix
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
len(y_pred_fix.nonzero()[0])
# Out:
# 1080

# %% [markdown]
# #### 2) 성능 확인

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
## 성능 확인을 위하여 Test set의 Y만 떼와 array로 저장
temp = []

for te_x, te_y in te_idfd :
    temp.append(te_y.numpy())

y_true = np.concatenate(temp)

# %%
len(y_true.nonzero()[0])
# Out:
# 1080

# %%
print(f"정확도: {accuracy_score(y_true, y_pred_fix):.6f}")
print(classification_report(y_true, y_pred_fix, target_names=['other', 'my']) )
# Out:
# 정확도: 0.508333
#               precision    recall  f1-score   support
#
#        other       0.51      0.51      0.51      1080
#           my       0.51      0.51      0.51      1080
#
#     accuracy                           0.51      2160
#    macro avg       0.51      0.51      0.51      2160
# weighted avg       0.51      0.51      0.51      2160

# %% [markdown]
# ### (3) 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - **반드시 반드시 모델을 저장하고 로컬에 다운로드하세요.**
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 모델 저장

# %%
## .keras로 저장해야 안전
custom_model.save('facenet_weight_4_layer_2_data_1_2218_data_2_3218.keras')

# %% [markdown]
# #### 2) 저장된 모델 체크

# %%
## Colab에 저장된 모델을 불러와 확인
temp_model = keras.saving.load_model('./FaceNet_1028.keras')
temp_model.summary()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# classification report 생성
report = classification_report(y_true, y_pred_fix, output_dict=True, target_names=['lfw', 'myface'])

df = pd.DataFrame(report).transpose()

df.drop(['accuracy'], axis = 0, inplace = True)
df.drop(['macro avg'], axis = 0, inplace = True)
df.drop(['weighted avg'], axis = 0, inplace = True)

# 히트맵 그리기
plt.figure(figsize=(10, 6))
sns.heatmap(df.iloc[:, :-2], annot=True, cmap="YlGnBu", cbar=True, fmt=".2f")
plt.title("my_face_A")
plt.show()
