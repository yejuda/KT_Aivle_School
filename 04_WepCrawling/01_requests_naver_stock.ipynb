# %% [markdown]
# ## Web Crawling
# - 웹 페이지에서 데이터를 수집하는 방법에 대해서 학습

# %% [markdown]
# ### 웹크롤링 방법
#
# #### 웹페이지의 종류
# - 정적인 페이지 : 웹 브라우져에 화면이 한번 뜨면 이벤트에 의한 화면의 변경이 없는 페이지
# - 동적인 페이지 : 웹 브라우져에 화면이 뜨고 이벤트가 발생하면 서버에서 데이터를 가져와 화면을 변경하는 페이지
#
# #### requests 이용
# - 받아오는 문자열에 따라 두가지 방법으로 구분
#     - json 문자열로 받아서 파싱하는 방법 : 주로 동적 페이지 크롤링할때 사용
#     - html 문자열로 받아서 파싱하는 방법 : 주로 정적 페이지 크롤링할때 사용
#
# #### selenium 이용
# - 브라우져를 직접 열어서 데이터를 받는 방법
#
# #### 크롤링 방법에 따른 속도
# - requests json > requests html >>>>> selenium
# - 정적: HTML, 동적: json
# - HTML은 태그(\<p>)라서 parsing이 오래 걸린다.

# %% [markdown]
# ### Crawling Naver Stock Datas
# - 네이버 증권 사이트에서 주가 데이터 수집
# - 수집할 데이터 : 일별 kospi, kosdaq 주가, 일별 환율(exchange rate) 데이터
# - 데이터 수집 절차
#     - 웹서비스 분석 : url: chrome devtool
#     - 서버에 데이터 요청 : request(url) > response : json(str)
#     - 서버에서 받은 데이터 파싱(데이터 형태를 변경) : json(str) > list, dict > DataFrame

# %%
import requests
import pandas as pd

# %% [markdown]
# #### 1. 웹서비스 분석 : url
# - pc 웹페이지가 복잡하면 mobile 웹페이지에서 수집

# %%
page_size, page = 60, 1     # page가 1부터 시작. 이것은 가장 최근 데이터를 의미
url = f'https://m.stock.naver.com/api/index/KOSPI/price?pageSize={page_size}&page={page}'
url
# Out:
# 'https://m.stock.naver.com/api/index/KOSPI/price?pageSize=60&page=1'

# %% [markdown]
# #### 2. 서버에 데이터 요청 : request(url) > response : json(str)
# - response의 status code가 200이 나오는지 확인
# - 403이나 500이 나오면 request가 잘못되거나 web server에서 수집이 안되도록 설정이 된것임
#     - header 설정 또는 selenium 사용
# - 200이 나오더라도 response 안에 있는 내용을 확인 > 확인하는 방법 : response.text

# %%
# get함수를 쓰는 방법 알기 -> shift + tab
response = requests.get(url)  # requests 패키지 안에 get이라는 함수를 사용하는 것
response
# Out:
# <Response [200]>

# %%
# response.text

# %%
type(response)  # 객체
# Out:
# requests.models.Response

# %%
type(response.text), response.text[:100]
# Out:
# (str,
#  '[{"localTradedAt":"2024-07-19","closePrice":"2,795.46","compareToPreviousClosePrice":"-28.89","compa')

# %%
# dir(response)

# %% [markdown]
# #### 3. 서버에서 받은 데이터 파싱(데이터 형태를 변경) : json(str) > list, dict > DataFrame

# %%
data = response.json()
type(data), data[:2]
# Out:
# (list,
#  [{'localTradedAt': '2024-09-19',
#    'closePrice': '2,580.80',
#    'compareToPreviousClosePrice': '5.39',
#    'compareToPreviousPrice': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'fluctuationsRatio': '0.21',
#    'openPrice': '2,594.67',
#    'highPrice': '2,598.68',
#    'lowPrice': '2,550.09'},
#   {'localTradedAt': '2024-09-13',
#    'closePrice': '2,575.41',
#    'compareToPreviousClosePrice': '3.32',
#    'compareToPreviousPrice': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'fluctuationsRatio': '0.13',
#    'openPrice': '2,571.81',
#    'highPrice': '2,584.11',
#    'lowPrice': '2,562.91'}])

# %%
df = pd.DataFrame(data)
df = df[['localTradedAt', 'closePrice']]
df.tail(2)
# Out:
#    localTradedAt closePrice
# 58    2024-06-25   2,774.39
# 59    2024-06-24   2,764.73

# %% [markdown]
# #### 4. 함수로 만들기

# %%
def stock_price(code='KOSPI', page=1, page_size=60):
    # URL가져오기
    url = f'https://m.stock.naver.com/api/index/{code}/price?pageSize={page_size}&page={page}'
    # 요청
    response = requests.get(url)  # requests 패키지 안에 get이라는 함수를 사용하는 것 / 해당 사이트에서 request 방식을 get방식을 사용하기 때문에 "requests.get"
    # json으로 바꾸기
    data = response.json()
    return pd.DataFrame(data)[['localTradedAt', 'closePrice']]

# %%
stock_price(page=3, page_size=5)
# Out:
#   localTradedAt closePrice
# 0    2024-09-03   2,664.63
# 1    2024-09-02   2,681.00
# 2    2024-08-30   2,674.31
# 3    2024-08-29   2,662.28
# 4    2024-08-28   2,689.83

# %% [markdown]
# #### 5. 원달러 환율 데이터 수집 : 실습

# %% [markdown]
# * 강사님 주신 링크
# https://m.stock.naver.com/marketindex/exchange/FX_USDKRW
# * 실습 때 한 링크
# https://m.stock.naver.com/domestic/index/KOSPI/total

# %% [markdown]
# ### 코스닥 데이터 수집

# %%
def stock_price(code='KOSPI', page=1, page_size=60):
    # URL가져오기
    url = f'https://m.stock.naver.com/api/index/{code}/price?pageSize={page_size}&page={page}'
    # 요청
    response = requests.get(url)  # requests 패키지 안에 get이라는 함수를 사용하는 것
    # json으로 바꾸기
    data = response.json()
    return pd.DataFrame(data)[['localTradedAt', 'closePrice']]

# %%
# 코스닥 데이터 수집
stock_price('KOSDAQ', page=3, page_size=5)
# Out:
#   localTradedAt closePrice
# 0    2024-09-03     760.37
# 1    2024-09-02     769.21
# 2    2024-08-30     767.66
# 3    2024-08-29     756.04
# 4    2024-08-28     762.50

# %% [markdown]
# ### 원달러 환율 데이터 수집

# %%
# 1. URL
page_size, page = 60, 1
url = f'https://m.stock.naver.com/front-api/marketIndex/prices?\
category=exchange&reutersCode=FX_USDKRW&page={page}&pageSize={page_size}'
# 2. request(URL) > response(JSON)
response = requests.get(url)
# 3. JSON > list, dict > DataFrame
data = response.json()['result']
df = pd.DataFrame(data)[['localTradedAt', 'closePrice']]
df.tail(2)
# Out:
#    localTradedAt closePrice
# 58    2024-06-26   1,394.50
# 59    2024-06-25   1,392.00

# %%
response.json()
# Out:
# {'isSuccess': True,
#  'detailCode': '',
#  'message': '',
#  'result': [{'localTradedAt': '2024-09-20',
#    'closePrice': '1,336.00',
#    'fluctuations': '6.00',
#    'fluctuationsRatio': '0.45',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,359.38',
#    'cashSellValue': '1,312.62',
#    'sendValue': '1,349.0',
#    'receiveValue': '1,323.0'},
#   {'localTradedAt': '2024-09-19',
#    'closePrice': '1,330.00',
#    'fluctuations': '-2.00',
#    'fluctuationsRatio': '-0.15',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,353.27',
#    'cashSellValue': '1,306.73',
#    'sendValue': '1,343.0',
#    'receiveValue': '1,317.0'},
#   {'localTradedAt': '2024-09-13',
#    'closePrice': '1,332.00',
#    'fluctuations': '-7.00',
#    'fluctuationsRatio': '-0.52',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,355.31',
#    'cashSellValue': '1,308.69',
#    'sendValue': '1,345.0',
#    'receiveValue': '1,319.0'},
#   {'localTradedAt': '2024-09-12',
#    'closePrice': '1,339.00',
#    'fluctuations': '-1.50',
#    'fluctuationsRatio': '-0.11',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,362.43',
#    'cashSellValue': '1,315.57',
#    'sendValue': '1,352.1',
#    'receiveValue': '1,325.9'},
#   {'localTradedAt': '2024-09-11',
#    'closePrice': '1,340.50',
#    'fluctuations': '-4.00',
#    'fluctuationsRatio': '-0.30',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,363.95',
#    'cashSellValue': '1,317.05',
#    'sendValue': '1,353.6',
#    'receiveValue': '1,327.4'},
#   {'localTradedAt': '2024-09-10',
#    'closePrice': '1,344.50',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.19',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,368.02',
#    'cashSellValue': '1,320.98',
#    'sendValue': '1,357.6',
#    'receiveValue': '1,331.4'},
#   {'localTradedAt': '2024-09-09',
#    'closePrice': '1,342.00',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.19',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,365.48',
#    'cashSellValue': '1,318.52',
#    'sendValue': '1,355.1',
#    'receiveValue': '1,328.9'},
#   {'localTradedAt': '2024-09-06',
#    'closePrice': '1,339.50',
#    'fluctuations': '4.50',
#    'fluctuationsRatio': '0.34',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,362.94',
#    'cashSellValue': '1,316.06',
#    'sendValue': '1,352.6',
#    'receiveValue': '1,326.4'},
#   {'localTradedAt': '2024-09-05',
#    'closePrice': '1,335.00',
#    'fluctuations': '-1.50',
#    'fluctuationsRatio': '-0.11',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,358.36',
#    'cashSellValue': '1,311.64',
#    'sendValue': '1,348.0',
#    'receiveValue': '1,322.0'},
#   {'localTradedAt': '2024-09-04',
#    'closePrice': '1,336.50',
#    'fluctuations': '-4.50',
#    'fluctuationsRatio': '-0.34',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,359.88',
#    'cashSellValue': '1,313.12',
#    'sendValue': '1,349.5',
#    'receiveValue': '1,323.5'},
#   {'localTradedAt': '2024-09-03',
#    'closePrice': '1,341.00',
#    'fluctuations': '2.00',
#    'fluctuationsRatio': '0.15',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,364.46',
#    'cashSellValue': '1,317.54',
#    'sendValue': '1,354.1',
#    'receiveValue': '1,327.9'},
#   {'localTradedAt': '2024-09-02',
#    'closePrice': '1,339.00',
#    'fluctuations': '0.00',
#    'fluctuationsRatio': '0.00',
#    'fluctuationsType': {'code': '3', 'text': '보합', 'name': 'UNCHANGED'},
#    'cashBuyValue': '1,362.43',
#    'cashSellValue': '1,315.57',
#    'sendValue': '1,352.1',
#    'receiveValue': '1,325.9'},
#   {'localTradedAt': '2024-08-30',
#    'closePrice': '1,339.00',
#    'fluctuations': '4.00',
#    'fluctuationsRatio': '0.30',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,362.43',
#    'cashSellValue': '1,315.57',
#    'sendValue': '1,352.1',
#    'receiveValue': '1,325.9'},
#   {'localTradedAt': '2024-08-29',
#    'closePrice': '1,335.00',
#    'fluctuations': '-2.50',
#    'fluctuationsRatio': '-0.19',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,358.36',
#    'cashSellValue': '1,311.64',
#    'sendValue': '1,348.0',
#    'receiveValue': '1,322.0'},
#   {'localTradedAt': '2024-08-28',
#    'closePrice': '1,337.50',
#    'fluctuations': '7.50',
#    'fluctuationsRatio': '0.56',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,360.9',
#    'cashSellValue': '1,314.1',
#    'sendValue': '1,350.6',
#    'receiveValue': '1,324.4'},
#   {'localTradedAt': '2024-08-27',
#    'closePrice': '1,330.00',
#    'fluctuations': '0.50',
#    'fluctuationsRatio': '0.04',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,353.27',
#    'cashSellValue': '1,306.73',
#    'sendValue': '1,343.0',
#    'receiveValue': '1,317.0'},
#   {'localTradedAt': '2024-08-26',
#    'closePrice': '1,329.50',
#    'fluctuations': '0.50',
#    'fluctuationsRatio': '0.04',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,352.76',
#    'cashSellValue': '1,306.24',
#    'sendValue': '1,342.5',
#    'receiveValue': '1,316.5'},
#   {'localTradedAt': '2024-08-23',
#    'closePrice': '1,329.00',
#    'fluctuations': '-14.00',
#    'fluctuationsRatio': '-1.04',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,352.25',
#    'cashSellValue': '1,305.75',
#    'sendValue': '1,342.0',
#    'receiveValue': '1,316.0'},
#   {'localTradedAt': '2024-08-22',
#    'closePrice': '1,343.00',
#    'fluctuations': '8.00',
#    'fluctuationsRatio': '0.60',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,366.5',
#    'cashSellValue': '1,319.5',
#    'sendValue': '1,356.1',
#    'receiveValue': '1,329.9'},
#   {'localTradedAt': '2024-08-21',
#    'closePrice': '1,335.00',
#    'fluctuations': '3.50',
#    'fluctuationsRatio': '0.26',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,358.36',
#    'cashSellValue': '1,311.64',
#    'sendValue': '1,348.0',
#    'receiveValue': '1,322.0'},
#   {'localTradedAt': '2024-08-20',
#    'closePrice': '1,331.50',
#    'fluctuations': '-3.50',
#    'fluctuationsRatio': '-0.26',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,354.8',
#    'cashSellValue': '1,308.2',
#    'sendValue': '1,344.5',
#    'receiveValue': '1,318.5'},
#   {'localTradedAt': '2024-08-19',
#    'closePrice': '1,335.00',
#    'fluctuations': '-19.50',
#    'fluctuationsRatio': '-1.44',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,358.36',
#    'cashSellValue': '1,311.64',
#    'sendValue': '1,348.0',
#    'receiveValue': '1,322.0'},
#   {'localTradedAt': '2024-08-16',
#    'closePrice': '1,354.50',
#    'fluctuations': '-6.50',
#    'fluctuationsRatio': '-0.48',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,378.2',
#    'cashSellValue': '1,330.8',
#    'sendValue': '1,367.7',
#    'receiveValue': '1,341.3'},
#   {'localTradedAt': '2024-08-14',
#    'closePrice': '1,361.00',
#    'fluctuations': '-4.00',
#    'fluctuationsRatio': '-0.29',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,384.81',
#    'cashSellValue': '1,337.19',
#    'sendValue': '1,374.3',
#    'receiveValue': '1,347.7'},
#   {'localTradedAt': '2024-08-13',
#    'closePrice': '1,365.00',
#    'fluctuations': '-6.00',
#    'fluctuationsRatio': '-0.44',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,388.88',
#    'cashSellValue': '1,341.12',
#    'sendValue': '1,378.3',
#    'receiveValue': '1,351.7'},
#   {'localTradedAt': '2024-08-12',
#    'closePrice': '1,371.00',
#    'fluctuations': '5.00',
#    'fluctuationsRatio': '0.37',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,394.99',
#    'cashSellValue': '1,347.01',
#    'sendValue': '1,384.4',
#    'receiveValue': '1,357.6'},
#   {'localTradedAt': '2024-08-09',
#    'closePrice': '1,366.00',
#    'fluctuations': '-10.00',
#    'fluctuationsRatio': '-0.73',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,389.9',
#    'cashSellValue': '1,342.1',
#    'sendValue': '1,379.3',
#    'receiveValue': '1,352.7'},
#   {'localTradedAt': '2024-08-08',
#    'closePrice': '1,376.00',
#    'fluctuations': '0.00',
#    'fluctuationsRatio': '0.00',
#    'fluctuationsType': {'code': '3', 'text': '보합', 'name': 'UNCHANGED'},
#    'cashBuyValue': '1,400.08',
#    'cashSellValue': '1,351.92',
#    'sendValue': '1,389.4',
#    'receiveValue': '1,362.6'},
#   {'localTradedAt': '2024-08-07',
#    'closePrice': '1,376.00',
#    'fluctuations': '-1.50',
#    'fluctuationsRatio': '-0.11',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,400.08',
#    'cashSellValue': '1,351.92',
#    'sendValue': '1,389.4',
#    'receiveValue': '1,362.6'},
#   {'localTradedAt': '2024-08-06',
#    'closePrice': '1,377.50',
#    'fluctuations': '7.50',
#    'fluctuationsRatio': '0.55',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,401.6',
#    'cashSellValue': '1,353.4',
#    'sendValue': '1,390.9',
#    'receiveValue': '1,364.1'},
#   {'localTradedAt': '2024-08-05',
#    'closePrice': '1,370.00',
#    'fluctuations': '8.50',
#    'fluctuationsRatio': '0.62',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,393.97',
#    'cashSellValue': '1,346.03',
#    'sendValue': '1,383.4',
#    'receiveValue': '1,356.6'},
#   {'localTradedAt': '2024-08-02',
#    'closePrice': '1,361.50',
#    'fluctuations': '-9.50',
#    'fluctuationsRatio': '-0.69',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,385.32',
#    'cashSellValue': '1,337.68',
#    'sendValue': '1,374.8',
#    'receiveValue': '1,348.2'},
#   {'localTradedAt': '2024-08-01',
#    'closePrice': '1,371.00',
#    'fluctuations': '0.00',
#    'fluctuationsRatio': '0.00',
#    'fluctuationsType': {'code': '3', 'text': '보합', 'name': 'UNCHANGED'},
#    'cashBuyValue': '1,394.99',
#    'cashSellValue': '1,347.01',
#    'sendValue': '1,384.4',
#    'receiveValue': '1,357.6'},
#   {'localTradedAt': '2024-07-31',
#    'closePrice': '1,371.00',
#    'fluctuations': '-14.00',
#    'fluctuationsRatio': '-1.01',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,394.99',
#    'cashSellValue': '1,347.01',
#    'sendValue': '1,384.4',
#    'receiveValue': '1,357.6'},
#   {'localTradedAt': '2024-07-30',
#    'closePrice': '1,385.00',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.18',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,409.23',
#    'cashSellValue': '1,360.77',
#    'sendValue': '1,398.5',
#    'receiveValue': '1,371.5'},
#   {'localTradedAt': '2024-07-29',
#    'closePrice': '1,382.50',
#    'fluctuations': '-3.00',
#    'fluctuationsRatio': '-0.22',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,406.69',
#    'cashSellValue': '1,358.31',
#    'sendValue': '1,396.0',
#    'receiveValue': '1,369.0'},
#   {'localTradedAt': '2024-07-26',
#    'closePrice': '1,385.50',
#    'fluctuations': '1.00',
#    'fluctuationsRatio': '0.07',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,409.74',
#    'cashSellValue': '1,361.26',
#    'sendValue': '1,399.0',
#    'receiveValue': '1,372.0'},
#   {'localTradedAt': '2024-07-25',
#    'closePrice': '1,384.50',
#    'fluctuations': '1.50',
#    'fluctuationsRatio': '0.11',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,408.72',
#    'cashSellValue': '1,360.28',
#    'sendValue': '1,398.0',
#    'receiveValue': '1,371.0'},
#   {'localTradedAt': '2024-07-24',
#    'closePrice': '1,383.00',
#    'fluctuations': '-3.50',
#    'fluctuationsRatio': '-0.25',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,407.2',
#    'cashSellValue': '1,358.8',
#    'sendValue': '1,396.5',
#    'receiveValue': '1,369.5'},
#   {'localTradedAt': '2024-07-23',
#    'closePrice': '1,386.50',
#    'fluctuations': '-1.50',
#    'fluctuationsRatio': '-0.11',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,410.76',
#    'cashSellValue': '1,362.24',
#    'sendValue': '1,400.0',
#    'receiveValue': '1,373.0'},
#   {'localTradedAt': '2024-07-22',
#    'closePrice': '1,388.00',
#    'fluctuations': '-3.50',
#    'fluctuationsRatio': '-0.25',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,412.29',
#    'cashSellValue': '1,363.71',
#    'sendValue': '1,401.6',
#    'receiveValue': '1,374.4'},
#   {'localTradedAt': '2024-07-19',
#    'closePrice': '1,391.50',
#    'fluctuations': '5.50',
#    'fluctuationsRatio': '0.40',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,415.85',
#    'cashSellValue': '1,367.15',
#    'sendValue': '1,405.1',
#    'receiveValue': '1,377.9'},
#   {'localTradedAt': '2024-07-18',
#    'closePrice': '1,386.00',
#    'fluctuations': '5.00',
#    'fluctuationsRatio': '0.36',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,410.25',
#    'cashSellValue': '1,361.75',
#    'sendValue': '1,399.5',
#    'receiveValue': '1,372.5'},
#   {'localTradedAt': '2024-07-17',
#    'closePrice': '1,381.00',
#    'fluctuations': '-4.50',
#    'fluctuationsRatio': '-0.32',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,405.16',
#    'cashSellValue': '1,356.84',
#    'sendValue': '1,394.5',
#    'receiveValue': '1,367.5'},
#   {'localTradedAt': '2024-07-16',
#    'closePrice': '1,385.50',
#    'fluctuations': '0.00',
#    'fluctuationsRatio': '0.00',
#    'fluctuationsType': {'code': '3', 'text': '보합', 'name': 'UNCHANGED'},
#    'cashBuyValue': '1,409.74',
#    'cashSellValue': '1,361.26',
#    'sendValue': '1,399.0',
#    'receiveValue': '1,372.0'},
#   {'localTradedAt': '2024-07-15',
#    'closePrice': '1,385.50',
#    'fluctuations': '8.50',
#    'fluctuationsRatio': '0.62',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,409.74',
#    'cashSellValue': '1,361.26',
#    'sendValue': '1,399.0',
#    'receiveValue': '1,372.0'},
#   {'localTradedAt': '2024-07-12',
#    'closePrice': '1,377.00',
#    'fluctuations': '3.50',
#    'fluctuationsRatio': '0.25',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,401.09',
#    'cashSellValue': '1,352.91',
#    'sendValue': '1,390.4',
#    'receiveValue': '1,363.6'},
#   {'localTradedAt': '2024-07-11',
#    'closePrice': '1,373.50',
#    'fluctuations': '-11.00',
#    'fluctuationsRatio': '-0.79',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,397.53',
#    'cashSellValue': '1,349.47',
#    'sendValue': '1,386.9',
#    'receiveValue': '1,360.1'},
#   {'localTradedAt': '2024-07-10',
#    'closePrice': '1,384.50',
#    'fluctuations': '0.50',
#    'fluctuationsRatio': '0.04',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,408.72',
#    'cashSellValue': '1,360.28',
#    'sendValue': '1,398.0',
#    'receiveValue': '1,371.0'},
#   {'localTradedAt': '2024-07-09',
#    'closePrice': '1,384.00',
#    'fluctuations': '-1.00',
#    'fluctuationsRatio': '-0.07',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,408.22',
#    'cashSellValue': '1,359.78',
#    'sendValue': '1,397.5',
#    'receiveValue': '1,370.5'},
#   {'localTradedAt': '2024-07-08',
#    'closePrice': '1,385.00',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.18',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,409.23',
#    'cashSellValue': '1,360.77',
#    'sendValue': '1,398.5',
#    'receiveValue': '1,371.5'},
#   {'localTradedAt': '2024-07-05',
#    'closePrice': '1,382.50',
#    'fluctuations': '0.50',
#    'fluctuationsRatio': '0.04',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,406.69',
#    'cashSellValue': '1,358.31',
#    'sendValue': '1,396.0',
#    'receiveValue': '1,369.0'},
#   {'localTradedAt': '2024-07-04',
#    'closePrice': '1,382.00',
#    'fluctuations': '-5.00',
#    'fluctuationsRatio': '-0.36',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,406.18',
#    'cashSellValue': '1,357.82',
#    'sendValue': '1,395.5',
#    'receiveValue': '1,368.5'},
#   {'localTradedAt': '2024-07-03',
#    'closePrice': '1,387.00',
#    'fluctuations': '0.00',
#    'fluctuationsRatio': '0.00',
#    'fluctuationsType': {'code': '3', 'text': '보합', 'name': 'UNCHANGED'},
#    'cashBuyValue': '1,411.27',
#    'cashSellValue': '1,362.73',
#    'sendValue': '1,400.5',
#    'receiveValue': '1,373.5'},
#   {'localTradedAt': '2024-07-02',
#    'closePrice': '1,387.00',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.18',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,411.27',
#    'cashSellValue': '1,362.73',
#    'sendValue': '1,400.5',
#    'receiveValue': '1,373.5'},
#   {'localTradedAt': '2024-07-01',
#    'closePrice': '1,384.50',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.18',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,408.72',
#    'cashSellValue': '1,360.28',
#    'sendValue': '1,398.0',
#    'receiveValue': '1,371.0'},
#   {'localTradedAt': '2024-06-28',
#    'closePrice': '1,382.00',
#    'fluctuations': '-5.50',
#    'fluctuationsRatio': '-0.40',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,406.18',
#    'cashSellValue': '1,357.82',
#    'sendValue': '1,395.5',
#    'receiveValue': '1,368.5'},
#   {'localTradedAt': '2024-06-27',
#    'closePrice': '1,387.50',
#    'fluctuations': '-7.00',
#    'fluctuationsRatio': '-0.50',
#    'fluctuationsType': {'code': '5', 'text': '하락', 'name': 'FALLING'},
#    'cashBuyValue': '1,411.78',
#    'cashSellValue': '1,363.22',
#    'sendValue': '1,401.0',
#    'receiveValue': '1,374.0'},
#   {'localTradedAt': '2024-06-26',
#    'closePrice': '1,394.50',
#    'fluctuations': '2.50',
#    'fluctuationsRatio': '0.18',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,418.9',
#    'cashSellValue': '1,370.1',
#    'sendValue': '1,408.1',
#    'receiveValue': '1,380.9'},
#   {'localTradedAt': '2024-06-25',
#    'closePrice': '1,392.00',
#    'fluctuations': '4.00',
#    'fluctuationsRatio': '0.29',
#    'fluctuationsType': {'code': '2', 'text': '상승', 'name': 'RISING'},
#    'cashBuyValue': '1,416.36',
#    'cashSellValue': '1,367.64',
#    'sendValue': '1,405.6',
#    'receiveValue': '1,378.4'}]}

# %%
def exchange_rate(code='FX_USDKRW',page=1, page_size=60):
    # URL가져오기
    url = f'https://m.stock.naver.com/front-api/marketIndex/prices?category=exchange&reutersCode={code}&page={page}&pageSize={page_size}'
    # 요청
    response = requests.get(url)  # requests 패키지 안에 get이라는 함수를 사용하는 것
    # json으로 바꾸기
    data = response.json()['result']  # json을 list형태로 바꿔준 것 / key값을 출력해서 value값들 출력
    return pd.DataFrame(data)[['localTradedAt', 'closePrice']]  # localTradedAt(날짜), closePrice(종가)

# %%
# 원달러 환율 데이터 수집
exchange_rate(page_size=10).tail(2)
# Out:
#   localTradedAt closePrice
# 8    2024-09-05   1,335.00
# 9    2024-09-04   1,336.50

# %% [markdown]
# #### 6. 시각화

# %%
# 데이터 수집
page_size = 30
kp_df = stock_price('KOSPI', page_size=page_size)  # 'closePrice'-> 2,764.73
kd_df = stock_price('KOSDAQ', page_size=page_size)  
usd_df = exchange_rate(page_size=page_size)

# 데이터 전처리
# 2,600.34로 되어 있는 형태를 2764.73(float)형태로 변환시키는 과정
kp_df['closePrice'] = kp_df['closePrice'].apply(lambda data: float(data.replace(',', '')))  # apply: 모든 결과 요소 출력해주는 역할
kd_df['closePrice'] = kd_df['closePrice'].apply(lambda data: float(data.replace(',', '')))
usd_df['closePrice'] = usd_df['closePrice'].apply(lambda data: float(data.replace(',', '')))

# %%
import matplotlib.pyplot as plt

# %%
# 해당 그래프는 데이터 스케일이 맞지 않아서, 서로의 관계를 찾을 수 없다.
# 아래에서 minmax_scale을 활용하여 데이터 스케일링 진행.

plt.figure(figsize=(20, 3))
plt.plot(kp_df['localTradedAt'], kp_df['closePrice'], label='kospi')
plt.plot(kd_df['localTradedAt'], kd_df['closePrice'], label='kosdaq')
plt.plot(usd_df['localTradedAt'], usd_df['closePrice'], label='usd')
plt.legend()
plt.xticks(kp_df['localTradedAt'][::5])
plt.show()

# %% [markdown]
# #### 7. 데이터 스케일링
# - min max scaling
#
#
# - $z = \frac{x_i - min(x)}{max(x) - min(x)} (0 \leqq z \leqq 1)$
#
#
# - latex syntax : `https://jjycjnmath.tistory.com/117`

# %%
from sklearn.preprocessing import minmax_scale

# %%
minmax_scale(kp_df['closePrice'])
# Out:
# array([0.48028821, 0.34704066, 0.31930005, 0.30221307, 0.        ,
#        0.0517756 , 0.11610911, 0.15908389, 0.31976325, 0.34704066,
#        0.77848688, 0.86273803, 0.82830674, 0.76639218, 0.90818322,
#        0.90519815, 0.95028307, 0.96922285, 1.        , 0.96634071,
#        0.94318065, 0.82856408, 0.94626866, 0.6748842 , 0.55651055,
#        0.54004117, 0.38630983, 0.22316006, 0.28327329, 0.04518785])

# %%
# 스케일러를 해주면 일정한 간격에서의 변동을 확인할 수 있다.

# 코스피,코스닥이 높아질 때 원달러 환율은 낮아지고
# 원달러 환율이 높을 때 코스피, 코스닥이 낮아진다.

plt.figure(figsize=(20, 3))
plt.plot(kp_df['localTradedAt'], minmax_scale(kp_df['closePrice']), label='kospi')
plt.plot(kd_df['localTradedAt'], minmax_scale(kd_df['closePrice']), label='kosdaq')
plt.plot(usd_df['localTradedAt'], minmax_scale(usd_df['closePrice']), label='usd')
plt.xticks(kp_df['localTradedAt'][::5])
plt.legend()
plt.show()

# %% [markdown]
# #### 8. 상관관계 분석
# - 피어슨 상관계수(Pearson Correlation Coefficient)
# - 두 데이터 집합의 상관도를 분석할때 사용되는 지표
# - 상관계수의 해석
#     - -1에 가까울수록 서로 반대방향으로 움직임
#     - 1에 가까울수록 서로 같은방향으로 움직임
#     - 0에 가까울수록 두 데이터는 관계가 없음

# %%
# 데이터 전처리 : merge
# 날짜 데이터를 기준으로 합쳐준다.
merge_df = pd.merge(kp_df, kd_df, on='localTradedAt')
merge_df = pd.merge(merge_df, usd_df, on='localTradedAt')
merge_df.columns = ['date', 'kospi', 'kosdaq', 'usd']
merge_df.tail(2)
# Out:
#           date    kospi  kosdaq     usd
# 28  2024-08-07  2568.41  748.54  1376.0
# 29  2024-08-06  2522.15  732.87  1377.5

# %%
merge_df.iloc[:, 1:].corr()
# Out:
#            kospi    kosdaq       usd
# kospi   1.000000  0.881488 -0.358403
# kosdaq  0.881488  1.000000  0.028613
# usd    -0.358403  0.028613  1.000000

# %%
## 투자 전략 ##
# 원달러 환율이 높으면 달러를 원화로 환전하여 코스피 지수를 구매한다.
# 원달러 환율이 낮으면 코스피 지수를 판매하여 달러로 환전한다.
