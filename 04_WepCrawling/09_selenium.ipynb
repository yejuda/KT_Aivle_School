# %% [markdown]
# ### selenium
# - `https://www.selenium.dev`
# - 자동화를 목적으로 만들어진 다양한 브라우져와 언어를 지원하는 라이브러리
# - 크롬 브라우져 설치
#     - 크롬 브라우져 드라이버 다운로드 (크롬 브라우져와 같은 버전)
#     - 다운로드한 드라이버 압축 해제
#     - chromedriver, chromedriver.exe 생성
#     - windows : 주피터 노트북 파일과 동일한 디렉토리에 chromedriver.exe 파일 업로드
#     - mac : sudo cp ~/Download/chromedirver /usr/local/bin

# %%
# !pip install selenium

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# 직접 드라이버를 다운 받아서 설정
driver = webdriver.Chrome()

# %%
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager  
# # !pip install webdriver_manager

# %%
# # 자동으로 본인 환경에 맞는 드라이버를 다운 받아서 설정
# service = Service(chromeDriverManager().install())

# %%
# 페이지 이동
driver.get('https://daum.net')

# %%
# 브라우저 사이즈 조절
driver.set_window_size(200, 600)

# %%
# 자바스크립트 코드 실행
driver.execute_script('alert("hello selenium!");')

# %%
# alert 종료
alert = driver.switch_to.alert
alert.accept()

# %% [markdown]
# 되도록이면 띄운 창을 건들이지 말아라. -> 연결 끊어질 수 있음.
# 다른 창에서 F12를 통해서 elements를 찾는 방법으로 진행해라.

# %%
# 검색어 입력 
# q
driver.find_element(By.CSS_SELECTOR, '#q')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0aaa4a76b9bdb4fff5ef9aa534692444", element="f.178AF7C5A579D942BC9C6A490837BFEA.d.B7A45F46B9D671C598C54EEB3BFEC0A2.e.2")>

# %%
# 검색어 입력 
driver.find_element(By.CSS_SELECTOR, '#q').send_keys('selenium')

# %%
# 검색 버튼 클릭(F12눌러서 '검색버튼'html 코드 찾아서 넣어주기 -> '.btn_ksearch')
driver.find_element(By.CSS_SELECTOR, '.btn_ksearch').click()

# %%
# 브라우저 종료: 자원(RAM) 반환
driver.quit()

# %% [markdown]
# #### 텍스트 데이터 가져오기
# - TED 사이트 : `https://www.ted.com`

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.ted.com/talks')

# %% [markdown]
# 안내창 닫기 버튼 클릭

# %%
import time

# 'time.sleep()'코드 없이 위의 코드들과 함께 실행하면 에러가 발생할 것이다. 

time.sleep(3)  # 랜더링 시간을 중간에 기다려줄 수 있도록 설정
driver.find_element(By.CSS_SELECTOR, '#close-pc-btn-handler').click()

# %%
driver.find_element(By.CSS_SELECTOR, 'h2.text-textPrimary-onLight').text
# Out:
# 'TED Talks: Discover ideas worth spreading'

# %%
driver.quit()

# %% [markdown]
# #### Headless
# - 브라우져를 화면에 띄우지 않고 메모리상에서만 올려서 크롤링하는 방법
# - window가 지원되지 않는 환경에서 사용이 가능
# - chrome version 60.0.0.0 이상부터 지원 합니다.
# ------
# 윈도우를 띄우면 서버량을 많이 잡아먹는다. 그래서 브라우저를 띄우지 않고 크롤링 하는 것.

# %%
options = webdriver.ChromeOptions()
options.add_argument('headless')

driver = webdriver.Chrome(options=options)
driver.get('https://www.ted.com/talks')

time.sleep(1)  # 랜더링 시간을 중간에 기다려줄 수 있도록 설정

driver.find_element(By.CSS_SELECTOR, '#close-pc-btn-handler').click() 
text = driver.find_element(By.CSS_SELECTOR, 'h2.text-textPrimary-onLight').text
print(text)

driver.quit()
# Out:
# TED Talks: Discover ideas worth spreading
